# %%
from hockey_rink import NHLRink, RinkImage
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
from scipy import stats
import statsmodels.formula.api as smf
import statsmodels.api as sm
import requests
from bs4 import BeautifulSoup

# %%
all_players = pd.read_csv("skaters_2024.csv")
ages = pd.read_csv("player_ages_24.csv")
mult_teams = pd.read_csv("split_times_2024.csv")
goals = pd.read_csv("goals_2024.csv")
#all data is from Natural Stat Trick

# %%
individual_stats = all_players[['Player', 'CF', 'CA', 'GF', 'GA', 'GF%', 'xGF', 'xGA', 'HDGF%', 'PDO']]
goals = goals[['Player', 'Goals', 'Total Assists', 'First Assists', 'Second Assists', 'Total Points', 'IPP', 'Shots', 'SH%', 'ixG', 'iCF', 'iHDCF', 'Rush Attempts','Rebounds Created', 'Giveaways', 'Takeaways', 'Hits', 'Hits Taken', 'Shots Blocked', 'Faceoffs %']]
player_stats = goals.merge(individual_stats, on="Player")
player_stats.head()
# Out:
#              Player  Goals  Total Assists  First Assists  Second Assists  \
# 0   Nikita Kucherov     44            100             62              38
# 1  Nathan MacKinnon     51             89             50              39
# 2    Connor McDavid     32            100             62              38
# 3    Artemi Panarin     49             71             37              34
# 4    David Pastrnak     47             63             39              24
#
#    Total Points    IPP  Shots    SH%    ixG  ...  Faceoffs %    CF    CA   GF  \
# 0           144  82.76    306  14.38  32.59  ...       50.00  2299  1465  174
# 1           140  74.87    405  12.59  34.82  ...       46.19  2587  1528  187
# 2           132  79.04    263  12.17  33.15  ...       51.10  2242  1237  167
# 3           120  80.00    303  16.17  28.44  ...       10.00  2344  1306  150
# 4           110  80.88    382  12.30  37.42  ...       33.33  1965  1366  136
#
#     GA    GF%     xGF    xGA  HDGF%    PDO
# 0  103  62.82  135.87  87.21  61.48  1.020
# 1   88  68.00  144.48  79.83  68.84  1.028
# 2   82  67.07  146.79  70.14  72.09  1.020
# 3   73  67.26  134.89  73.56  59.26  1.026
# 4   68  66.67  118.40  69.76  65.14  1.036
#
# [5 rows x 29 columns]

# %%
all_players.head()
# Out:
#    Unnamed: 0          Player Team Position  GP        TOI  CF  CA     CF%  \
# 0         870  Cameron Butler  CBJ        R   1   0.900000   2   0  100.00
# 1         538     Cale Fleury  SEA        D   1  13.500000  20   5   80.00
# 2         245    Jayson Megna  BOS        C   1  11.750000  13   4   76.47
# 3         917    Ondrej Pavel  COL        C   2  12.200000  15   5   75.00
# 4         798  Mavrik Bourque  DAL        C   1  10.933333  20   7   74.07
#
#    FF  ...    PDO  Off. Zone Starts  Neu. Zone Starts  Def. Zone Starts  \
# 0   2  ...   0.00                 1                 0                 0
# 1  16  ...  1.125                 2                 1                 0
# 2   8  ...  1.000                 0                 1                 1
# 3   9  ...  0.667                 1                 4                 0
# 4  13  ...  1.000                 2                 4                 3
#
#   On The Fly Starts  Off. Zone Start %  Off. Zone Faceoffs Neu. Zone Faceoffs  \
# 0                 0             100.00                   3                  0
# 1                14             100.00                   8                  3
# 2                13               0.00                   0                  2
# 3                15             100.00                   3                  6
# 4                 8              40.00                   4                  4
#
#    Def. Zone Faceoffs  Off. Zone Faceoff %
# 0                   0               100.00
# 1                   0               100.00
# 2                   1                 0.00
# 3                   1                75.00
# 4                   3                57.14
#
# [5 rows x 54 columns]

# %%
#All Players usage to calculate the overall percentile
all_toi = all_players[['Player', 'Team','Position', 'GP', 'TOI']]
all_toi = all_toi.query('GP>=30')
all_toi['TOI'] = round(all_toi['TOI'],2)
all_toi.head()
# Out:
#               Player Team Position  GP      TOI
# 9    Matthew Tkachuk  FLA        L  80  1491.20
# 11        Zach Hyman  EDM        L  80  1560.03
# 12  Carter Verhaeghe  FLA        C  76  1365.15
# 13     Stefan Noesen  CAR        R  81   960.92
# 15     Evan Bouchard  EDM        D  81  1862.77

# %%
ages=ages[['Player','Team','Position', 'Age']]
ages.head()
# Out:
#          Player Team Position  Age
# 0    A.J. Greer  CGY        L   27
# 1  Aaron Ekblad  FLA        D   28
# 2  Adam Beckman  MIN        L   23
# 3  Adam Boqvist  CBJ        D   23
# 4  Adam Edstrom  NYR        C   23

# %%
#add in player ages
all_toi = all_toi.merge(ages, on= ('Player', 'Position'), how = 'left' )
all_toi=all_toi.rename(columns={'Team_x': 'Team'})
all_toi.drop(columns=['Team_y'], inplace=True)
all_toi.head()
# Out:
#              Player Team Position  GP      TOI   Age
# 0   Matthew Tkachuk  FLA        L  80  1491.20  26.0
# 1        Zach Hyman  EDM        L  80  1560.03  32.0
# 2  Carter Verhaeghe  FLA        C  76  1365.15  28.0
# 3     Stefan Noesen  CAR        R  81   960.92  31.0
# 4     Evan Bouchard  EDM        D  81  1862.77  24.0

# %%
#redefine the dataframe
all_toi = all_toi[['Player', 'Team', 'Position', 'GP', 'TOI', 'Age']]
all_toi['atoi'] =round((all_toi['TOI']/all_toi['GP']),2)
all_toi.head()
# Out:
#              Player Team Position  GP      TOI   Age   atoi
# 0   Matthew Tkachuk  FLA        L  80  1491.20  26.0  18.64
# 1        Zach Hyman  EDM        L  80  1560.03  32.0  19.50
# 2  Carter Verhaeghe  FLA        C  76  1365.15  28.0  17.96
# 3     Stefan Noesen  CAR        R  81   960.92  31.0  11.86
# 4     Evan Bouchard  EDM        D  81  1862.77  24.0  23.00

# %%
all_toi.query('Player == "Noah Hanifin"')
# Out:
#            Player      Team Position  GP      TOI   Age   atoi
# 314  Noah Hanifin  CGY, VGK        D  80  1889.12  27.0  23.61

# %%
all_toi.query('Player == "Sebastian Aho"')
# Out:
#             Player Team Position  GP      TOI   Age   atoi
# 31   Sebastian Aho  CAR        C  78  1530.95  26.0  19.63
# 396  Sebastian Aho  NYI        D  58   950.70  28.0  16.39

# %%
#Total TOI Percentile
all_toi['total_percentile'] = all_toi['TOI'].rank(pct=True)
all_toi['Skater']=np.where(all_toi['Position'] == "D", "D", "F")
all_toi.head()
# Out:
#              Player Team Position  GP      TOI   Age   atoi  total_percentile  \
# 0   Matthew Tkachuk  FLA        L  80  1491.20  26.0  18.64          0.800000
# 1        Zach Hyman  EDM        L  80  1560.03  32.0  19.50          0.850746
# 2  Carter Verhaeghe  FLA        C  76  1365.15  28.0  17.96          0.694030
# 3     Stefan Noesen  CAR        R  81   960.92  31.0  11.86          0.367164
# 4     Evan Bouchard  EDM        D  81  1862.77  24.0  23.00          0.968657
#
#   Skater
# 0      F
# 1      F
# 2      F
# 3      F
# 4      D

# %%
#I need to pull out the multi-team players first
multi_teams = all_toi.query('Team.str.contains(",")')
multi_teams = multi_teams.explode('Team').reset_index(drop=True)
multi_teams.head()
# Out:
#               Player      Team Position  GP      TOI   Age   atoi  \
# 0      Tyler Toffoli  N.J, WPG     C, R  79  1339.85  32.0  16.96
# 1      Jake Guentzel  CAR, PIT     C, L  67  1330.73  29.0  19.86
# 2    Andrei Kuzmenko  CGY, VAN        L  72  1071.67  28.0  14.88
# 3    Michael Bunting  CAR, PIT        L  81  1270.53  28.0  15.69
# 4  Casey Mittelstadt  BUF, COL        C  80  1418.37  25.0  17.73
#
#    total_percentile Skater
# 0          0.670149      F
# 1          0.662687      F
# 2          0.450746      F
# 3          0.595522      F
# 4          0.732836      F

# %%
#test
multi_teams.query('Player == "Noah Hanifin"')
# Out:
#           Player      Team Position  GP      TOI   Age   atoi  \
# 22  Noah Hanifin  CGY, VGK        D  80  1889.12  27.0  23.61
#
#     total_percentile Skater
# 22          0.973134      D

# %%
#redefine the data frame
mult_teams = mult_teams[['Player', 'Team', 'GP', 'TOI']]
mult_teams['atoi'] = round((mult_teams['TOI']/mult_teams['GP']),2)
mult_teams['TOI'] = round(mult_teams['TOI'],2)
mult_teams.head()
# Out:
#            Player Team  GP    TOI   atoi
# 0  Cameron Butler  CBJ   1   0.90   0.90
# 1     Cale Fleury  SEA   1  13.50  13.50
# 2    Jayson Megna  BOS   1  11.75  11.75
# 3    Ondrej Pavel  COL   2  12.20   6.10
# 4  Mavrik Bourque  DAL   1  10.93  10.93

# %%
#drop those players that appear only once, keeping all duplicates
mult_teams = mult_teams[mult_teams.duplicated('Player', keep=False)]
mult_teams=mult_teams.sort_values(by=['Player', 'GP'], ascending=[True, False]).reset_index()
mult_teams=mult_teams.drop('index', axis = 1)
mult_teams.head()
# Out:
#           Player Team  GP      TOI   atoi
# 0  Adam Henrique  ANA  60  1054.67  17.58
# 1  Adam Henrique  EDM  22   326.17  14.83
# 2   Adam Ruzicka  CGY  39   396.27  10.16
# 3   Adam Ruzicka  ARI   3    24.87   8.29
# 4  Alex Wennberg  SEA  60  1129.12  18.82

# %%
mult_teams.query('Player == "Elias Lindholm"')
# Out:
#             Player Team  GP      TOI   atoi
# 49  Elias Lindholm  CGY  49  1016.68  20.75
# 50  Elias Lindholm  VAN  26   460.33  17.71

# %%
#Creating a new df of just the multi team players with their total TOI and overal percentile.
multi_teams = multi_teams.merge(mult_teams, on = "Player", how = "left")
multi_teams.head()
# Out:
#             Player    Team_x Position  GP_x    TOI_x   Age  atoi_x  \
# 0    Tyler Toffoli  N.J, WPG     C, R    79  1339.85  32.0   16.96
# 1    Tyler Toffoli  N.J, WPG     C, R    79  1339.85  32.0   16.96
# 2    Jake Guentzel  CAR, PIT     C, L    67  1330.73  29.0   19.86
# 3    Jake Guentzel  CAR, PIT     C, L    67  1330.73  29.0   19.86
# 4  Andrei Kuzmenko  CGY, VAN        L    72  1071.67  28.0   14.88
#
#    total_percentile Skater Team_y  GP_y    TOI_y  atoi_y
# 0          0.670149      F    N.J  61.0  1069.63   17.53
# 1          0.670149      F    WPG  18.0   270.22   15.01
# 2          0.662687      F    PIT  50.0  1033.25   20.66
# 3          0.662687      F    CAR  17.0   297.48   17.50
# 4          0.450746      F    VAN  43.0   617.12   14.35

# %%
multi_teams = multi_teams[['Player', 'Team_y', 'Position', 'GP_x', 'GP_y', 'TOI_x', 'TOI_y', 'atoi_x', 'atoi_y', 'Age', 'total_percentile', 'Skater' ]]
multi_teams=multi_teams.rename(columns={'Team_y': 'Team',
                                       'TOI_x':'TOI', 'TOI_y':'team_TOI', 'GP_x':'GP', 'GP_y':'team_gp', 'atoi_x':'atoi', 'atoi_y':'team_atoi'})

multi_teams.head()
# Out:
#             Player Team Position  GP  team_gp      TOI  team_TOI   atoi  \
# 0    Tyler Toffoli  N.J     C, R  79     61.0  1339.85   1069.63  16.96
# 1    Tyler Toffoli  WPG     C, R  79     18.0  1339.85    270.22  16.96
# 2    Jake Guentzel  PIT     C, L  67     50.0  1330.73   1033.25  19.86
# 3    Jake Guentzel  CAR     C, L  67     17.0  1330.73    297.48  19.86
# 4  Andrei Kuzmenko  VAN        L  72     43.0  1071.67    617.12  14.88
#
#    team_atoi   Age  total_percentile Skater
# 0      17.53  32.0          0.670149      F
# 1      15.01  32.0          0.670149      F
# 2      20.66  29.0          0.662687      F
# 3      17.50  29.0          0.662687      F
# 4      14.35  28.0          0.450746      F

# %%
#all of the players who did not move this season
single_teams = all_toi.query('~Team.str.contains(",")')
single_teams.head()
# Out:
#              Player Team Position  GP      TOI   Age   atoi  total_percentile  \
# 0   Matthew Tkachuk  FLA        L  80  1491.20  26.0  18.64          0.800000
# 1        Zach Hyman  EDM        L  80  1560.03  32.0  19.50          0.850746
# 2  Carter Verhaeghe  FLA        C  76  1365.15  28.0  17.96          0.694030
# 3     Stefan Noesen  CAR        R  81   960.92  31.0  11.86          0.367164
# 4     Evan Bouchard  EDM        D  81  1862.77  24.0  23.00          0.968657
#
#   Skater
# 0      F
# 1      F
# 2      F
# 3      F
# 4      D

# %%
#checking for a multi-team player
single_teams.query('Player == "Elias Lindholm"')
# Out:
# Empty DataFrame
# Columns: [Player, Team, Position, GP, TOI, Age, atoi, total_percentile, Skater]
# Index: []

# %%
#join the multi team players back in 
all_players = single_teams.append(multi_teams, ignore_index=True)
all_players['team_gp'] = np.where(all_players['team_gp'].isnull(), all_players['GP'],all_players['team_gp'] )
all_players['team_TOI'] = np.where(all_players['team_TOI'].isnull(), all_players['TOI'],all_players['team_TOI'])
all_players['team_atoi'] = np.where(all_players['team_atoi'].isnull(), all_players['atoi'],all_players['team_atoi'])
all_players.head()
# Out:
# C:\Users\Karoline Sears\AppData\Local\Temp\ipykernel_12040\1387649138.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_players = single_teams.append(multi_teams, ignore_index=True)
#              Player Team Position  GP      TOI   Age   atoi  total_percentile  \
# 0   Matthew Tkachuk  FLA        L  80  1491.20  26.0  18.64          0.800000
# 1        Zach Hyman  EDM        L  80  1560.03  32.0  19.50          0.850746
# 2  Carter Verhaeghe  FLA        C  76  1365.15  28.0  17.96          0.694030
# 3     Stefan Noesen  CAR        R  81   960.92  31.0  11.86          0.367164
# 4     Evan Bouchard  EDM        D  81  1862.77  24.0  23.00          0.968657
#
#   Skater  team_gp  team_TOI  team_atoi
# 0      F     80.0   1491.20      18.64
# 1      F     80.0   1560.03      19.50
# 2      F     76.0   1365.15      17.96
# 3      F     81.0    960.92      11.86
# 4      D     81.0   1862.77      23.00

# %%
# all_players['toi_pace'] = all_players['team_TOI']/all_players['team_gp']
all_players['adj_toi'] = all_players['team_atoi']*all_players['GP']

# %%
# #replace the null values in team_gp and team_TOI with the games played and TOI for single team players
# all_players['team_TOI'] = np.where(pd.isnull(all_players['team_TOI']), all_players['TOI'], all_players['team_TOI'])
# all_players['team_ATOI'] = all_players['TOI']/all_players['GP']
# all_players['team_gp'] = np.where(pd.isnull(all_players['team_gp']), all_players['GP'], all_players['team_gp'])

# %%
#test - ADD PACE HERE
all_players.query('Player == "Elias Lindholm"')
# Out:
#              Player Team Position  GP      TOI   Age   atoi  total_percentile  \
# 659  Elias Lindholm  CGY        C  75  1477.02  29.0  19.69          0.789552
# 660  Elias Lindholm  VAN        C  75  1477.02  29.0  19.69          0.789552
#
#     Skater  team_gp  team_TOI  team_atoi  adj_toi
# 659      F     49.0   1016.68      20.75  1556.25
# 660      F     26.0    460.33      17.71  1328.25

# %%
#Quality of Team - Rank Among Forwards rank among teams first 

def calculate_percentile_rank(player_time_on_ice, player_position, player_team):
    # Assuming you have a DataFrame called `all_players` containing player data
    
    # Filter data based on player position and team
    filtered_data = all_players[(all_players["Skater"] == "F") & (all_players["Team"] == player_team)]
    
    # Extract time on ice values for the specific player position and team
    forwards_time_on_ice = filtered_data["adj_toi"]
    percentile_rank = None
    
    if player_position == "D":
        percentile_rank = stats.percentileofscore(forwards_time_on_ice, player_time_on_ice)
    elif player_position == "F":
        percentile_rank = stats.percentileofscore(forwards_time_on_ice, player_time_on_ice)

    # Calculate the percentile rank
    return percentile_rank

all_players["QoTF"] = all_players.apply(lambda row: calculate_percentile_rank(row["adj_toi"], row["Skater"], row["Team"]), axis=1)
all_players.head()
# Out:
#              Player Team Position  GP      TOI   Age   atoi  total_percentile  \
# 0   Matthew Tkachuk  FLA        L  80  1491.20  26.0  18.64          0.800000
# 1        Zach Hyman  EDM        L  80  1560.03  32.0  19.50          0.850746
# 2  Carter Verhaeghe  FLA        C  76  1365.15  28.0  17.96          0.694030
# 3     Stefan Noesen  CAR        R  81   960.92  31.0  11.86          0.367164
# 4     Evan Bouchard  EDM        D  81  1862.77  24.0  23.00          0.968657
#
#   Skater  team_gp  team_TOI  team_atoi  adj_toi        QoTF
# 0      F     80.0   1491.20      18.64  1491.20   93.333333
# 1      F     80.0   1560.03      19.50  1560.00   80.000000
# 2      F     76.0   1365.15      17.96  1364.96   80.000000
# 3      F     81.0    960.92      11.86   960.66   33.333333
# 4      D     81.0   1862.77      23.00  1863.00  100.000000

# %%
#Quality of Team - Rank Among Defensemen

def calculate_percentile_rank(player_time_on_ice, player_position, player_team):
    # Assuming you have a DataFrame called `all_players` containing player data
    
    # Filter data based on player position and team
    filtered_data = all_players[(all_players["Skater"] == "D") & (all_players["Team"] == player_team)]
    
    # Extract time on ice values for the specific player position and team
    defense_time_on_ice = filtered_data["adj_toi"]
    percentile_rank = None
    
    if player_position == "F":
        percentile_rank = stats.percentileofscore(defense_time_on_ice, player_time_on_ice)
    elif player_position == "D":
        percentile_rank = stats.percentileofscore(defense_time_on_ice, player_time_on_ice)

    # Calculate the percentile rank
    return percentile_rank

all_players["QoTD"] = all_players.apply(lambda row: calculate_percentile_rank(row["adj_toi"], row["Skater"], row["Team"]), axis=1)
all_players.head()
# Out:
#              Player Team Position  GP      TOI   Age   atoi  total_percentile  \
# 0   Matthew Tkachuk  FLA        L  80  1491.20  26.0  18.64          0.800000
# 1        Zach Hyman  EDM        L  80  1560.03  32.0  19.50          0.850746
# 2  Carter Verhaeghe  FLA        C  76  1365.15  28.0  17.96          0.694030
# 3     Stefan Noesen  CAR        R  81   960.92  31.0  11.86          0.367164
# 4     Evan Bouchard  EDM        D  81  1862.77  24.0  23.00          0.968657
#
#   Skater  team_gp  team_TOI  team_atoi  adj_toi        QoTF        QoTD
# 0      F     80.0   1491.20      18.64  1491.20   93.333333   62.500000
# 1      F     80.0   1560.03      19.50  1560.00   80.000000   42.857143
# 2      F     76.0   1365.15      17.96  1364.96   80.000000   50.000000
# 3      F     81.0    960.92      11.86   960.66   33.333333   14.285714
# 4      D     81.0   1862.77      23.00  1863.00  100.000000  100.000000

# %%
all_players.query('Player == "Elias Lindholm"')
# Out:
#              Player Team Position  GP      TOI   Age   atoi  total_percentile  \
# 659  Elias Lindholm  CGY        C  75  1477.02  29.0  19.69          0.789552
# 660  Elias Lindholm  VAN        C  75  1477.02  29.0  19.69          0.789552
#
#     Skater  team_gp  team_TOI  team_atoi  adj_toi   QoTF       QoTD
# 659      F     49.0   1016.68      20.75  1556.25  93.75  72.727273
# 660      F     26.0    460.33      17.71  1328.25  80.00  42.857143

# %%
# Identify the specific name to keep - in future need to use name/age in case there are other players like this
name_to_keep = 'Sebastian Aho'

# Filter out the specific name from duplicates
duplicates_except_specific = all_players[all_players['Player'] != name_to_keep]

# Identify the duplicated player names
duplicated_names = duplicates_except_specific[duplicates_except_specific.duplicated(subset='Player')]['Player']

# Create a DataFrame of duplicated player names except for the specific name
result_df = all_players[all_players['Player'].isin(duplicated_names)]
result_df.head()
# Out:
#               Player Team Position  GP      TOI   Age   atoi  \
# 613    Tyler Toffoli  N.J     C, R  79  1339.85  32.0  16.96
# 614    Tyler Toffoli  WPG     C, R  79  1339.85  32.0  16.96
# 615    Jake Guentzel  PIT     C, L  67  1330.73  29.0  19.86
# 616    Jake Guentzel  CAR     C, L  67  1330.73  29.0  19.86
# 617  Andrei Kuzmenko  VAN        L  72  1071.67  28.0  14.88
#
#      total_percentile Skater  team_gp  team_TOI  team_atoi  adj_toi  \
# 613          0.670149      F     61.0   1069.63      17.53  1384.87
# 614          0.670149      F     18.0    270.22      15.01  1185.79
# 615          0.662687      F     50.0   1033.25      20.66  1384.22
# 616          0.662687      F     17.0    297.48      17.50  1172.50
# 617          0.450746      F     43.0    617.12      14.35  1033.20
#
#           QoTF       QoTD
# 613  86.666667  62.500000
# 614  50.000000  37.500000
# 615  81.250000  62.500000
# 616  53.333333  28.571429
# 617  53.333333  28.571429

# %%
#Test to make sure that Aho didn't get removed
result_df.query('Player == "Sebasitan Aho"')
# Out:
# Empty DataFrame
# Columns: [Player, Team, Position, GP, TOI, Age, atoi, total_percentile, Skater, team_gp, team_TOI, team_atoi, adj_toi, QoTF, QoTD]
# Index: []

# %%
result_df.query('Player == "Elias Lindholm"')
# Out:
#              Player Team Position  GP      TOI   Age   atoi  total_percentile  \
# 659  Elias Lindholm  CGY        C  75  1477.02  29.0  19.69          0.789552
# 660  Elias Lindholm  VAN        C  75  1477.02  29.0  19.69          0.789552
#
#     Skater  team_gp  team_TOI  team_atoi  adj_toi   QoTF       QoTD
# 659      F     49.0   1016.68      20.75  1556.25  93.75  72.727273
# 660      F     26.0    460.33      17.71  1328.25  80.00  42.857143

# %%
#Adding a column to identify the team that the player started with and then ended with
result_df['team_no'] = result_df.groupby('Player').cumcount()+1

result_df.head()
# Out:
# C:\Users\Karoline Sears\AppData\Local\Temp\ipykernel_12040\358628190.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df['team_no'] = result_df.groupby('Player').cumcount()+1
#               Player Team Position  GP      TOI   Age   atoi  \
# 613    Tyler Toffoli  N.J     C, R  79  1339.85  32.0  16.96
# 614    Tyler Toffoli  WPG     C, R  79  1339.85  32.0  16.96
# 615    Jake Guentzel  PIT     C, L  67  1330.73  29.0  19.86
# 616    Jake Guentzel  CAR     C, L  67  1330.73  29.0  19.86
# 617  Andrei Kuzmenko  VAN        L  72  1071.67  28.0  14.88
#
#      total_percentile Skater  team_gp  team_TOI  team_atoi  adj_toi  \
# 613          0.670149      F     61.0   1069.63      17.53  1384.87
# 614          0.670149      F     18.0    270.22      15.01  1185.79
# 615          0.662687      F     50.0   1033.25      20.66  1384.22
# 616          0.662687      F     17.0    297.48      17.50  1172.50
# 617          0.450746      F     43.0    617.12      14.35  1033.20
#
#           QoTF       QoTD  team_no
# 613  86.666667  62.500000        1
# 614  50.000000  37.500000        2
# 615  81.250000  62.500000        1
# 616  53.333333  28.571429        2
# 617  53.333333  28.571429        1

# %%
# Pivot the DataFrame to reshape it and include TOI
pivoted_df = result_df.pivot(index='Player', columns='team_no', values=['Team', 'adj_toi'])

# Rename columns to 'Team 1', 'Team 2', 'TOI Team 1', 'TOI Team 2', ...
pivoted_df.columns = [f'{col[0]} {col[1]}' for col in pivoted_df.columns]

# Reset index to make 'Player' a column again
pivoted_df.reset_index(inplace=True)

# %%
pivoted_df = pivoted_df.fillna(0)
pivoted_df.head()
# Out:
#             Player Team 1 Team 2 Team 3  adj_toi 1  adj_toi 2  adj_toi 3
# 0    Adam Henrique    ANA    EDM      0    1441.56    1216.06        0.0
# 1     Adam Ruzicka    CGY    ARI      0     426.72     348.18        0.0
# 2    Alex Wennberg    SEA    NYR      0    1486.78    1214.23        0.0
# 3  Andrei Kuzmenko    VAN    CGY      0    1033.20    1128.24        0.0
# 4     Andrew Peeke    CBJ    BOS      0     593.18     669.18        0.0

# %%
#append the multiple players to the all_players table
all_players = all_players.merge(pivoted_df, on="Player", how = "left")

all_players.head()
# Out:
#              Player Team Position  GP      TOI   Age   atoi  total_percentile  \
# 0   Matthew Tkachuk  FLA        L  80  1491.20  26.0  18.64          0.800000
# 1        Zach Hyman  EDM        L  80  1560.03  32.0  19.50          0.850746
# 2  Carter Verhaeghe  FLA        C  76  1365.15  28.0  17.96          0.694030
# 3     Stefan Noesen  CAR        R  81   960.92  31.0  11.86          0.367164
# 4     Evan Bouchard  EDM        D  81  1862.77  24.0  23.00          0.968657
#
#   Skater  team_gp  ...  team_atoi  adj_toi        QoTF        QoTD  Team 1  \
# 0      F     80.0  ...      18.64  1491.20   93.333333   62.500000     NaN
# 1      F     80.0  ...      19.50  1560.00   80.000000   42.857143     NaN
# 2      F     76.0  ...      17.96  1364.96   80.000000   50.000000     NaN
# 3      F     81.0  ...      11.86   960.66   33.333333   14.285714     NaN
# 4      D     81.0  ...      23.00  1863.00  100.000000  100.000000     NaN
#
#   Team 2 Team 3 adj_toi 1  adj_toi 2  adj_toi 3
# 0    NaN    NaN       NaN        NaN        NaN
# 1    NaN    NaN       NaN        NaN        NaN
# 2    NaN    NaN       NaN        NaN        NaN
# 3    NaN    NaN       NaN        NaN        NaN
# 4    NaN    NaN       NaN        NaN        NaN
#
# [5 rows x 21 columns]

# %%
all_players.query('Player == "Elias Lindholm"')
# Out:
#              Player Team Position  GP      TOI   Age   atoi  total_percentile  \
# 659  Elias Lindholm  CGY        C  75  1477.02  29.0  19.69          0.789552
# 660  Elias Lindholm  VAN        C  75  1477.02  29.0  19.69          0.789552
#
#     Skater  team_gp  ...  team_atoi  adj_toi   QoTF       QoTD  Team 1 Team 2  \
# 659      F     49.0  ...      20.75  1556.25  93.75  72.727273     CGY    VAN
# 660      F     26.0  ...      17.71  1328.25  80.00  42.857143     CGY    VAN
#
#     Team 3 adj_toi 1  adj_toi 2  adj_toi 3
# 659      0   1556.25    1328.25        0.0
# 660      0   1556.25    1328.25        0.0
#
# [2 rows x 21 columns]

# %%
#Quality of Competition, Forwards
def calculate_percentile_rank(player_row, player_position):
    # Filter data based on player position and exclude rows where player's team matches
    filtered_data = all_players[
        (all_players["Skater"] == "F") & 
        (all_players["Player"] != player_row["Player"]) & 
        (all_players["Team"] != player_row["Team"])
    ]
    
    # Group by player name and calculate mean TOI
    grouped_data = filtered_data.groupby("Player")["adj_toi"].mean()
    
    # Calculate percentile rank
    percentile_rank = stats.percentileofscore(grouped_data, player_row["adj_toi"])
    
    return percentile_rank

# Calculate the percentile ranks for each player
all_players["QoCF"] = all_players.apply(lambda row: calculate_percentile_rank(row, row["Skater"]), axis=1)
all_players.head()
# Out:
#              Player Team Position  GP      TOI   Age   atoi  total_percentile  \
# 0   Matthew Tkachuk  FLA        L  80  1491.20  26.0  18.64          0.800000
# 1        Zach Hyman  EDM        L  80  1560.03  32.0  19.50          0.850746
# 2  Carter Verhaeghe  FLA        C  76  1365.15  28.0  17.96          0.694030
# 3     Stefan Noesen  CAR        R  81   960.92  31.0  11.86          0.367164
# 4     Evan Bouchard  EDM        D  81  1862.77  24.0  23.00          0.968657
#
#   Skater  team_gp  ...  adj_toi        QoTF        QoTD  Team 1  Team 2  \
# 0      F     80.0  ...  1491.20   93.333333   62.500000     NaN     NaN
# 1      F     80.0  ...  1560.00   80.000000   42.857143     NaN     NaN
# 2      F     76.0  ...  1364.96   80.000000   50.000000     NaN     NaN
# 3      F     81.0  ...   960.66   33.333333   14.285714     NaN     NaN
# 4      D     81.0  ...  1863.00  100.000000  100.000000     NaN     NaN
#
#   Team 3 adj_toi 1 adj_toi 2  adj_toi 3       QoCF
# 0    NaN       NaN       NaN        NaN  87.234043
# 1    NaN       NaN       NaN        NaN  92.924528
# 2    NaN       NaN       NaN        NaN  77.068558
# 3    NaN       NaN       NaN        NaN  41.273585
# 4    NaN       NaN       NaN        NaN  99.764151
#
# [5 rows x 22 columns]

# %%
#Quality of Competition, Defense
def calculate_percentile_rank(player_row, player_position):
    # Filter data based on player position and exclude rows where player's team matches
    filtered_data = all_players[
        (all_players["Skater"] == "D") & 
        (all_players["Player"] != player_row["Player"]) & 
        (all_players["Team"] != player_row["Team"])
    ]
    
    # Group by player name and calculate mean TOI
    grouped_data = filtered_data.groupby("Player")["adj_toi"].mean()
    
    # Calculate percentile rank
    percentile_rank = stats.percentileofscore(grouped_data, player_row["adj_toi"])
    
    return percentile_rank

# Calculate the percentile ranks for each player
all_players["QoCD"] = all_players.apply(lambda row: calculate_percentile_rank(row, row["Skater"]), axis=1)
all_players.head()
# Out:
#              Player Team Position  GP      TOI   Age   atoi  total_percentile  \
# 0   Matthew Tkachuk  FLA        L  80  1491.20  26.0  18.64          0.800000
# 1        Zach Hyman  EDM        L  80  1560.03  32.0  19.50          0.850746
# 2  Carter Verhaeghe  FLA        C  76  1365.15  28.0  17.96          0.694030
# 3     Stefan Noesen  CAR        R  81   960.92  31.0  11.86          0.367164
# 4     Evan Bouchard  EDM        D  81  1862.77  24.0  23.00          0.968657
#
#   Skater  team_gp  ...        QoTF        QoTD  Team 1  Team 2  Team 3  \
# 0      F     80.0  ...   93.333333   62.500000     NaN     NaN     NaN
# 1      F     80.0  ...   80.000000   42.857143     NaN     NaN     NaN
# 2      F     76.0  ...   80.000000   50.000000     NaN     NaN     NaN
# 3      F     81.0  ...   33.333333   14.285714     NaN     NaN     NaN
# 4      D     81.0  ...  100.000000  100.000000     NaN     NaN     NaN
#
#   adj_toi 1 adj_toi 2 adj_toi 3       QoCF       QoCD
# 0       NaN       NaN       NaN  87.234043  66.519824
# 1       NaN       NaN       NaN  92.924528  72.368421
# 2       NaN       NaN       NaN  77.068558  56.387665
# 3       NaN       NaN       NaN  41.273585  29.955947
# 4       NaN       NaN       NaN  99.764151  91.228070
#
# [5 rows x 23 columns]

# %%
all_players['team_no'] = all_players.groupby('Player').cumcount()+1
all_players.head()
# Out:
#              Player Team Position  GP      TOI   Age   atoi  total_percentile  \
# 0   Matthew Tkachuk  FLA        L  80  1491.20  26.0  18.64          0.800000
# 1        Zach Hyman  EDM        L  80  1560.03  32.0  19.50          0.850746
# 2  Carter Verhaeghe  FLA        C  76  1365.15  28.0  17.96          0.694030
# 3     Stefan Noesen  CAR        R  81   960.92  31.0  11.86          0.367164
# 4     Evan Bouchard  EDM        D  81  1862.77  24.0  23.00          0.968657
#
#   Skater  team_gp  ...        QoTD  Team 1  Team 2  Team 3  adj_toi 1  \
# 0      F     80.0  ...   62.500000     NaN     NaN     NaN        NaN
# 1      F     80.0  ...   42.857143     NaN     NaN     NaN        NaN
# 2      F     76.0  ...   50.000000     NaN     NaN     NaN        NaN
# 3      F     81.0  ...   14.285714     NaN     NaN     NaN        NaN
# 4      D     81.0  ...  100.000000     NaN     NaN     NaN        NaN
#
#   adj_toi 2 adj_toi 3       QoCF       QoCD  team_no
# 0       NaN       NaN  87.234043  66.519824        1
# 1       NaN       NaN  92.924528  72.368421        1
# 2       NaN       NaN  77.068558  56.387665        1
# 3       NaN       NaN  41.273585  29.955947        1
# 4       NaN       NaN  99.764151  91.228070        1
#
# [5 rows x 24 columns]

# %%
all_players['team_count'] = np.where(pd.isnull(all_players['Team 1']), all_players['Team'], "Multi")
all_players.head()
# Out:
#              Player Team Position  GP      TOI   Age   atoi  total_percentile  \
# 0   Matthew Tkachuk  FLA        L  80  1491.20  26.0  18.64          0.800000
# 1        Zach Hyman  EDM        L  80  1560.03  32.0  19.50          0.850746
# 2  Carter Verhaeghe  FLA        C  76  1365.15  28.0  17.96          0.694030
# 3     Stefan Noesen  CAR        R  81   960.92  31.0  11.86          0.367164
# 4     Evan Bouchard  EDM        D  81  1862.77  24.0  23.00          0.968657
#
#   Skater  team_gp  ...  Team 1  Team 2  Team 3  adj_toi 1  adj_toi 2  \
# 0      F     80.0  ...     NaN     NaN     NaN        NaN        NaN
# 1      F     80.0  ...     NaN     NaN     NaN        NaN        NaN
# 2      F     76.0  ...     NaN     NaN     NaN        NaN        NaN
# 3      F     81.0  ...     NaN     NaN     NaN        NaN        NaN
# 4      D     81.0  ...     NaN     NaN     NaN        NaN        NaN
#
#   adj_toi 3       QoCF       QoCD  team_no  team_count
# 0       NaN  87.234043  66.519824        1         FLA
# 1       NaN  92.924528  72.368421        1         EDM
# 2       NaN  77.068558  56.387665        1         FLA
# 3       NaN  41.273585  29.955947        1         CAR
# 4       NaN  99.764151  91.228070        1         EDM
#
# [5 rows x 25 columns]

# %%
all_players.query('Player == "Elias Lindholm"')
# Out:
#              Player Team Position  GP      TOI   Age   atoi  total_percentile  \
# 659  Elias Lindholm  CGY        C  75  1477.02  29.0  19.69          0.789552
# 660  Elias Lindholm  VAN        C  75  1477.02  29.0  19.69          0.789552
#
#     Skater  team_gp  ...  Team 1  Team 2  Team 3  adj_toi 1  adj_toi 2  \
# 659      F     49.0  ...     CGY     VAN       0    1556.25    1328.25
# 660      F     26.0  ...     CGY     VAN       0    1556.25    1328.25
#
#     adj_toi 3       QoCF       QoCD  team_no  team_count
# 659       0.0  92.180095  71.739130        1       Multi
# 660       0.0  73.286052  53.947368        2       Multi
#
# [2 rows x 25 columns]

# %%
#pull out the multi team players again to pivot
mult_team_quals = all_players.query('team_count == "Multi"')
mult_team_quals.head()
# Out:
#               Player Team Position  GP      TOI   Age   atoi  \
# 613    Tyler Toffoli  N.J     C, R  79  1339.85  32.0  16.96
# 614    Tyler Toffoli  WPG     C, R  79  1339.85  32.0  16.96
# 615    Jake Guentzel  PIT     C, L  67  1330.73  29.0  19.86
# 616    Jake Guentzel  CAR     C, L  67  1330.73  29.0  19.86
# 617  Andrei Kuzmenko  VAN        L  72  1071.67  28.0  14.88
#
#      total_percentile Skater  team_gp  ...  Team 1  Team 2  Team 3  adj_toi 1  \
# 613          0.670149      F     61.0  ...     N.J     WPG       0    1384.87
# 614          0.670149      F     18.0  ...     N.J     WPG       0    1384.87
# 615          0.662687      F     50.0  ...     PIT     CAR       0    1384.22
# 616          0.662687      F     17.0  ...     PIT     CAR       0    1384.22
# 617          0.450746      F     43.0  ...     VAN     CGY       0    1033.20
#
#      adj_toi 2 adj_toi 3       QoCF       QoCD  team_no  team_count
# 613    1185.79       0.0  78.436019  57.456140        1       Multi
# 614    1185.79       0.0  59.810875  42.982456        2       Multi
# 615    1172.50       0.0  78.486998  57.268722        1       Multi
# 616    1172.50       0.0  58.865248  40.969163        2       Multi
# 617    1128.24       0.0  47.754137  33.771930        1       Multi
#
# [5 rows x 25 columns]

# %%
# #determine toi rate for time on team - based on atoi and skater position?
# mult_team_quals['team_ATOI'] = mult_team_quals['team_TOI']/mult_team_quals['team_gp']
# mult_team_quals

# %%
mult_team_quals.query('Player=="Elias Lindholm"')
# Out:
#              Player Team Position  GP      TOI   Age   atoi  total_percentile  \
# 659  Elias Lindholm  CGY        C  75  1477.02  29.0  19.69          0.789552
# 660  Elias Lindholm  VAN        C  75  1477.02  29.0  19.69          0.789552
#
#     Skater  team_gp  ...  Team 1  Team 2  Team 3  adj_toi 1  adj_toi 2  \
# 659      F     49.0  ...     CGY     VAN       0    1556.25    1328.25
# 660      F     26.0  ...     CGY     VAN       0    1556.25    1328.25
#
#     adj_toi 3       QoCF       QoCD  team_no  team_count
# 659       0.0  92.180095  71.739130        1       Multi
# 660       0.0  73.286052  53.947368        2       Multi
#
# [2 rows x 25 columns]

# %%
#pivot the multiple percentiles
mult_team_quals['team_no'] = mult_team_quals.groupby('Player').cumcount()+1

# Pivot the DataFrame to reshape it and include QoC
pivot_competition_f = mult_team_quals.pivot(index='Player', columns='team_no', values=['Team',  'adj_toi', 'QoCF', 'QoTF'])
pivot_competition_d =  mult_team_quals.pivot(index='Player', columns='team_no', values=['Team','adj_toi', 'QoCD','QoTD'])


# Rename columns to 'Team 1', 'Team 2', 'TOI Team 1', 'TOI Team 2', ...
pivot_competition_f.columns = [f'{col[0]} {col[1]}' for col in pivot_competition_f.columns]
pivot_competition_d.columns = [f'{col[0]} {col[1]}' for col in pivot_competition_d.columns]

# Reset index to make 'Player' a column again
pivot_competition_f.reset_index(inplace=True)
pivot_competition_d.reset_index(inplace=True)
# Out:
# C:\Users\Karoline Sears\AppData\Local\Temp\ipykernel_12040\3790111065.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mult_team_quals['team_no'] = mult_team_quals.groupby('Player').cumcount()+1

# %%
pivot_competition_f = pivot_competition_f.fillna(0)
pivot_competition_f.head()
# Out:
#             Player Team 1 Team 2 Team 3  adj_toi 1  adj_toi 2  adj_toi 3  \
# 0    Adam Henrique    ANA    EDM      0    1441.56    1216.06        0.0
# 1     Adam Ruzicka    CGY    ARI      0     426.72     348.18        0.0
# 2    Alex Wennberg    SEA    NYR      0    1486.78    1214.23        0.0
# 3  Andrei Kuzmenko    VAN    CGY      0    1033.20    1128.24        0.0
# 4     Andrew Peeke    CBJ    BOS      0     593.18     669.18        0.0
#
#       QoCF 1     QoCF 2  QoCF 3      QoTF 1     QoTF 2  QoTF 3
# 0  82.938389  62.411348     0.0   93.333333  66.666667     0.0
# 1   6.398104   3.782506     0.0   18.750000   7.142857     0.0
# 2  86.524823  62.085308     0.0  100.000000  66.666667     0.0
# 3  47.754137  54.739336     0.0   53.333333  56.250000     0.0
# 4  16.509434  20.616114     0.0    6.666667  33.333333     0.0

# %%
pivot_competition_d = pivot_competition_d.fillna(0)
pivot_competition_d = pivot_competition_d[['Player', 'QoCD 1', 'QoCD 2', 'QoCD 3', 'QoTD 1', 'QoTD 2', 'QoTD 3'  ]]
pivot_competition_d.head()
# Out:
#             Player     QoCD 1     QoCD 2  QoCD 3     QoTD 1     QoTD 2  QoTD 3
# 0    Adam Henrique  59.825328  46.052632     0.0  87.500000  14.285714     0.0
# 1     Adam Ruzicka   1.739130   0.000000     0.0  18.181818   0.000000     0.0
# 2    Alex Wennberg  65.638767  45.374449     0.0  71.428571  25.000000     0.0
# 3  Andrei Kuzmenko  33.771930  38.695652     0.0  28.571429  54.545455     0.0
# 4     Andrew Peeke   9.734513  13.333333     0.0  12.500000  22.222222     0.0

# %%
#Join the two together
weighted_df= pivot_competition_f.merge(pivot_competition_d, on="Player")
weighted_df.head()
# Out:
#             Player Team 1 Team 2 Team 3  adj_toi 1  adj_toi 2  adj_toi 3  \
# 0    Adam Henrique    ANA    EDM      0    1441.56    1216.06        0.0
# 1     Adam Ruzicka    CGY    ARI      0     426.72     348.18        0.0
# 2    Alex Wennberg    SEA    NYR      0    1486.78    1214.23        0.0
# 3  Andrei Kuzmenko    VAN    CGY      0    1033.20    1128.24        0.0
# 4     Andrew Peeke    CBJ    BOS      0     593.18     669.18        0.0
#
#       QoCF 1     QoCF 2  QoCF 3      QoTF 1     QoTF 2  QoTF 3     QoCD 1  \
# 0  82.938389  62.411348     0.0   93.333333  66.666667     0.0  59.825328
# 1   6.398104   3.782506     0.0   18.750000   7.142857     0.0   1.739130
# 2  86.524823  62.085308     0.0  100.000000  66.666667     0.0  65.638767
# 3  47.754137  54.739336     0.0   53.333333  56.250000     0.0  33.771930
# 4  16.509434  20.616114     0.0    6.666667  33.333333     0.0   9.734513
#
#       QoCD 2  QoCD 3     QoTD 1     QoTD 2  QoTD 3
# 0  46.052632     0.0  87.500000  14.285714     0.0
# 1   0.000000     0.0  18.181818   0.000000     0.0
# 2  45.374449     0.0  71.428571  25.000000     0.0
# 3  38.695652     0.0  28.571429  54.545455     0.0
# 4  13.333333     0.0  12.500000  22.222222     0.0

# %%
weighted_df.query('Player == "Elias Lindholm"')
# Out:
#             Player Team 1 Team 2 Team 3  adj_toi 1  adj_toi 2  adj_toi 3  \
# 20  Elias Lindholm    CGY    VAN      0    1556.25    1328.25        0.0
#
#        QoCF 1     QoCF 2  QoCF 3  QoTF 1  QoTF 2  QoTF 3    QoCD 1     QoCD 2  \
# 20  92.180095  73.286052     0.0   93.75    80.0     0.0  71.73913  53.947368
#
#     QoCD 3     QoTD 1     QoTD 2  QoTD 3
# 20     0.0  72.727273  42.857143     0.0

# %%
# #Weighted QoC = (QoC_Team1 * TOI_Team1 + QoC_Team2 * TOI_Team2 + ...) / Total_TOI
# weighted_df['w_QoCF'] = ((weighted_df['QoCF 1']*weighted_df['team_TOI 1'])+(weighted_df['QoCF 2']*weighted_df['team_TOI 2'])
#                          +(weighted_df['QoCF 3']*weighted_df['team_TOI 3']))/(weighted_df['team_TOI 1']+weighted_df['team_TOI 2']+weighted_df['team_TOI 3'])

# weighted_df['w_QoCD'] =  ((weighted_df['QoCD 1']*weighted_df['team_TOI 1'])+(weighted_df['QoCD 2']*weighted_df['team_TOI 2'])
#                          +(weighted_df['QoCD 3']*weighted_df['team_TOI 3']))/(weighted_df['team_TOI 1']+weighted_df['team_TOI 2']+weighted_df['team_TOI 3'])
# weighted_df['w_QoTF'] = ((weighted_df['QoTF 1']*weighted_df['team_TOI 1'])+(weighted_df['QoTF 2']*weighted_df['team_TOI 2'])
#                          +(weighted_df['QoTF 3']*weighted_df['team_TOI 3']))/(weighted_df['team_TOI 1']+weighted_df['team_TOI 2']+weighted_df['team_TOI 3'])
# weighted_df['w_QoTD'] =  ((weighted_df['QoTD 1']*weighted_df['team_TOI 1'])+(weighted_df['QoTD 2']*weighted_df['team_TOI 2'])
#                          +(weighted_df['QoTD 3']*weighted_df['team_TOI 3']))/(weighted_df['team_TOI 1']+weighted_df['team_TOI 2']+weighted_df['team_TOI 3'])

# weighted_df = weighted_df[['Player', 'QoCF', 'QoCD','QoTF', 'QoTD']]
# weighted_df.head()

# %%
all_players.head()
# Out:
#              Player Team Position  GP      TOI   Age   atoi  total_percentile  \
# 0   Matthew Tkachuk  FLA        L  80  1491.20  26.0  18.64          0.800000
# 1        Zach Hyman  EDM        L  80  1560.03  32.0  19.50          0.850746
# 2  Carter Verhaeghe  FLA        C  76  1365.15  28.0  17.96          0.694030
# 3     Stefan Noesen  CAR        R  81   960.92  31.0  11.86          0.367164
# 4     Evan Bouchard  EDM        D  81  1862.77  24.0  23.00          0.968657
#
#   Skater  team_gp  ...  Team 1  Team 2  Team 3  adj_toi 1  adj_toi 2  \
# 0      F     80.0  ...     NaN     NaN     NaN        NaN        NaN
# 1      F     80.0  ...     NaN     NaN     NaN        NaN        NaN
# 2      F     76.0  ...     NaN     NaN     NaN        NaN        NaN
# 3      F     81.0  ...     NaN     NaN     NaN        NaN        NaN
# 4      D     81.0  ...     NaN     NaN     NaN        NaN        NaN
#
#   adj_toi 3       QoCF       QoCD  team_no  team_count
# 0       NaN  87.234043  66.519824        1         FLA
# 1       NaN  92.924528  72.368421        1         EDM
# 2       NaN  77.068558  56.387665        1         FLA
# 3       NaN  41.273585  29.955947        1         CAR
# 4       NaN  99.764151  91.228070        1         EDM
#
# [5 rows x 25 columns]

# %%
# Identify the specific name to keep (the one with two different players)
name_to_keep = 'Sebastian Aho'

# Create a mask to keep the first occurrence of all player names except for the specific name
mask = all_players['Player'] != name_to_keep
filtered_players = all_players[mask].drop_duplicates(subset='Player', keep='first')

# Append the rows with the specific name to the filtered DataFrame
filtered_players = filtered_players.append(all_players[all_players['Player'] == name_to_keep])
filtered_players.head()
# Out:
# C:\Users\Karoline Sears\AppData\Local\Temp\ipykernel_12040\1040420341.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_players = filtered_players.append(all_players[all_players['Player'] == name_to_keep])
#              Player Team Position  GP      TOI   Age   atoi  total_percentile  \
# 0   Matthew Tkachuk  FLA        L  80  1491.20  26.0  18.64          0.800000
# 1        Zach Hyman  EDM        L  80  1560.03  32.0  19.50          0.850746
# 2  Carter Verhaeghe  FLA        C  76  1365.15  28.0  17.96          0.694030
# 3     Stefan Noesen  CAR        R  81   960.92  31.0  11.86          0.367164
# 4     Evan Bouchard  EDM        D  81  1862.77  24.0  23.00          0.968657
#
#   Skater  team_gp  ...  Team 1  Team 2  Team 3  adj_toi 1  adj_toi 2  \
# 0      F     80.0  ...     NaN     NaN     NaN        NaN        NaN
# 1      F     80.0  ...     NaN     NaN     NaN        NaN        NaN
# 2      F     76.0  ...     NaN     NaN     NaN        NaN        NaN
# 3      F     81.0  ...     NaN     NaN     NaN        NaN        NaN
# 4      D     81.0  ...     NaN     NaN     NaN        NaN        NaN
#
#   adj_toi 3       QoCF       QoCD  team_no  team_count
# 0       NaN  87.234043  66.519824        1         FLA
# 1       NaN  92.924528  72.368421        1         EDM
# 2       NaN  77.068558  56.387665        1         FLA
# 3       NaN  41.273585  29.955947        1         CAR
# 4       NaN  99.764151  91.228070        1         EDM
#
# [5 rows x 25 columns]

# %%
filtered_players.query('Player == "Sebastian Aho"')
# Out:
#             Player Team Position  GP      TOI   Age   atoi  total_percentile  \
# 27   Sebastian Aho  CAR        C  78  1530.95  26.0  19.63          0.834328
# 364  Sebastian Aho  NYI        D  58   950.70  28.0  16.39          0.353731
#
#     Skater  team_gp  ...  Team 1  Team 2  Team 3  adj_toi 1  adj_toi 2  \
# 27       F     78.0  ...     NaN     NaN     NaN        NaN        NaN
# 364      D     58.0  ...     NaN     NaN     NaN        NaN        NaN
#
#     adj_toi 3       QoCF       QoCD  team_no  team_count
# 27        NaN  91.037736  69.911504        1         CAR
# 364       NaN  39.904988  28.634361        2         NYI
#
# [2 rows x 25 columns]

# %%
filtered_players.query('Player == "Elias Lindholm"')
# Out:
#              Player Team Position  GP      TOI   Age   atoi  total_percentile  \
# 659  Elias Lindholm  CGY        C  75  1477.02  29.0  19.69          0.789552
#
#     Skater  team_gp  ...  Team 1  Team 2  Team 3  adj_toi 1  adj_toi 2  \
# 659      F     49.0  ...     CGY     VAN       0    1556.25    1328.25
#
#     adj_toi 3       QoCF      QoCD  team_no  team_count
# 659       0.0  92.180095  71.73913        1       Multi
#
# [1 rows x 25 columns]

# %%
# player_usage = filtered_players.merge(weighted_df, on="Player", how = "left")
player_usage = filtered_players

# %%
# #player_usage2 = player_usage
# player_usage['QoCF'] = np.where(pd.isnull(player_usage['w_QoCF']), player_usage['QoCF'], player_usage['w_QoCF'])
# player_usage['QoCD'] = np.where(pd.isnull(player_usage['w_QoCD']), player_usage['QoCD'], player_usage['w_QoCD'])
# player_usage['QoTF'] = np.where(pd.isnull(player_usage['w_QoTF']), player_usage['QoTF'], player_usage['w_QoTF'])
# player_usage['QoTD'] = np.where(pd.isnull(player_usage['w_QoTD']), player_usage['QoTD'], player_usage['w_QoTD'])
player_usage.head()
# Out:
#              Player Team Position  GP      TOI   Age   atoi  total_percentile  \
# 0   Matthew Tkachuk  FLA        L  80  1491.20  26.0  18.64          0.800000
# 1        Zach Hyman  EDM        L  80  1560.03  32.0  19.50          0.850746
# 2  Carter Verhaeghe  FLA        C  76  1365.15  28.0  17.96          0.694030
# 3     Stefan Noesen  CAR        R  81   960.92  31.0  11.86          0.367164
# 4     Evan Bouchard  EDM        D  81  1862.77  24.0  23.00          0.968657
#
#   Skater  team_gp  ...  Team 1  Team 2  Team 3  adj_toi 1  adj_toi 2  \
# 0      F     80.0  ...     NaN     NaN     NaN        NaN        NaN
# 1      F     80.0  ...     NaN     NaN     NaN        NaN        NaN
# 2      F     76.0  ...     NaN     NaN     NaN        NaN        NaN
# 3      F     81.0  ...     NaN     NaN     NaN        NaN        NaN
# 4      D     81.0  ...     NaN     NaN     NaN        NaN        NaN
#
#   adj_toi 3       QoCF       QoCD  team_no  team_count
# 0       NaN  87.234043  66.519824        1         FLA
# 1       NaN  92.924528  72.368421        1         EDM
# 2       NaN  77.068558  56.387665        1         FLA
# 3       NaN  41.273585  29.955947        1         CAR
# 4       NaN  99.764151  91.228070        1         EDM
#
# [5 rows x 25 columns]

# %%
player_usage.query('Player=="Elias Lindholm"')
# Out:
#              Player Team Position  GP      TOI   Age   atoi  total_percentile  \
# 659  Elias Lindholm  CGY        C  75  1477.02  29.0  19.69          0.789552
#
#     Skater  team_gp  ...  Team 1  Team 2  Team 3  adj_toi 1  adj_toi 2  \
# 659      F     49.0  ...     CGY     VAN       0    1556.25    1328.25
#
#     adj_toi 3       QoCF      QoCD  team_no  team_count
# 659       0.0  92.180095  71.73913        1       Multi
#
# [1 rows x 25 columns]

# %%
player_usage['total_percentile']= round(player_usage['total_percentile']*100,2)
# Specify the columns to round
columns_to_round = ['QoCF', 'QoCD', 'QoTF', 'QoTD' ]

# Round the specified columns to 2 decimal places
player_usage[columns_to_round] = player_usage[columns_to_round].apply(lambda x: round(x, 2))

player_usage.head()
# Out:
#              Player Team Position  GP      TOI   Age   atoi  total_percentile  \
# 0   Matthew Tkachuk  FLA        L  80  1491.20  26.0  18.64             80.00
# 1        Zach Hyman  EDM        L  80  1560.03  32.0  19.50             85.07
# 2  Carter Verhaeghe  FLA        C  76  1365.15  28.0  17.96             69.40
# 3     Stefan Noesen  CAR        R  81   960.92  31.0  11.86             36.72
# 4     Evan Bouchard  EDM        D  81  1862.77  24.0  23.00             96.87
#
#   Skater  team_gp  ...  Team 1  Team 2  Team 3  adj_toi 1  adj_toi 2  \
# 0      F     80.0  ...     NaN     NaN     NaN        NaN        NaN
# 1      F     80.0  ...     NaN     NaN     NaN        NaN        NaN
# 2      F     76.0  ...     NaN     NaN     NaN        NaN        NaN
# 3      F     81.0  ...     NaN     NaN     NaN        NaN        NaN
# 4      D     81.0  ...     NaN     NaN     NaN        NaN        NaN
#
#   adj_toi 3   QoCF   QoCD  team_no  team_count
# 0       NaN  87.23  66.52        1         FLA
# 1       NaN  92.92  72.37        1         EDM
# 2       NaN  77.07  56.39        1         FLA
# 3       NaN  41.27  29.96        1         CAR
# 4       NaN  99.76  91.23        1         EDM
#
# [5 rows x 25 columns]

# %%
#Toughest Minutes 
# tough_min = player_usage['QoCF']+player_usage['QoCD']+player_usage['QoTF']+player_usage['QoTD'] 
# w_tough_min = player_usage['w_QoCF']+player_usage['w_QoCD']+player_usage['w_QoTF']+player_usage['w_QoTD'] 

player_usage['toughest_min'] = player_usage['QoCF']+player_usage['QoCD']+player_usage['QoTF']+player_usage['QoTD'] 


player_usage = player_usage.sort_values(['toughest_min', 'TOI'], ascending=[False, False]).reset_index(drop=True)

player_usage.head()
# Out:
#           Player Team Position  GP      TOI   Age   atoi  total_percentile  \
# 0   John Carlson  WSH        D  82  2123.12  34.0  25.89            100.00
# 1   Drew Doughty  L.A        D  82  2115.07  34.0  25.79             99.85
# 2  Mike Matheson  MTL        D  82  2095.33  30.0  25.55             99.70
# 3  Rasmus Dahlin  BUF        D  81  2059.22  24.0  25.42             99.55
# 4    Brock Faber  MIN        D  82  2046.83  21.0  24.96             99.40
#
#   Skater  team_gp  ...  Team 2  Team 3  adj_toi 1  adj_toi 2  adj_toi 3  \
# 0      D     82.0  ...     NaN     NaN        NaN        NaN        NaN
# 1      D     82.0  ...     NaN     NaN        NaN        NaN        NaN
# 2      D     82.0  ...     NaN     NaN        NaN        NaN        NaN
# 3      D     81.0  ...     NaN     NaN        NaN        NaN        NaN
# 4      D     82.0  ...     NaN     NaN        NaN        NaN        NaN
#
#     QoCF    QoCD team_no  team_count  toughest_min
# 0  100.0  100.00       1         WSH        400.00
# 1  100.0   99.56       1         L.A        399.56
# 2  100.0   99.12       1         MTL        399.12
# 3  100.0   98.68       1         BUF        398.68
# 4  100.0   98.25       1         MIN        398.25
#
# [5 rows x 26 columns]

# %%
pd.set_option('display.max_columns',None)
player_usage.query('Player == "Elias Lindholm"')
# Out:
#              Player Team Position  GP      TOI   Age   atoi  total_percentile  \
# 107  Elias Lindholm  CGY        C  75  1477.02  29.0  19.69             78.96
#
#     Skater  team_gp  team_TOI  team_atoi  adj_toi   QoTF   QoTD Team 1 Team 2  \
# 107      F     49.0   1016.68      20.75  1556.25  93.75  72.73    CGY    VAN
#
#     Team 3  adj_toi 1  adj_toi 2  adj_toi 3   QoCF   QoCD  team_no team_count  \
# 107      0    1556.25    1328.25        0.0  92.18  71.74        1      Multi
#
#      toughest_min
# 107         330.4

# %%
player_usage['toughest_min'].median()
# Out:
# 200.40999999999997

# %%
player_usage['toughest_min'].mean()
# Out:
# 198.4055904334828

# %%
player_usage['toughest_min'].mode()
# Out:
# 0     58.82
# 1    100.50
# Name: toughest_min, dtype: float64

# %%
defense = player_usage.query('Skater == "D"')
defense['toughest_min'].mean()
# Out:
# 236.5650214592275

# %%
#the median toughest minutes
defense['toughest_min'].median()
# Out:
# 245.51

# %%
defense['toughest_min'].describe()
# Out:
# count    233.000000
# mean     236.565021
# std      118.981937
# min       24.990000
# 25%      134.110000
# 50%      245.510000
# 75%      349.960000
# max      400.000000
# Name: toughest_min, dtype: float64

# %%
defense
# Out:
#                Player Team Position  GP      TOI   Age   atoi  \
# 0        John Carlson  WSH        D  82  2123.12  34.0  25.89
# 1        Drew Doughty  L.A        D  82  2115.07  34.0  25.79
# 2       Mike Matheson  MTL        D  82  2095.33  30.0  25.55
# 3       Rasmus Dahlin  BUF        D  81  2059.22  24.0  25.42
# 4         Brock Faber  MIN        D  82  2046.83  21.0  24.96
# ..                ...  ...      ...  ..      ...   ...    ...
# 623       Josh Mahura  FLA        D  30   377.77  26.0  12.59
# 624     Nick DeSimone  CGY        D  34   458.35  29.0  13.48
# 628   Jacob MacDonald  S.J        D  34   408.73  31.0  12.02
# 630        Marc Staal  PHI        D  35   483.42  37.0  13.81
# 669  Gustav Lindström  NaN        D  46   708.40   NaN  15.40
#
#      total_percentile Skater  team_gp  team_TOI  team_atoi  adj_toi    QoTF  \
# 0              100.00      D     82.0   2123.12      25.89  2122.98  100.00
# 1               99.85      D     82.0   2115.07      25.79  2114.78  100.00
# 2               99.70      D     82.0   2095.33      25.55  2095.10  100.00
# 3               99.55      D     81.0   2059.22      25.42  2059.02  100.00
# 4               99.40      D     82.0   2046.83      24.96  2046.72  100.00
# ..                ...    ...      ...       ...        ...      ...     ...
# 623              3.28      D     30.0    377.77      12.59   377.70   13.33
# 624              6.87      D     23.0    276.97      12.04   409.36   12.50
# 628              4.78      D     34.0    408.73      12.02   408.68    6.67
# 630              7.76      D     35.0    483.42      13.81   483.35    0.00
# 669             20.75      D     46.0    708.40      15.40   708.40     NaN
#
#        QoTD Team 1 Team 2 Team 3  adj_toi 1  adj_toi 2  adj_toi 3    QoCF  \
# 0    100.00    NaN    NaN    NaN        NaN        NaN        NaN  100.00
# 1    100.00    NaN    NaN    NaN        NaN        NaN        NaN  100.00
# 2    100.00    NaN    NaN    NaN        NaN        NaN        NaN  100.00
# 3    100.00    NaN    NaN    NaN        NaN        NaN        NaN  100.00
# 4    100.00    NaN    NaN    NaN        NaN        NaN        NaN  100.00
# ..      ...    ...    ...    ...        ...        ...        ...     ...
# 623   12.50    NaN    NaN    NaN        NaN        NaN        NaN    4.26
# 624    9.09    CGY    N.J      0     409.36     560.66        0.0    6.38
# 628   11.11    NaN    NaN    NaN        NaN        NaN        NaN    6.60
# 630   11.11    NaN    NaN    NaN        NaN        NaN        NaN    9.93
# 669     NaN    NaN    NaN    NaN        NaN        NaN        NaN   22.71
#
#        QoCD  team_no team_count  toughest_min
# 0    100.00        1        WSH        400.00
# 1     99.56        1        L.A        399.56
# 2     99.12        1        MTL        399.12
# 3     98.68        1        BUF        398.68
# 4     98.25        1        MIN        398.25
# ..      ...      ...        ...           ...
# 623    0.00        1        FLA         30.09
# 624    1.75        1      Multi         29.72
# 628    1.32        1        S.J         25.70
# 630    3.95        1        PHI         24.99
# 669   17.17        1        NaN           NaN
#
# [234 rows x 26 columns]

# %%
forward = player_usage.query('Skater == "F"')
forward['toughest_min'].mean()
# Out:
# 178.0130504587156

# %%
forward['toughest_min'].median()
# Out:
# 175.37

# %%
#rankings among all players
def calculate_percentile_rank(all_rank):
    
    percentile_rank = stats.percentileofscore(player_usage["toughest_min"], all_rank)
    return percentile_rank

all_rank = 1447.75 # Replace with the player's actual time on ice

percentile_rank = calculate_percentile_rank(all_rank)
print(f"The player's percentile rank among all players is: {percentile_rank}")
# Out:
# The player's percentile rank among all players is: nan

# %%
#rankings within defensemen - should this be looking at actual TOI or the toughest min?
def calculate_percentile_rank(d_rank):
    
    percentile_rank = stats.percentileofscore(defense["toughest_min"], d_rank)
    return percentile_rank

d_rank = 294.61 # Replace with the player's actual time on ice?

percentile_rank = calculate_percentile_rank(d_rank)
print(f"The player's percentile rank among all players is: {percentile_rank}")
# Out:
# The player's percentile rank among all players is: nan

# %%
plt.hist(defense['toughest_min'])
# Out:
# (array([26., 15., 21., 17., 20., 20., 16., 22., 28., 48.]),
#  array([ 24.99 ,  62.491,  99.992, 137.493, 174.994, 212.495, 249.996,
#         287.497, 324.998, 362.499, 400.   ]),
#  <BarContainer object of 10 artists>)

# %%
#ranking within forwards toughest min
def calculate_percentile_rank(f_rank):
    
    percentile_rank = stats.percentileofscore(forward["toughest_min"], f_rank)
    return percentile_rank

f_rank =  1447.75 # Replace with the player's actual time on ice

percentile_rank = calculate_percentile_rank(f_rank)
print(f"The player's percentile rank among all players is: {percentile_rank}")
# Out:
# The player's percentile rank among all players is: 100.0

# %%
#Defensive Players
d_men = player_usage.query('Skater == "D"')
d_men = d_men[['Player', 'Team', 'QoCD','QoTD']]
d_men
# Out:
#                Player Team    QoCD    QoTD
# 0        John Carlson  WSH  100.00  100.00
# 1        Drew Doughty  L.A   99.56  100.00
# 2       Mike Matheson  MTL   99.12  100.00
# 3       Rasmus Dahlin  BUF   98.68  100.00
# 4         Brock Faber  MIN   98.25  100.00
# ..                ...  ...     ...     ...
# 623       Josh Mahura  FLA    0.00   12.50
# 624     Nick DeSimone  CGY    1.75    9.09
# 628   Jacob MacDonald  S.J    1.32   11.11
# 630        Marc Staal  PHI    3.95   11.11
# 669  Gustav Lindström  NaN   17.17     NaN
#
# [234 rows x 4 columns]

# %%
#Young forwards
forwards = player_usage.query('Skater == "F"')
young_forwards = forwards.query('Age <=25')
young_forwards = young_forwards[['Player', 'Team', 'Position', 'GP', 'Age', 'TOI', 'QoCF', 'QoTF', 'w_QoCF', 'w_QoTF', 'toughest_min']]
young_forwards['young_percentile'] = round((young_forwards['TOI'].rank(pct=True))*100, 2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[74], line 4
#       2 forwards = player_usage.query('Skater == "F"')
#       3 young_forwards = forwards.query('Age <=25')
# ----> 4 young_forwards = young_forwards[['Player', 'Team', 'Position', 'GP', 'Age', 'TOI', 'QoCF', 'QoTF', 'w_QoCF', 'w_QoTF', 'toughest_min']]
#       5 young_forwards['young_percentile'] = round((young_forwards['TOI'].rank(pct=True))*100, 2)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6133, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['w_QoCF', 'w_QoTF'] not in index"

# %%
result = d_men[d_men['QoCD']  < d_men['QoTD']]
result['diff'] = result['QoCD']-result['QoTD']
result.query('diff <= -25').sort_values(['diff'], ascending=[True])

# %%
#seesaw
seesaw = d_men.query('Player == "Nick Jensen" or Player == "Justin Holl" or Player == "David Savard"')
seesaw = seesaw[['Player','Team', 'QoCD', 'QoTD']]
seesaw

# %%
young_forwards.query('Player == "Alex DeBrincat"')

# %%
young_forwards['toughest_min'].mean()

# %%
forwards.query('Player == "Alex DeBrincat"')
pd.set_option('display.max_colwidth', None)

# %%
forwards.query('Player == "Alex DeBrincat"').describe()

# %% [markdown]
# Bruins Free Agents:
#
# 1. Jesper Boqvist (RFA)
# 2. Jake DeBrusk (UFA)
# 3. Danton Heinen (UFA)
# 4. Pat Maroon (UFA)
# 5. JVR (UFA)
# 6. Matt Grzelcyk (UFA)
# 7. Derek Forbort (UFA)
# 8. Kevin Shattenkirk (UFA)

# %%
boston_roster = player_usage.query('Team == "BOS"')
boston_roster
# Out:
#                  Player Team Position  GP      TOI   Age   atoi  \
# 18       Charlie McAvoy  BOS        D  74  1838.60  26.0  24.85
# 46      Hampus Lindholm  BOS        D  73  1699.92  30.0  23.29
# 71       David Pastrnak  BOS        R  82  1634.23  28.0  19.93
# 97        Brad Marchand  BOS        L  82  1566.35  36.0  19.10
# 118       Brandon Carlo  BOS        D  76  1512.65  27.0  19.90
# 149       Charlie Coyle  BOS        C  82  1481.45  32.0  18.07
# 183         Pavel Zacha  BOS        C  78  1412.27  27.0  18.11
# 210        Jake DeBrusk  BOS        L  80  1346.58  27.0  16.83
# 274       Morgan Geekie  BOS        C  76  1171.08  25.0  15.41
# 299      Trent Frederic  BOS        C  82  1127.98  26.0  13.76
# 310       Matt Grzelcyk  BOS        D  63  1108.65  30.0  17.60
# 344       Danton Heinen  BOS        L  74  1070.43  28.0  14.47
# 377   Kevin Shattenkirk  BOS        D  61   962.58  35.0  15.78
# 405  James van Riemsdyk  BOS        L  71   958.93  35.0  13.51
# 475  Parker Wotherspoon  BOS        D  41   726.63  26.0  17.72
# 496        Mason Lohrei  BOS        D  41   695.27  23.0  16.96
# 548       Derek Forbort  BOS        D  35   622.78  32.0  17.79
# 573         Jakub Lauko  BOS        C  60   589.25  24.0   9.82
# 587        John Beecher  BOS        C  52   552.43  23.0  10.62
# 610      Jesper Boqvist  BOS        C  47   524.05  25.0  11.15
# 633     Matthew Poitras  BOS        C  33   442.07  20.0  13.40
# 660         Oskar Steen  BOS        C  34   308.38  26.0   9.07
#
#      total_percentile Skater  team_gp  team_TOI  team_atoi  adj_toi    QoTF  \
# 18              96.12      D     74.0   1838.60      24.85  1838.90  100.00
# 46              92.24      D     73.0   1699.92      23.29  1700.17  100.00
# 71              89.55      F     82.0   1634.23      19.93  1634.26  100.00
# 97              85.22      F     82.0   1566.35      19.10  1566.20   93.33
# 118             82.24      D     76.0   1512.65      19.90  1512.40   86.67
# 149             79.25      F     82.0   1481.45      18.07  1481.74   86.67
# 183             72.54      F     78.0   1412.27      18.11  1412.58   80.00
# 210             67.91      F     80.0   1346.58      16.83  1346.40   73.33
# 274             52.24      F     76.0   1171.08      15.41  1171.16   66.67
# 299             48.96      F     82.0   1127.98      13.76  1128.32   60.00
# 310             47.76      D     63.0   1108.65      17.60  1108.80   53.33
# 344             44.78      F     74.0   1070.43      14.47  1070.78   53.33
# 377             37.01      D     61.0    962.58      15.78   962.58   46.67
# 405             36.27      F     71.0    958.93      13.51   959.21   46.67
# 475             21.94      D     41.0    726.63      17.72   726.52   33.33
# 496             19.85      D     41.0    695.27      16.96   695.36   33.33
# 548             15.37      D     35.0    622.78      17.79   622.65   33.33
# 573             13.73      F     60.0    589.25       9.82   589.20   33.33
# 587             11.49      F     52.0    552.43      10.62   552.24   26.67
# 610              9.10      F     47.0    524.05      11.15   524.05   20.00
# 633              5.97      F     33.0    442.07      13.40   442.20   13.33
# 660              1.34      F     34.0    308.38       9.07   308.38    6.67
#
#        QoTD Team 1 Team 2 Team 3  adj_toi 1  adj_toi 2  adj_toi 3   QoCF  \
# 18   100.00    NaN    NaN    NaN        NaN        NaN        NaN  99.76
# 46    88.89    NaN    NaN    NaN        NaN        NaN        NaN  98.58
# 71    77.78    NaN    NaN    NaN        NaN        NaN        NaN  97.16
# 97    77.78    NaN    NaN    NaN        NaN        NaN        NaN  92.65
# 118   77.78    NaN    NaN    NaN        NaN        NaN        NaN  90.05
# 149   66.67    NaN    NaN    NaN        NaN        NaN        NaN  86.73
# 183   66.67    NaN    NaN    NaN        NaN        NaN        NaN  80.81
# 210   66.67    NaN    NaN    NaN        NaN        NaN        NaN  75.83
# 274   66.67    NaN    NaN    NaN        NaN        NaN        NaN  58.29
# 299   66.67    NaN    NaN    NaN        NaN        NaN        NaN  54.98
# 310   66.67    NaN    NaN    NaN        NaN        NaN        NaN  52.84
# 344   55.56    NaN    NaN    NaN        NaN        NaN        NaN  50.47
# 377   55.56    NaN    NaN    NaN        NaN        NaN        NaN  41.23
# 405   44.44    NaN    NaN    NaN        NaN        NaN        NaN  40.28
# 475   44.44    NaN    NaN    NaN        NaN        NaN        NaN  23.46
# 496   33.33    NaN    NaN    NaN        NaN        NaN        NaN  21.80
# 548   11.11    NaN    NaN    NaN        NaN        NaN        NaN  17.30
# 573    0.00    NaN    NaN    NaN        NaN        NaN        NaN  15.17
# 587    0.00    NaN    NaN    NaN        NaN        NaN        NaN  13.51
# 610    0.00    NaN    NaN    NaN        NaN        NaN        NaN  10.90
# 633    0.00    NaN    NaN    NaN        NaN        NaN        NaN   7.82
# 660    0.00    NaN    NaN    NaN        NaN        NaN        NaN   1.90
#
#       QoCD  team_no team_count  toughest_min
# 18   88.94        1        BOS        388.70
# 46   80.09        1        BOS        367.56
# 71   75.22        1        BOS        350.16
# 97   71.24        1        BOS        335.00
# 118  67.26        1        BOS        321.76
# 149  65.93        1        BOS        306.00
# 183  57.96        1        BOS        285.44
# 210  53.54        1        BOS        269.37
# 274  39.82        1        BOS        231.45
# 299  38.05        1        BOS        219.70
# 310  38.05        1        BOS        210.89
# 344  35.40        1        BOS        194.76
# 377  29.20        1        BOS        172.66
# 405  29.20        1        BOS        160.59
# 475  17.26        1        BOS        118.49
# 496  15.49        1        BOS        103.95
# 548  11.50        1        BOS         73.24
# 573   9.29        1        BOS         57.79
# 587   6.64        1        BOS         46.82
# 610   5.31        1        BOS         36.21
# 633   2.65        1        BOS         23.80
# 660   0.00        1        BOS          8.57

# %%
free_agents = boston_roster.query('Player == "Jesper Boqvist"or Player == "Jake DeBrusk" or Player == "Danton Heinen" or Player == "Matt Grzelcyk"')
free_agents
# Out:
#              Player Team Position  GP      TOI   Age   atoi  total_percentile  \
# 210    Jake DeBrusk  BOS        L  80  1346.58  27.0  16.83             67.91
# 310   Matt Grzelcyk  BOS        D  63  1108.65  30.0  17.60             47.76
# 344   Danton Heinen  BOS        L  74  1070.43  28.0  14.47             44.78
# 610  Jesper Boqvist  BOS        C  47   524.05  25.0  11.15              9.10
#
#     Skater  team_gp  team_TOI  team_atoi  adj_toi   QoTF   QoTD Team 1 Team 2  \
# 210      F     80.0   1346.58      16.83  1346.40  73.33  66.67    NaN    NaN
# 310      D     63.0   1108.65      17.60  1108.80  53.33  66.67    NaN    NaN
# 344      F     74.0   1070.43      14.47  1070.78  53.33  55.56    NaN    NaN
# 610      F     47.0    524.05      11.15   524.05  20.00   0.00    NaN    NaN
#
#     Team 3  adj_toi 1  adj_toi 2  adj_toi 3   QoCF   QoCD  team_no team_count  \
# 210    NaN        NaN        NaN        NaN  75.83  53.54        1        BOS
# 310    NaN        NaN        NaN        NaN  52.84  38.05        1        BOS
# 344    NaN        NaN        NaN        NaN  50.47  35.40        1        BOS
# 610    NaN        NaN        NaN        NaN  10.90   5.31        1        BOS
#
#      toughest_min
# 210        269.37
# 310        210.89
# 344        194.76
# 610         36.21

# %%
free_agents
# Out:
#              Player Team Position  GP      TOI   Age   atoi  total_percentile  \
# 210    Jake DeBrusk  BOS        L  80  1346.58  27.0  16.83             67.91
# 310   Matt Grzelcyk  BOS        D  63  1108.65  30.0  17.60             47.76
# 344   Danton Heinen  BOS        L  74  1070.43  28.0  14.47             44.78
# 610  Jesper Boqvist  BOS        C  47   524.05  25.0  11.15              9.10
#
#     Skater  team_gp  team_TOI  team_atoi  adj_toi   QoTF   QoTD Team 1 Team 2  \
# 210      F     80.0   1346.58      16.83  1346.40  73.33  66.67    NaN    NaN
# 310      D     63.0   1108.65      17.60  1108.80  53.33  66.67    NaN    NaN
# 344      F     74.0   1070.43      14.47  1070.78  53.33  55.56    NaN    NaN
# 610      F     47.0    524.05      11.15   524.05  20.00   0.00    NaN    NaN
#
#     Team 3  adj_toi 1  adj_toi 2  adj_toi 3   QoCF   QoCD  team_no team_count  \
# 210    NaN        NaN        NaN        NaN  75.83  53.54        1        BOS
# 310    NaN        NaN        NaN        NaN  52.84  38.05        1        BOS
# 344    NaN        NaN        NaN        NaN  50.47  35.40        1        BOS
# 610    NaN        NaN        NaN        NaN  10.90   5.31        1        BOS
#
#      toughest_min
# 210        269.37
# 310        210.89
# 344        194.76
# 610         36.21

# %%
#create a data set of other stats
performance = all_players
performance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 727 entries, 0 to 726
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Player            727 non-null    object
#  1   Team              726 non-null    object
#  2   Position          727 non-null    object
#  3   GP                727 non-null    int64
#  4   TOI               727 non-null    float64
#  5   Age               726 non-null    float64
#  6   atoi              727 non-null    float64
#  7   total_percentile  727 non-null    float64
#  8   Skater            727 non-null    object
#  9   team_gp           727 non-null    float64
#  10  team_TOI          727 non-null    float64
#  11  team_atoi         727 non-null    float64
#  12  adj_toi           727 non-null    float64
#  13  QoTF              726 non-null    float64
#  14  QoTD              726 non-null    float64
#  15  Team 1            113 non-null    object
#  16  Team 2            113 non-null    object
#  17  Team 3            113 non-null    object
#  18  adj_toi 1         113 non-null    float64
#  19  adj_toi 2         113 non-null    float64
#  20  adj_toi 3         113 non-null    float64
#  21  QoCF              727 non-null    float64
#  22  QoCD              727 non-null    float64
#  23  team_no           727 non-null    int64
#  24  team_count        726 non-null    object
# dtypes: float64(15), int64(2), object(8)
# memory usage: 147.7+ KB

# %%
# performance= performance[['Player', 'Position','Goals',
#        'Total Assists', 'First Assists', 'Second Assists', 'Total Points',
#        'IPP', 'Shots', 'SH%', 'ixG', 'iCF', 'iFF', 'iSCF', 'iHDCF',
#        'Rush Attempts', 'Rebounds Created', 'PIM', 'Total Penalties', 'Minor',
#        'Major', 'Misconduct', 'Penalties Drawn', 'Giveaways', 'Takeaways',
#        'Hits', 'Hits Taken', 'Shots Blocked', 'Faceoffs Won', 'Faceoffs Lost',
#        'Faceoffs %']]
# performance.head()

performance = performance.merge(all_toi, on= ('Player', 'Position'), how = 'left' )
performance.head()
# Out:
#              Player Team_x Position  GP_x    TOI_x  Age_x  atoi_x  \
# 0   Matthew Tkachuk    FLA        L    80  1491.20   26.0   18.64
# 1        Zach Hyman    EDM        L    80  1560.03   32.0   19.50
# 2  Carter Verhaeghe    FLA        C    76  1365.15   28.0   17.96
# 3     Stefan Noesen    CAR        R    81   960.92   31.0   11.86
# 4     Evan Bouchard    EDM        D    81  1862.77   24.0   23.00
#
#    total_percentile_x Skater_x  team_gp  team_TOI  team_atoi  adj_toi  \
# 0            0.800000        F     80.0   1491.20      18.64  1491.20
# 1            0.850746        F     80.0   1560.03      19.50  1560.00
# 2            0.694030        F     76.0   1365.15      17.96  1364.96
# 3            0.367164        F     81.0    960.92      11.86   960.66
# 4            0.968657        D     81.0   1862.77      23.00  1863.00
#
#          QoTF        QoTD Team 1 Team 2 Team 3  adj_toi 1  adj_toi 2  \
# 0   93.333333   62.500000    NaN    NaN    NaN        NaN        NaN
# 1   80.000000   42.857143    NaN    NaN    NaN        NaN        NaN
# 2   80.000000   50.000000    NaN    NaN    NaN        NaN        NaN
# 3   33.333333   14.285714    NaN    NaN    NaN        NaN        NaN
# 4  100.000000  100.000000    NaN    NaN    NaN        NaN        NaN
#
#    adj_toi 3       QoCF       QoCD  team_no team_count Team_y  GP_y    TOI_y  \
# 0        NaN  87.234043  66.519824        1        FLA    FLA    80  1491.20
# 1        NaN  92.924528  72.368421        1        EDM    EDM    80  1560.03
# 2        NaN  77.068558  56.387665        1        FLA    FLA    76  1365.15
# 3        NaN  41.273585  29.955947        1        CAR    CAR    81   960.92
# 4        NaN  99.764151  91.228070        1        EDM    EDM    81  1862.77
#
#    Age_y  atoi_y  total_percentile_y Skater_y
# 0   26.0   18.64            0.800000        F
# 1   32.0   19.50            0.850746        F
# 2   28.0   17.96            0.694030        F
# 3   31.0   11.86            0.367164        F
# 4   24.0   23.00            0.968657        D

# %%
young_free_agents = free_agents[['QoCF', 'QoCD', 'QoTF', 'QoTD']]
young_free_agents
# Out:
#       QoCF   QoCD   QoTF   QoTD
# 210  75.83  53.54  73.33  66.67
# 310  52.84  38.05  53.33  66.67
# 344  50.47  35.40  53.33  55.56
# 610  10.90   5.31  20.00   0.00

# %%
boston_roster['QoCF'] = pd.to_numeric(boston_roster['QoCF'])  # Convert 'QoCF' column to numeric type
boston_roster.set_index('Player', inplace=True)
boston_roster = boston_roster.sort_values(['QoCF', 'TOI'], ascending=[False, False])
boston_roster
# Out:
# C:\Users\Karoline Sears\AppData\Local\Temp\ipykernel_12040\4287085920.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boston_roster['QoCF'] = pd.to_numeric(boston_roster['QoCF'])  # Convert 'QoCF' column to numeric type
#                    Team Position  GP      TOI   Age   atoi  total_percentile  \
# Player
# Charlie McAvoy      BOS        D  74  1838.60  26.0  24.85             96.12
# Hampus Lindholm     BOS        D  73  1699.92  30.0  23.29             92.24
# David Pastrnak      BOS        R  82  1634.23  28.0  19.93             89.55
# Brad Marchand       BOS        L  82  1566.35  36.0  19.10             85.22
# Brandon Carlo       BOS        D  76  1512.65  27.0  19.90             82.24
# Charlie Coyle       BOS        C  82  1481.45  32.0  18.07             79.25
# Pavel Zacha         BOS        C  78  1412.27  27.0  18.11             72.54
# Jake DeBrusk        BOS        L  80  1346.58  27.0  16.83             67.91
# Morgan Geekie       BOS        C  76  1171.08  25.0  15.41             52.24
# Trent Frederic      BOS        C  82  1127.98  26.0  13.76             48.96
# Matt Grzelcyk       BOS        D  63  1108.65  30.0  17.60             47.76
# Danton Heinen       BOS        L  74  1070.43  28.0  14.47             44.78
# Kevin Shattenkirk   BOS        D  61   962.58  35.0  15.78             37.01
# James van Riemsdyk  BOS        L  71   958.93  35.0  13.51             36.27
# Parker Wotherspoon  BOS        D  41   726.63  26.0  17.72             21.94
# Mason Lohrei        BOS        D  41   695.27  23.0  16.96             19.85
# Derek Forbort       BOS        D  35   622.78  32.0  17.79             15.37
# Jakub Lauko         BOS        C  60   589.25  24.0   9.82             13.73
# John Beecher        BOS        C  52   552.43  23.0  10.62             11.49
# Jesper Boqvist      BOS        C  47   524.05  25.0  11.15              9.10
# Matthew Poitras     BOS        C  33   442.07  20.0  13.40              5.97
# Oskar Steen         BOS        C  34   308.38  26.0   9.07              1.34
#
#                    Skater  team_gp  team_TOI  team_atoi  adj_toi    QoTF  \
# Player
# Charlie McAvoy          D     74.0   1838.60      24.85  1838.90  100.00
# Hampus Lindholm         D     73.0   1699.92      23.29  1700.17  100.00
# David Pastrnak          F     82.0   1634.23      19.93  1634.26  100.00
# Brad Marchand           F     82.0   1566.35      19.10  1566.20   93.33
# Brandon Carlo           D     76.0   1512.65      19.90  1512.40   86.67
# Charlie Coyle           F     82.0   1481.45      18.07  1481.74   86.67
# Pavel Zacha             F     78.0   1412.27      18.11  1412.58   80.00
# Jake DeBrusk            F     80.0   1346.58      16.83  1346.40   73.33
# Morgan Geekie           F     76.0   1171.08      15.41  1171.16   66.67
# Trent Frederic          F     82.0   1127.98      13.76  1128.32   60.00
# Matt Grzelcyk           D     63.0   1108.65      17.60  1108.80   53.33
# Danton Heinen           F     74.0   1070.43      14.47  1070.78   53.33
# Kevin Shattenkirk       D     61.0    962.58      15.78   962.58   46.67
# James van Riemsdyk      F     71.0    958.93      13.51   959.21   46.67
# Parker Wotherspoon      D     41.0    726.63      17.72   726.52   33.33
# Mason Lohrei            D     41.0    695.27      16.96   695.36   33.33
# Derek Forbort           D     35.0    622.78      17.79   622.65   33.33
# Jakub Lauko             F     60.0    589.25       9.82   589.20   33.33
# John Beecher            F     52.0    552.43      10.62   552.24   26.67
# Jesper Boqvist          F     47.0    524.05      11.15   524.05   20.00
# Matthew Poitras         F     33.0    442.07      13.40   442.20   13.33
# Oskar Steen             F     34.0    308.38       9.07   308.38    6.67
#
#                       QoTD Team 1 Team 2 Team 3  adj_toi 1  adj_toi 2  \
# Player
# Charlie McAvoy      100.00    NaN    NaN    NaN        NaN        NaN
# Hampus Lindholm      88.89    NaN    NaN    NaN        NaN        NaN
# David Pastrnak       77.78    NaN    NaN    NaN        NaN        NaN
# Brad Marchand        77.78    NaN    NaN    NaN        NaN        NaN
# Brandon Carlo        77.78    NaN    NaN    NaN        NaN        NaN
# Charlie Coyle        66.67    NaN    NaN    NaN        NaN        NaN
# Pavel Zacha          66.67    NaN    NaN    NaN        NaN        NaN
# Jake DeBrusk         66.67    NaN    NaN    NaN        NaN        NaN
# Morgan Geekie        66.67    NaN    NaN    NaN        NaN        NaN
# Trent Frederic       66.67    NaN    NaN    NaN        NaN        NaN
# Matt Grzelcyk        66.67    NaN    NaN    NaN        NaN        NaN
# Danton Heinen        55.56    NaN    NaN    NaN        NaN        NaN
# Kevin Shattenkirk    55.56    NaN    NaN    NaN        NaN        NaN
# James van Riemsdyk   44.44    NaN    NaN    NaN        NaN        NaN
# Parker Wotherspoon   44.44    NaN    NaN    NaN        NaN        NaN
# Mason Lohrei         33.33    NaN    NaN    NaN        NaN        NaN
# Derek Forbort        11.11    NaN    NaN    NaN        NaN        NaN
# Jakub Lauko           0.00    NaN    NaN    NaN        NaN        NaN
# John Beecher          0.00    NaN    NaN    NaN        NaN        NaN
# Jesper Boqvist        0.00    NaN    NaN    NaN        NaN        NaN
# Matthew Poitras       0.00    NaN    NaN    NaN        NaN        NaN
# Oskar Steen           0.00    NaN    NaN    NaN        NaN        NaN
#
#                     adj_toi 3   QoCF   QoCD  team_no team_count  toughest_min
# Player
# Charlie McAvoy            NaN  99.76  88.94        1        BOS        388.70
# Hampus Lindholm           NaN  98.58  80.09        1        BOS        367.56
# David Pastrnak            NaN  97.16  75.22        1        BOS        350.16
# Brad Marchand             NaN  92.65  71.24        1        BOS        335.00
# Brandon Carlo             NaN  90.05  67.26        1        BOS        321.76
# Charlie Coyle             NaN  86.73  65.93        1        BOS        306.00
# Pavel Zacha               NaN  80.81  57.96        1        BOS        285.44
# Jake DeBrusk              NaN  75.83  53.54        1        BOS        269.37
# Morgan Geekie             NaN  58.29  39.82        1        BOS        231.45
# Trent Frederic            NaN  54.98  38.05        1        BOS        219.70
# Matt Grzelcyk             NaN  52.84  38.05        1        BOS        210.89
# Danton Heinen             NaN  50.47  35.40        1        BOS        194.76
# Kevin Shattenkirk         NaN  41.23  29.20        1        BOS        172.66
# James van Riemsdyk        NaN  40.28  29.20        1        BOS        160.59
# Parker Wotherspoon        NaN  23.46  17.26        1        BOS        118.49
# Mason Lohrei              NaN  21.80  15.49        1        BOS        103.95
# Derek Forbort             NaN  17.30  11.50        1        BOS         73.24
# Jakub Lauko               NaN  15.17   9.29        1        BOS         57.79
# John Beecher              NaN  13.51   6.64        1        BOS         46.82
# Jesper Boqvist            NaN  10.90   5.31        1        BOS         36.21
# Matthew Poitras           NaN   7.82   2.65        1        BOS         23.80
# Oskar Steen               NaN   1.90   0.00        1        BOS          8.57

# %%
# Create the heatmap table
boston_map = boston_roster[['QoCF', 'QoCD', 'QoTF', 'QoTD']]
sb.heatmap(boston_map, annot=True, cmap='YlGnBu', fmt='.0f', cbar=True)
plt.tick_params(axis='x', labelrotation=0, labeltop=True, labelbottom=False)
plt.tick_params(axis='y', labelrotation=360)
# Add labels and title
plt.xlabel('')
plt.ylabel('')
plt.title('Player Usage')

# Display the plot
plt.show()

# %%
boston = boston_roster
boston['QoCF'] = pd.to_numeric(boston['QoCF'])  # Convert 'QoCF' column to numeric type
# boston.set_index('Player', inplace=True)
boston = boston.sort_values(['QoCF', 'TOI'], ascending=[False, False])
boston
# Out:
# C:\Users\Karoline Sears\AppData\Local\Temp\ipykernel_12040\1704624828.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boston['QoCF'] = pd.to_numeric(boston['QoCF'])  # Convert 'QoCF' column to numeric type
#                  Player Team Position  GP      TOI   Age   atoi  \
# 18       Charlie McAvoy  BOS        D  74  1838.60  26.0  24.85
# 46      Hampus Lindholm  BOS        D  73  1699.92  30.0  23.29
# 71       David Pastrnak  BOS        R  82  1634.23  28.0  19.93
# 97        Brad Marchand  BOS        L  82  1566.35  36.0  19.10
# 118       Brandon Carlo  BOS        D  76  1512.65  27.0  19.90
# 149       Charlie Coyle  BOS        C  82  1481.45  32.0  18.07
# 183         Pavel Zacha  BOS        C  78  1412.27  27.0  18.11
# 210        Jake DeBrusk  BOS        L  80  1346.58  27.0  16.83
# 274       Morgan Geekie  BOS        C  76  1171.08  25.0  15.41
# 299      Trent Frederic  BOS        C  82  1127.98  26.0  13.76
# 310       Matt Grzelcyk  BOS        D  63  1108.65  30.0  17.60
# 344       Danton Heinen  BOS        L  74  1070.43  28.0  14.47
# 377   Kevin Shattenkirk  BOS        D  61   962.58  35.0  15.78
# 405  James van Riemsdyk  BOS        L  71   958.93  35.0  13.51
# 475  Parker Wotherspoon  BOS        D  41   726.63  26.0  17.72
# 496        Mason Lohrei  BOS        D  41   695.27  23.0  16.96
# 548       Derek Forbort  BOS        D  35   622.78  32.0  17.79
# 573         Jakub Lauko  BOS        C  60   589.25  24.0   9.82
# 587        John Beecher  BOS        C  52   552.43  23.0  10.62
# 610      Jesper Boqvist  BOS        C  47   524.05  25.0  11.15
# 633     Matthew Poitras  BOS        C  33   442.07  20.0  13.40
# 660         Oskar Steen  BOS        C  34   308.38  26.0   9.07
#
#      total_percentile Skater  team_gp  team_TOI  team_atoi  adj_toi    QoTF  \
# 18              96.12      D     74.0   1838.60      24.85  1838.90  100.00
# 46              92.24      D     73.0   1699.92      23.29  1700.17  100.00
# 71              89.55      F     82.0   1634.23      19.93  1634.26  100.00
# 97              85.22      F     82.0   1566.35      19.10  1566.20   93.33
# 118             82.24      D     76.0   1512.65      19.90  1512.40   86.67
# 149             79.25      F     82.0   1481.45      18.07  1481.74   86.67
# 183             72.54      F     78.0   1412.27      18.11  1412.58   80.00
# 210             67.91      F     80.0   1346.58      16.83  1346.40   73.33
# 274             52.24      F     76.0   1171.08      15.41  1171.16   66.67
# 299             48.96      F     82.0   1127.98      13.76  1128.32   60.00
# 310             47.76      D     63.0   1108.65      17.60  1108.80   53.33
# 344             44.78      F     74.0   1070.43      14.47  1070.78   53.33
# 377             37.01      D     61.0    962.58      15.78   962.58   46.67
# 405             36.27      F     71.0    958.93      13.51   959.21   46.67
# 475             21.94      D     41.0    726.63      17.72   726.52   33.33
# 496             19.85      D     41.0    695.27      16.96   695.36   33.33
# 548             15.37      D     35.0    622.78      17.79   622.65   33.33
# 573             13.73      F     60.0    589.25       9.82   589.20   33.33
# 587             11.49      F     52.0    552.43      10.62   552.24   26.67
# 610              9.10      F     47.0    524.05      11.15   524.05   20.00
# 633              5.97      F     33.0    442.07      13.40   442.20   13.33
# 660              1.34      F     34.0    308.38       9.07   308.38    6.67
#
#        QoTD Team 1 Team 2 Team 3  adj_toi 1  adj_toi 2  adj_toi 3   QoCF  \
# 18   100.00    NaN    NaN    NaN        NaN        NaN        NaN  99.76
# 46    88.89    NaN    NaN    NaN        NaN        NaN        NaN  98.58
# 71    77.78    NaN    NaN    NaN        NaN        NaN        NaN  97.16
# 97    77.78    NaN    NaN    NaN        NaN        NaN        NaN  92.65
# 118   77.78    NaN    NaN    NaN        NaN        NaN        NaN  90.05
# 149   66.67    NaN    NaN    NaN        NaN        NaN        NaN  86.73
# 183   66.67    NaN    NaN    NaN        NaN        NaN        NaN  80.81
# 210   66.67    NaN    NaN    NaN        NaN        NaN        NaN  75.83
# 274   66.67    NaN    NaN    NaN        NaN        NaN        NaN  58.29
# 299   66.67    NaN    NaN    NaN        NaN        NaN        NaN  54.98
# 310   66.67    NaN    NaN    NaN        NaN        NaN        NaN  52.84
# 344   55.56    NaN    NaN    NaN        NaN        NaN        NaN  50.47
# 377   55.56    NaN    NaN    NaN        NaN        NaN        NaN  41.23
# 405   44.44    NaN    NaN    NaN        NaN        NaN        NaN  40.28
# 475   44.44    NaN    NaN    NaN        NaN        NaN        NaN  23.46
# 496   33.33    NaN    NaN    NaN        NaN        NaN        NaN  21.80
# 548   11.11    NaN    NaN    NaN        NaN        NaN        NaN  17.30
# 573    0.00    NaN    NaN    NaN        NaN        NaN        NaN  15.17
# 587    0.00    NaN    NaN    NaN        NaN        NaN        NaN  13.51
# 610    0.00    NaN    NaN    NaN        NaN        NaN        NaN  10.90
# 633    0.00    NaN    NaN    NaN        NaN        NaN        NaN   7.82
# 660    0.00    NaN    NaN    NaN        NaN        NaN        NaN   1.90
#
#       QoCD  team_no team_count  toughest_min
# 18   88.94        1        BOS        388.70
# 46   80.09        1        BOS        367.56
# 71   75.22        1        BOS        350.16
# 97   71.24        1        BOS        335.00
# 118  67.26        1        BOS        321.76
# 149  65.93        1        BOS        306.00
# 183  57.96        1        BOS        285.44
# 210  53.54        1        BOS        269.37
# 274  39.82        1        BOS        231.45
# 299  38.05        1        BOS        219.70
# 310  38.05        1        BOS        210.89
# 344  35.40        1        BOS        194.76
# 377  29.20        1        BOS        172.66
# 405  29.20        1        BOS        160.59
# 475  17.26        1        BOS        118.49
# 496  15.49        1        BOS        103.95
# 548  11.50        1        BOS         73.24
# 573   9.29        1        BOS         57.79
# 587   6.64        1        BOS         46.82
# 610   5.31        1        BOS         36.21
# 633   2.65        1        BOS         23.80
# 660   0.00        1        BOS          8.57

# %%
# Create the heatmap table
boston = boston[['QoCF', 'QoCD', 'QoTF', 'QoTD']]
sb.heatmap(boston, annot=True, cmap='YlGnBu', fmt='.0f', cbar=True)
plt.tick_params(axis='x', labelrotation=0, labeltop=True, labelbottom=False)
plt.tick_params(axis='y', labelrotation=360)
# Add labels and title
plt.xlabel('')
plt.ylabel('')
plt.title('Player Usage')

# Display the plot
plt.show()

# %%
boston_roster_1=boston_roster[[ 'toughest_min']]
boston_roster_1
# Out:
#                     toughest_min
# Player
# Charlie McAvoy            388.70
# Hampus Lindholm           367.56
# David Pastrnak            350.16
# Brad Marchand             335.00
# Brandon Carlo             321.76
# Charlie Coyle             306.00
# Pavel Zacha               285.44
# Jake DeBrusk              269.37
# Morgan Geekie             231.45
# Trent Frederic            219.70
# Matt Grzelcyk             210.89
# Danton Heinen             194.76
# Kevin Shattenkirk         172.66
# James van Riemsdyk        160.59
# Parker Wotherspoon        118.49
# Mason Lohrei              103.95
# Derek Forbort              73.24
# Jakub Lauko                57.79
# John Beecher               46.82
# Jesper Boqvist             36.21
# Matthew Poitras            23.80
# Oskar Steen                 8.57

# %%
#forwards who are of similar age to JD - 
 
young_forwards
# Out:
#                    Player Team Position  GP      TOI   Age   atoi  \
# 44            Nick Suzuki  MTL        C  82  1743.65  24.0  21.26
# 65           Jesper Bratt  N.J        L  82  1581.57  25.0  19.29
# 68          Robert Thomas  STL        C  82  1719.25  24.0  20.97
# 69      Fabian Zetterlund  S.J        L  82  1546.20  24.0  18.86
# 75          Cole Caufield  MTL        R  82  1592.48  23.0  19.42
# ..                    ...  ...      ...  ..      ...   ...    ...
# 645             Nils Aman  VAN        C  43   444.37  24.0  10.33
# 654  Jaret Anderson-Dolan  L.A        C  31   342.55  24.0  11.05
# 656          Kyle MacLean  NYI        C  32   322.77  25.0  10.09
# 662       Jonah Gadjovich  FLA        L  39   289.82  25.0   7.43
# 665         James Hamblin  EDM        L  31   245.67  25.0   7.92
#
#      total_percentile Skater  team_gp  team_TOI  team_atoi  adj_toi    QoTF  \
# 44              93.88      F     82.0   1743.65      21.26  1743.32  100.00
# 65              86.42      F     82.0   1581.57      19.29  1581.78  100.00
# 68              93.13      F     82.0   1719.25      20.97  1719.54  100.00
# 69              84.18      F     82.0   1546.20      18.86  1546.52  100.00
# 75              87.61      F     82.0   1592.48      19.42  1592.44   92.86
# ..                ...    ...      ...       ...        ...      ...     ...
# 645              6.12      F     43.0    444.37      10.33   444.19    6.67
# 654              2.39      F     30.0    328.90      10.96   339.76    7.69
# 656              1.79      F     32.0    322.77      10.09   322.88    7.14
# 662              1.19      F     39.0    289.82       7.43   289.77    6.67
# 665              0.60      F     31.0    245.67       7.92   245.52    6.67
#
#       QoTD Team 1 Team 2 Team 3  adj_toi 1  adj_toi 2  adj_toi 3   QoCF  \
# 44   87.50    NaN    NaN    NaN        NaN        NaN        NaN  99.05
# 65   87.50    NaN    NaN    NaN        NaN        NaN        NaN  93.85
# 68   71.43    NaN    NaN    NaN        NaN        NaN        NaN  98.82
# 69   88.89    NaN    NaN    NaN        NaN        NaN        NaN  91.51
# 75   87.50    NaN    NaN    NaN        NaN        NaN        NaN  94.80
# ..     ...    ...    ...    ...        ...        ...        ...    ...
# 645   0.00    NaN    NaN    NaN        NaN        NaN        NaN   8.25
# 654   0.00    L.A    NSH      0     339.76     423.15        0.0   3.55
# 656   0.00    NaN    NaN    NaN        NaN        NaN        NaN   2.37
# 662   0.00    NaN    NaN    NaN        NaN        NaN        NaN   1.65
# 665   0.00    NaN    NaN    NaN        NaN        NaN        NaN   0.71
#
#       QoCD  team_no team_count  toughest_min
# 44   84.07        1        MTL        370.62
# 65   72.37        1        N.J        353.72
# 68   82.82        1        STL        353.07
# 69   70.04        1        S.J        350.44
# 75   73.45        1        MTL        348.61
# ..     ...      ...        ...           ...
# 645   2.63        1        VAN         17.55
# 654   0.00        1      Multi         11.24
# 656   0.00        1        NYI          9.51
# 662   0.00        1        FLA          8.32
# 665   0.00        1        EDM          7.38
#
# [131 rows x 26 columns]

# %%
#Players similar age to JD

jd_f = forward.query('Age >=26 and Age < 28 ')
jd_f['Player'].unique()
# Out:
# array(['Auston Matthews', 'Kirill Kaprizov', 'Mikko Rantanen',
#        'Mathew Barzal', 'Joel Eriksson Ek', 'Connor McDavid',
#        'Travis Konecny', 'Sebastian Aho', 'Dylan Strome', 'Brock Boeser',
#        'Troy Terry', 'Matthew Tkachuk', 'Anthony Cirelli',
#        'Drake Batherson', 'Mitchell Marner', 'Alex DeBrincat',
#        'Jordan Kyrou', 'Yegor Sharangovich', 'Pavel Zacha', 'Kevin Fiala',
#        'Lawson Crouse', 'Jake DeBrusk', 'Roope Hintz', 'Adrian Kempe',
#        'Dylan Larkin', 'Jack Eichel', 'Luke Kunin', 'Taylor Raddysh',
#        'Tage Thompson', 'Kyle Connor', 'Timo Meier', "Drew O'Connor",
#        'Trent Frederic', 'Yakov Trenin', 'Mathieu Joseph', 'Nicolas Roy',
#        'Jordan Greenway', 'Beck Malenstyn', 'Sam Bennett', 'Tommy Novak',
#        'Kasperi Kapanen', 'Jack Roslovic', 'Ross Colton',
#        'Anthony Beauvillier', 'Michael Eyssimont', 'Kevin Stenlund',
#        'Brandon Duhaime', 'Sam Steel', 'Brett Howden', 'Daniel Sprong',
#        'Christian Fischer', "Logan O'Connor", 'Keegan Kolesar',
#        'Michael McLeod', 'Tanner Jeannot', 'Blake Lizotte', 'A.J. Greer',
#        'Max Jones', 'Mathieu Olivier', 'Nathan Bastian',
#        'Carl Grundstrom', 'Sammy Blais', 'Michael Pezzetta',
#        'Alex Barré-Boulet', 'Jansen Harkins', 'Tyson Jost',
#        'Mitchell Chaffee', 'Walker Duehr', 'Matthew Phillips',
#        'Oskar Steen', 'Givani Smith', 'Zack MacEwen'], dtype=object)

# %%
jd_f = jd_f.query('Position == "L" or Position == "R"')
jd_f = jd_f.query('team_count != "Multi"')

# %%
jd_f['QoCF'] = pd.to_numeric(jd_f['QoCF'])  # Convert 'QoCF' column to numeric type
jd_f.set_index('Player', inplace=True)
jd_f = jd_f.sort_values(['QoCF', 'TOI'], ascending=[False, False])
jd_f
# Out:
#                   Team Position  GP      TOI   Age   atoi  total_percentile  \
# Player
# Mikko Rantanen     COL        R  80  1832.45  27.0  22.91             95.37
# Kirill Kaprizov    MIN        L  75  1616.17  27.0  21.55             88.66
# Brock Boeser       VAN        R  81  1506.78  27.0  18.60             81.49
# Travis Konecny     PHI        R  76  1508.02  27.0  19.84             81.79
# Drake Batherson    OTT        R  82  1490.27  26.0  18.17             79.70
# Matthew Tkachuk    FLA        L  80  1491.20  26.0  18.64             80.00
# Kevin Fiala        L.A        L  82  1478.92  27.0  18.04             79.10
# Mitchell Marner    TOR        R  69  1468.08  27.0  21.28             77.76
# Alex DeBrincat     DET        R  82  1467.15  26.0  17.89             77.46
# Adrian Kempe       L.A        R  77  1457.92  27.0  18.93             76.42
# Troy Terry         ANA        R  76  1388.23  26.0  18.27             71.19
# Lawson Crouse      ARI        L  81  1362.18  26.0  16.82             69.25
# Jake DeBrusk       BOS        L  80  1346.58  27.0  16.83             67.91
# Kyle Connor        WPG        L  65  1282.10  27.0  19.72             60.45
# Drew O'Connor      PIT        L  79  1235.43  26.0  15.64             57.31
# Timo Meier         N.J        R  69  1214.50  27.0  17.60             56.12
# Mathieu Joseph     OTT        R  72  1185.98  27.0  16.47             53.43
# Taylor Raddysh     CHI        R  73  1159.42  26.0  15.88             51.79
# Jordan Greenway    BUF        L  67  1155.72  27.0  17.25             51.34
# Beck Malenstyn     WSH        L  81  1153.73  26.0  14.24             51.19
# Kasperi Kapanen    STL        R  73  1050.05  27.0  14.38             43.43
# Daniel Sprong      DET        R  76   912.03  27.0  12.00             32.84
# Christian Fischer  DET        R  79   901.13  27.0  11.41             31.64
# Keegan Kolesar     VGK        R  79   858.20  27.0  10.86             28.96
# Logan O'Connor     COL        R  57   852.17  27.0  14.95             28.81
# Tanner Jeannot     T.B        L  55   661.00  27.0  12.02             18.06
# Max Jones          ANA        L  52   626.82  26.0  12.05             16.12
# Mathieu Olivier    CBJ        R  54   609.23  27.0  11.28             14.78
# Nathan Bastian     N.J        R  54   548.30  26.0  10.15             10.90
# Carl Grundstrom    L.A        R  50   546.85  26.0  10.94             10.60
# Sammy Blais        STL        L  53   513.53  27.0   9.69              8.51
# A.J. Greer         CGY        L  59   521.07  27.0   8.83              8.96
# Michael Pezzetta   MTL        L  61   475.55  26.0   7.80              7.46
# Mitchell Chaffee   T.B        R  30   338.65  26.0  11.29              2.24
# Walker Duehr       CGY        R  40   324.67  26.0   8.12              1.94
# Givani Smith       S.J        R  36   281.13  26.0   7.81              0.90
# Zack MacEwen       OTT        R  30   191.93  27.0   6.40              0.15
#
#                   Skater  team_gp  team_TOI  team_atoi  adj_toi    QoTF  \
# Player
# Mikko Rantanen         F     80.0   1832.45      22.91  1832.80   94.44
# Kirill Kaprizov        F     75.0   1616.17      21.55  1616.25  100.00
# Brock Boeser           F     81.0   1506.78      18.60  1506.60   86.67
# Travis Konecny         F     76.0   1508.02      19.84  1507.84  100.00
# Drake Batherson        F     82.0   1490.27      18.17  1489.94   80.00
# Matthew Tkachuk        F     80.0   1491.20      18.64  1491.20   93.33
# Kevin Fiala            F     82.0   1478.92      18.04  1479.28   92.31
# Mitchell Marner        F     69.0   1468.08      21.28  1468.32   86.67
# Alex DeBrincat         F     82.0   1467.15      17.89  1466.98   92.86
# Adrian Kempe           F     77.0   1457.92      18.93  1457.61   76.92
# Troy Terry             F     76.0   1388.23      18.27  1388.52   86.67
# Lawson Crouse          F     81.0   1362.18      16.82  1362.42   78.57
# Jake DeBrusk           F     80.0   1346.58      16.83  1346.40   73.33
# Kyle Connor            F     65.0   1282.10      19.72  1281.80   64.29
# Drew O'Connor          F     79.0   1235.43      15.64  1235.56   68.75
# Timo Meier             F     69.0   1214.50      17.60  1214.40   60.00
# Mathieu Joseph         F     72.0   1185.98      16.47  1185.84   66.67
# Taylor Raddysh         F     73.0   1159.42      15.88  1159.24   73.33
# Jordan Greenway        F     67.0   1155.72      17.25  1155.75   57.14
# Beck Malenstyn         F     81.0   1153.73      14.24  1153.44   66.67
# Kasperi Kapanen        F     73.0   1050.05      14.38  1049.74   41.67
# Daniel Sprong          F     76.0    912.03      12.00   912.00   35.71
# Christian Fischer      F     79.0    901.13      11.41   901.39   28.57
# Keegan Kolesar         F     79.0    858.20      10.86   857.94   20.00
# Logan O'Connor         F     57.0    852.17      14.95   852.15   44.44
# Tanner Jeannot         F     55.0    661.00      12.02   661.10   33.33
# Max Jones              F     52.0    626.82      12.05   626.60   26.67
# Mathieu Olivier        F     54.0    609.23      11.28   609.12   13.33
# Nathan Bastian         F     54.0    548.30      10.15   548.10   26.67
# Carl Grundstrom        F     50.0    546.85      10.94   547.00   15.38
# Sammy Blais            F     53.0    513.53       9.69   513.57   16.67
# A.J. Greer             F     59.0    521.07       8.83   520.97   37.50
# Michael Pezzetta       F     61.0    475.55       7.80   475.80   14.29
# Mitchell Chaffee       F     30.0    338.65      11.29   338.70   13.33
# Walker Duehr           F     40.0    324.67       8.12   324.80    6.25
# Givani Smith           F     36.0    281.13       7.81   281.16    6.67
# Zack MacEwen           F     30.0    191.93       6.40   192.00    6.67
#
#                     QoTD Team 1 Team 2 Team 3  adj_toi 1  adj_toi 2  \
# Player
# Mikko Rantanen     71.43    NaN    NaN    NaN        NaN        NaN
# Kirill Kaprizov    88.89    NaN    NaN    NaN        NaN        NaN
# Brock Boeser       71.43    NaN    NaN    NaN        NaN        NaN
# Travis Konecny     66.67    NaN    NaN    NaN        NaN        NaN
# Drake Batherson    71.43    NaN    NaN    NaN        NaN        NaN
# Matthew Tkachuk    62.50    NaN    NaN    NaN        NaN        NaN
# Kevin Fiala        33.33    NaN    NaN    NaN        NaN        NaN
# Mitchell Marner    66.67    NaN    NaN    NaN        NaN        NaN
# Alex DeBrincat     57.14    NaN    NaN    NaN        NaN        NaN
# Adrian Kempe       33.33    NaN    NaN    NaN        NaN        NaN
# Troy Terry         87.50    NaN    NaN    NaN        NaN        NaN
# Lawson Crouse      62.50    NaN    NaN    NaN        NaN        NaN
# Jake DeBrusk       66.67    NaN    NaN    NaN        NaN        NaN
# Kyle Connor        50.00    NaN    NaN    NaN        NaN        NaN
# Drew O'Connor      50.00    NaN    NaN    NaN        NaN        NaN
# Timo Meier         62.50    NaN    NaN    NaN        NaN        NaN
# Mathieu Joseph     42.86    NaN    NaN    NaN        NaN        NaN
# Taylor Raddysh     66.67    NaN    NaN    NaN        NaN        NaN
# Jordan Greenway    44.44    NaN    NaN    NaN        NaN        NaN
# Beck Malenstyn     28.57    NaN    NaN    NaN        NaN        NaN
# Kasperi Kapanen    42.86    NaN    NaN    NaN        NaN        NaN
# Daniel Sprong      14.29    NaN    NaN    NaN        NaN        NaN
# Christian Fischer  14.29    NaN    NaN    NaN        NaN        NaN
# Keegan Kolesar     22.22    NaN    NaN    NaN        NaN        NaN
# Logan O'Connor      0.00    NaN    NaN    NaN        NaN        NaN
# Tanner Jeannot     11.11    NaN    NaN    NaN        NaN        NaN
# Max Jones          12.50    NaN    NaN    NaN        NaN        NaN
# Mathieu Olivier    12.50    NaN    NaN    NaN        NaN        NaN
# Nathan Bastian      0.00    NaN    NaN    NaN        NaN        NaN
# Carl Grundstrom     0.00    NaN    NaN    NaN        NaN        NaN
# Sammy Blais         0.00    NaN    NaN    NaN        NaN        NaN
# A.J. Greer         18.18    NaN    NaN    NaN        NaN        NaN
# Michael Pezzetta    0.00    NaN    NaN    NaN        NaN        NaN
# Mitchell Chaffee    0.00    NaN    NaN    NaN        NaN        NaN
# Walker Duehr        0.00    NaN    NaN    NaN        NaN        NaN
# Givani Smith        0.00    NaN    NaN    NaN        NaN        NaN
# Zack MacEwen        0.00    NaN    NaN    NaN        NaN        NaN
#
#                    adj_toi 3    QoCF   QoCD  team_no team_count  toughest_min
# Player
# Mikko Rantanen           NaN  100.00  87.77        1        COL        353.64
# Kirill Kaprizov          NaN   96.00  74.56        1        MIN        359.45
# Brock Boeser             NaN   89.39  66.23        1        VAN        313.72
# Travis Konecny           NaN   89.36  66.67        1        PHI        322.70
# Drake Batherson          NaN   87.47  65.64        1        OTT        304.54
# Matthew Tkachuk          NaN   87.23  66.52        1        FLA        309.58
# Kevin Fiala              NaN   86.32  66.67        1        L.A        278.63
# Mitchell Marner          NaN   85.55  64.47        1        TOR        303.36
# Alex DeBrincat           NaN   85.11  64.32        1        DET        299.43
# Adrian Kempe             NaN   84.43  62.72        1        L.A        257.40
# Troy Terry               NaN   78.72  56.77        1        ANA        309.66
# Lawson Crouse            NaN   76.89  55.70        1        ARI        273.66
# Jake DeBrusk             NaN   75.83  53.54        1        BOS        269.37
# Kyle Connor              NaN   66.75  49.12        1        WPG        230.16
# Drew O'Connor            NaN   63.68  46.26        1        PIT        228.69
# Timo Meier               NaN   62.41  44.74        1        N.J        229.65
# Mathieu Joseph           NaN   59.34  42.29        1        OTT        211.16
# Taylor Raddysh           NaN   57.78  39.56        1        CHI        237.34
# Jordan Greenway          NaN   57.65  40.53        1        BUF        199.76
# Beck Malenstyn           NaN   56.84  40.79        1        WSH        192.87
# Kasperi Kapanen          NaN   48.82  34.36        1        STL        167.71
# Daniel Sprong            NaN   36.88  26.87        1        DET        113.75
# Christian Fischer        NaN   35.46  25.99        1        DET        104.31
# Keegan Kolesar           NaN   31.91  25.11        1        VGK         99.24
# Logan O'Connor           NaN   30.73  25.33        1        COL        100.50
# Tanner Jeannot           NaN   20.14  12.78        1        T.B         77.36
# Max Jones                NaN   18.20  11.35        1        ANA         68.72
# Mathieu Olivier          NaN   16.98  11.01        1        CBJ         53.82
# Nathan Bastian           NaN   12.77   6.58        1        N.J         46.02
# Carl Grundstrom          NaN   12.74   6.58        1        L.A         34.70
# Sammy Blais              NaN   10.38   4.85        1        STL         31.90
# A.J. Greer               NaN   10.17   4.35        1        CGY         70.20
# Michael Pezzetta         NaN    9.22   3.98        1        MTL         27.49
# Mitchell Chaffee         NaN    3.08   0.00        1        T.B         16.41
# Walker Duehr             NaN    2.60   0.00        1        CGY          8.85
# Givani Smith             NaN    1.18   0.00        1        S.J          7.85
# Zack MacEwen             NaN    0.00   0.00        1        OTT          6.67

# %%
# Create the heatmap table
jd_f = jd_f[['QoCF', 'QoCD', 'QoTF', 'QoTD']]

plt.figure(figsize=(14, 10)) 

sns.heatmap(jd_f, annot=True, cmap='YlGnBu', fmt='.0f', cbar=True)
plt.tick_params(axis='x', labelrotation=0, labeltop=True, labelbottom=False)
plt.tick_params(axis='y', labelrotation=360)
# Add labels and title
plt.xlabel('')
plt.ylabel('')
plt.title('Player Usage')

# Display the plot
plt.show()

# %%
# atlantic = forwards.query('Team == "BOS" or Team == "TOR" or Team == "OTT" or Team == "MTL" or Team == "DET" or Team == "BUF" or Team == "TBL" or Team == "FLA"')
# atlantic
new_players = player_usage.query('Player == "Elias Lindholm"or Player == "Nikita Zadorov" or Player == "Max Jones"')
new_players
# Out:
#              Player Team Position  GP      TOI   Age   atoi  total_percentile  \
# 107  Elias Lindholm  CGY        C  75  1477.02  29.0  19.69             78.96
# 273  Nikita Zadorov  VAN        D  75  1308.07  29.0  17.44             64.03
# 553       Max Jones  ANA        L  52   626.82  26.0  12.05             16.12
#
#     Skater  team_gp  team_TOI  team_atoi  adj_toi   QoTF   QoTD Team 1 Team 2  \
# 107      F     49.0   1016.68      20.75  1556.25  93.75  72.73    CGY    VAN
# 273      D     54.0    921.60      17.07  1280.25  73.33  42.86    VAN    CGY
# 553      F     52.0    626.82      12.05   626.60  26.67  12.50    NaN    NaN
#
#     Team 3  adj_toi 1  adj_toi 2  adj_toi 3   QoCF   QoCD  team_no team_count  \
# 107      0    1556.25    1328.25        0.0  92.18  71.74        1      Multi
# 273      0    1280.25    1380.00        0.0  66.04  49.34        1      Multi
# 553    NaN        NaN        NaN        NaN  18.20  11.35        1        ANA
#
#      toughest_min
# 107        330.40
# 273        231.57
# 553         68.72

# %%
# atlantic_tm=atlantic
# atlantic_tm['tm_percentile'] = round(((atlantic['toughest_min'].rank(pct=True))*100),2)
# atlantic_tm=atlantic_tm.sort_values(by=['tm_percentile'], ascending=[False]).reset_index(drop=True)


# new_players['tm_percentile'] = round(((new_players['toughest_min'].rank(pct=True))*100),2)
# new_players=new_players.sort_values(by=['tm_percentile'], ascending=[False]).reset_index(drop=True)
all_players_1 = player_usage
all_players_1['tm_percentile'] = round(((all_players_1['toughest_min'].rank(pct=True))*100),2)
all_players_1=all_players_1.sort_values(by=['tm_percentile'], ascending=[False]).reset_index(drop=True)

# %%
all_players_1.head()
# Out:
#           Player Team Position  GP      TOI   Age   atoi  total_percentile  \
# 0   John Carlson  WSH        D  82  2123.12  34.0  25.89            100.00
# 1   Drew Doughty  L.A        D  82  2115.07  34.0  25.79             99.85
# 2  Mike Matheson  MTL        D  82  2095.33  30.0  25.55             99.70
# 3  Rasmus Dahlin  BUF        D  81  2059.22  24.0  25.42             99.55
# 4    Brock Faber  MIN        D  82  2046.83  21.0  24.96             99.40
#
#   Skater  team_gp  team_TOI  team_atoi  adj_toi   QoTF   QoTD Team 1 Team 2  \
# 0      D     82.0   2123.12      25.89  2122.98  100.0  100.0    NaN    NaN
# 1      D     82.0   2115.07      25.79  2114.78  100.0  100.0    NaN    NaN
# 2      D     82.0   2095.33      25.55  2095.10  100.0  100.0    NaN    NaN
# 3      D     81.0   2059.22      25.42  2059.02  100.0  100.0    NaN    NaN
# 4      D     82.0   2046.83      24.96  2046.72  100.0  100.0    NaN    NaN
#
#   Team 3  adj_toi 1  adj_toi 2  adj_toi 3   QoCF    QoCD  team_no team_count  \
# 0    NaN        NaN        NaN        NaN  100.0  100.00        1        WSH
# 1    NaN        NaN        NaN        NaN  100.0   99.56        1        L.A
# 2    NaN        NaN        NaN        NaN  100.0   99.12        1        MTL
# 3    NaN        NaN        NaN        NaN  100.0   98.68        1        BUF
# 4    NaN        NaN        NaN        NaN  100.0   98.25        1        MIN
#
#    toughest_min  tm_percentile
# 0        400.00         100.00
# 1        399.56          99.85
# 2        399.12          99.70
# 3        398.68          99.55
# 4        398.25          99.40

# %%
atlantic_tm.query('Player == "Jake DeBrusk"')
# Out:
#           Player Team Position  GP      TOI   Age  total_percentile  \
# 25  Jake DeBrusk  BOS        L  80  1346.58  27.0             67.91
#
#     toughest_min  tm_percentile  Goals  Total Assists  First Assists  \
# 25        269.37          74.23     19             21             14
#
#     Second Assists  Total Points    IPP  Shots    SH%    ixG  iCF  iHDCF  \
# 25               7            40  59.70    182  10.44  25.22  330    110
#
#     Rush Attempts  Rebounds Created  Giveaways  Takeaways  Hits  Hits Taken  \
# 25             19                31         26         36    91         119
#
#     Shots Blocked Faceoffs %    CF    CA  GF  GA    GF%    xGF    xGA  HDGF%  \
# 25             48      30.43  1304  1378  67  59  53.17  75.02  68.69  63.33
#
#       PDO
# 25  1.012

# %%
# atlantic_tm=atlantic_tm[['Player', 'Team', 'Position', 'GP', 'TOI', 'Age', 'total_percentile', 'toughest_min', 'tm_percentile']]
# atlantic_tm = atlantic_tm.merge(player_stats, on = 'Player', how = "left")

# new_players=new_players[['Player', 'Team', 'Position', 'GP', 'TOI', 'Age', 'total_percentile', 'toughest_min', 'tm_percentile']]
# new_players = new_players.merge(player_stats, on = 'Player', how = "left")

all_players_1 = all_players_1[['Player', 'Team', 'Position', 'GP', 'TOI', 'Age', 'total_percentile', 'toughest_min', 'tm_percentile']]
all_players_1 = all_players_1.merge(player_stats, on = 'Player', how = "left")
all_players_1.head()
# Out:
#           Player Team Position  GP      TOI   Age  total_percentile  \
# 0   John Carlson  WSH        D  82  2123.12  34.0            100.00
# 1   Drew Doughty  L.A        D  82  2115.07  34.0             99.85
# 2  Mike Matheson  MTL        D  82  2095.33  30.0             99.70
# 3  Rasmus Dahlin  BUF        D  81  2059.22  24.0             99.55
# 4    Brock Faber  MIN        D  82  2046.83  21.0             99.40
#
#    toughest_min  tm_percentile  Goals  Total Assists  First Assists  \
# 0        400.00         100.00     10             42             16
# 1        399.56          99.85     15             35             14
# 2        399.12          99.70     11             51             24
# 3        398.68          99.55     20             39             24
# 4        398.25          99.40      8             39             18
#
#    Second Assists  Total Points    IPP  Shots    SH%    ixG  iCF  iHDCF  \
# 0              26            52  46.85    176   5.68  12.36  439     28
# 1              21            50  43.86    135  11.11   8.30  306     12
# 2              27            62  57.94    187   5.88  10.10  403     23
# 3              15            59  53.15    235   8.51  14.63  474     21
# 4              21            47  42.34    136   5.88   7.44  293     15
#
#    Rush Attempts  Rebounds Created  Giveaways  Takeaways  Hits  Hits Taken  \
# 0             11                50         82         58    61          87
# 1              7                27         45         20   104         122
# 2              6                30         76         49    47         113
# 3             11                38         44         42   174         157
# 4              3                24         35         15    59         122
#
#    Shots Blocked Faceoffs %    CF    CA   GF   GA    GF%     xGF     xGA  \
# 0            194          -  2182  2361  111  117  48.68  131.22  126.94
# 1            142          -  2247  1863  114   71  61.62  118.76   99.71
# 2            186          -  1924  2393  107  131  44.96  108.85  134.15
# 3            154          -  2450  1795  111   96  53.62  125.63  104.05
# 4            150          -  1979  2169  111  118  48.47  104.82  107.61
#
#    HDGF%    PDO
# 0  50.00  1.004
# 1  57.65  1.024
# 2  47.17  0.993
# 3  47.78  0.978
# 4  49.12  1.002

# %%
# # atlantic_tm.head(26).sort_values(by=['Rush Attempts'], ascending=[False]).reset_index(drop=True)

# new_players.head(26).sort_values(by=['Rush Attempts'], ascending=[False]).reset_index(drop=True)

# %%
# atlantic_tm.iloc[25:41].sort_values(by=['HDGF%'], ascending=[False]).reset_index(drop=True)

# %%
atlantic_tm.query('Player == "Jake DeBrusk"')
# Out:
#           Player Team Position  GP      TOI   Age  total_percentile  \
# 25  Jake DeBrusk  BOS        L  80  1346.58  27.0             67.91
#
#     toughest_min  tm_percentile  Goals  Total Assists  First Assists  \
# 25        269.37          74.23     19             21             14
#
#     Second Assists  Total Points    IPP  Shots    SH%    ixG  iCF  iHDCF  \
# 25               7            40  59.70    182  10.44  25.22  330    110
#
#     Rush Attempts  Rebounds Created  Giveaways  Takeaways  Hits  Hits Taken  \
# 25             19                31         26         36    91         119
#
#     Shots Blocked Faceoffs %    CF    CA  GF  GA    GF%    xGF    xGA  HDGF%  \
# 25             48      30.43  1304  1378  67  59  53.17  75.02  68.69  63.33
#
#       PDO
# 25  1.012

# %%
# #reltationship between tough min and goals scored?
# atlantic_1 = atlantic_tm[['Player','toughest_min', 'Position', 'Goals', 'IPP', 'Total Points', 'SH%']]
# atlantic_1=atlantic_1.rename(columns={'Total Points': 'Total_Points', 'SH%': 'SH_pct'})
# atlantic_1.head()

#reltationship between tough min and goals scored?
all_players_1 = all_players_1[['Player','toughest_min', 'Position', 'Goals', 'IPP', 'Total Points', 'SH%']]
all_players_1=all_players_1.rename(columns={'Total Points': 'Total_Points', 'SH%': 'SH_pct'})
all_players_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 676 entries, 0 to 675
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Player        676 non-null    object
#  1   toughest_min  675 non-null    float64
#  2   Position      676 non-null    object
#  3   Goals         676 non-null    int64
#  4   IPP           676 non-null    object
#  5   Total_Points  676 non-null    int64
#  6   SH_pct        676 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 42.2+ KB

# %%
column_name = 'toughest_min'

# Calculate the mean of the specified column
column_median = all_players_1[column_name].median()

# Replace NaN values in the specified column with the column mean
all_players_1[column_name].fillna(column_median, inplace=True)

# %%
# atlantic_1['intercept']=1
# lm=sm.OLS(atlantic_1['Goals'], atlantic_1[['intercept', 'toughest_min']])
# results = lm.fit()
# results.summary()

all_players_1['intercept']=1
lm=sm.OLS(all_players_1['Goals'], all_players_1[['intercept', 'toughest_min']])
results = lm.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Goals   R-squared:                       0.217
# Model:                            OLS   Adj. R-squared:                  0.216
# Method:                 Least Squares   F-statistic:                     187.3
# Date:                Tue, 02 Jul 2024   Prob (F-statistic):           8.35e-38
# Time:                        08:05:17   Log-Likelihood:                -2477.5
# No. Observations:                 676   AIC:                             4959.
# Df Residuals:                     674   BIC:                             4968.
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# intercept        3.0389      0.738      4.118      0.000       1.590       4.488
# toughest_min     0.0442      0.003     13.687      0.000       0.038       0.051
# ==============================================================================
# Omnibus:                      105.767   Durbin-Watson:                   1.905
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              192.375
# Skew:                           0.936   Prob(JB):                     1.68e-42
# Kurtosis:                       4.824   Cond. No.                         463.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
atlantic_1.head()
# Out:
#             Player  toughest_min Position  Goals    IPP  Total_Points SH_pct  \
# 0      Nick Suzuki        370.62        C     33  69.37            77  17.74
# 1  Auston Matthews        367.29        C     69  69.48           107  18.60
# 2     Sam Reinhart        362.26        C     57  71.76            94  24.46
# 3   David Pastrnak        350.16        R     47  80.88           110  12.30
# 4    Cole Caufield        348.61        R     28  60.75            65   8.92
#
#    intercept
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %%
# formula = 'Goals ~ toughest_min + Position + Total_Points'
# model = smf.ols(formula=formula, data=atlantic_1).fit()
# print(model.summary())

formula = 'Goals ~ toughest_min + Position + Total_Points'
model = smf.ols(formula=formula, data=all_players_1).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Goals   R-squared:                       0.852
# Model:                            OLS   Adj. R-squared:                  0.850
# Method:                 Least Squares   F-statistic:                     478.1
# Date:                Tue, 02 Jul 2024   Prob (F-statistic):          2.24e-270
# Time:                        08:05:29   Log-Likelihood:                -1915.7
# No. Observations:                 676   AIC:                             3849.
# Df Residuals:                     667   BIC:                             3890.
# Df Model:                           8
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            1.9604      0.400      4.903      0.000       1.175       2.745
# Position[T.C, L]     1.4745      2.947      0.500      0.617      -4.312       7.261
# Position[T.C, R]     3.1999      2.409      1.328      0.185      -1.531       7.931
# Position[T.D]       -4.7563      0.460    -10.349      0.000      -5.659      -3.854
# Position[T.D, L]    -1.0834      4.162     -0.260      0.795      -9.256       7.090
# Position[T.L]        0.9458      0.476      1.985      0.048       0.010       1.881
# Position[T.R]        0.6528      0.502      1.300      0.194      -0.333       1.639
# toughest_min        -0.0045      0.002     -1.957      0.051      -0.009    1.51e-05
# Total_Points         0.3830      0.011     35.377      0.000       0.362       0.404
# ==============================================================================
# Omnibus:                      132.089   Durbin-Watson:                   1.887
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1086.020
# Skew:                           0.614   Prob(JB):                    1.49e-236
# Kurtosis:                       9.087   Cond. No.                     6.04e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.04e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Define the coefficients
Intercept =1.9571
Coeff_Position_C_L = 1.4745      
Coeff_Position_C_R = 3.1999            
Coeff_Position_D = -4.7563      
Coeff_Position_D_L = -1.0834            
Coeff_Position_L = 0.9458      
Coeff_Position_R = 0.6528      
Coeff_toughest_min = -0.0045
Coeff_Total_Points = 0.3830

# Create dummy variables for Position column
position_dummies = pd.get_dummies(all_players_1['Position'], prefix='Position', drop_first=True)

# Concatenate the original DataFrame with the dummy variables
all_players_1 = pd.concat([all_players_1, position_dummies], axis=1)






# # Define the coefficients
# Intercept = 0.4824
# Coeff_Position_L = -0.4402
# Coeff_Position_R = -0.8225
# Coeff_toughest_min = -0.0040
# Coeff_Total_Points = 0.4434

# # Create dummy variables for Position column
# position_dummies = pd.get_dummies(atlantic_1['Position'], prefix='Position', drop_first=True)

# # Concatenate the original DataFrame with the dummy variables
# atlantic_1 = pd.concat([atlantic_1, position_dummies], axis=1)

# atlantic_1['Predicted_Goals'] = (
#     Intercept +
#     (Coeff_Position_L * atlantic_1['Position_L']) +
#     (Coeff_Position_R * atlantic_1['Position_R']) +
#     (Coeff_toughest_min * atlantic_1['toughest_min']) +
#     (Coeff_Total_Points * atlantic_1['Total_Points'])
# )

# atlantic_1
# Out:
# Index(['Player', 'toughest_min', 'Position', 'Goals', 'IPP', 'Total_Points',
#        'SH_pct', 'intercept', 'Position_C, L', 'Position_C, R', 'Position_D',
#        'Position_D, L', 'Position_L', 'Position_R'],
#       dtype='object')

# %%
all_players_1['Predicted_Goals'] = (
    Intercept +
    (Coeff_Position_C_L * all_players_1['Position_C, L']) +
    (Coeff_Position_C_R * all_players_1['Position_C, R']) +
    (Coeff_Position_D * all_players_1['Position_D']) +
    (Coeff_Position_D_L * all_players_1['Position_D, L']) +
    (Coeff_Position_L * all_players_1['Position_L']) +
    (Coeff_Position_R * all_players_1['Position_R']) +
    (Coeff_toughest_min * all_players_1['toughest_min']) +
    (Coeff_Total_Points * all_players_1['Total_Points']) 
    )

all_players_1['Predicted_Goals'] = round(all_players_1['Predicted_Goals'],2)

# %%
new_players = all_players_1.query('Player == "Elias Lindholm"or Player == "Nikita Zadorov" or Player == "Max Jones"')
new_players = new_players [['Player', 'toughest_min', 'Goals', 'IPP', 'Total_Points', 'SH_pct', 'Predicted_Goals']]
new_players
# Out:
#              Player  toughest_min  Goals    IPP  Total_Points SH_pct  \
# 107  Elias Lindholm        330.40     15  61.97            44   8.67
# 276  Nikita Zadorov        231.57      6  41.67            20   6.67
# 559       Max Jones         68.72      5  65.22            15   6.58
#
#      Predicted_Goals
# 107            17.32
# 276             3.82
# 559             8.34

# %%
atlantic_1.query('Player == "Jake DeBrusk"')
# Out:
#           Player  toughest_min Position  Goals    IPP  Total_Points SH_pct  \
# 25  Jake DeBrusk        269.37        L     19  59.70            40  10.44
#
#     intercept  Position_L  Position_R  Predicted_Goals
# 25          1           1           0         16.70072
