# %%
import requests
import os 
import json
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
from pprint import pprint 
import pytz
import schedule
import time
from PIL import Image
from IPython.display import display
pd.options.mode.chained_assignment = None 
import re

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# goal_counts_df = 'C:\\Users\\Karoline Sears\\Documents\\GitHub\\hockey-streamlit\\data\\goal_counts.csv'
# goal_counts_df = pd.read_csv(goal_counts_df)
# goal_location_df = 'C:\\Users\\Karoline Sears\\Documents\\GitHub\\hockey-streamlit\\data\\goal_locations.csv'
# goal_location_df= pd.read_csv(goal_location_df)
formatted_date = "2024-04-17"
base_url = "https://api-web.nhle.com/v1/schedule/"
api_url = f"{base_url}{formatted_date}"
#api_url = "https://api-web.nhle.com/v1/schedule/2023-10-11"
response = requests.get(api_url )
content = json.loads(response.content)

# %%
 #url = "https://api.nhle.com/stats/rest/en/shiftcharts?cayenneExp=gameId=2023020260"
#url = "https://api-web.nhle.com/v1/gamecenter/2023020260/boxscore"
#game_id = 2023021272
response = requests.get(url )
content = json.loads(response.content)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # The response content can be accessed using response.text
    response_text = response.text
    #pprint(response_text)
else:
    print(f"Request failed with status code {response.status_code}")

json_data = json.loads(response_text)

# events = json_data['plays']
# events_df = pd.DataFrame(events)
#json_data.keys()
# events_df = events_df.convert_dtypes()
# details = pd.json_normalize(events_df['details'])
# details = details[['eventOwnerTeamId', 'xCoord', 'yCoord', 'shotType', 'scoringPlayerId', 'shootingPlayerId']]
# all_game_data = pd.concat([events_df[['sortOrder', 'situationCode', 'timeInPeriod', 'typeCode']], details], axis=1)

#         # Filter rows where 'typeCode' is 505-508
# shots = all_game_data[all_game_data['typeCode'].isin([505, 506, 507, 508])]
# shots['game_id']= game_id
# shots

details = pd.DataFrame(json_data['data'])
details
# Out:
#            id  detailCode duration endTime eventDescription  \
# 0    13440828           0    00:26   00:26             None
# 1    13440829           0    00:36   03:40             None
# 2    13440830           0    01:09   06:04             None
# 3    13441215           0    00:40   10:27             None
# 4    13441593           0    00:39   14:07             None
# 5    13441594           0    00:17   16:52             None
# 6    13442166           0    01:13   01:13             None
# 7    13442167           0    00:34   04:41             None
# 8    13443126           0    00:43   14:45             None
# 9    13443127           0    00:29   17:32             None
# 10   13443128           0    00:21   18:29             None
# 11   13443797           0    00:50   02:00             None
# 12   13444164           0    01:02   04:34             None
# 13   13444165           0    00:30   07:49             None
# 14   13444740           0    00:20   10:55             None
# 15   13444741           0    01:16   14:59             None
# 16   13444742           0    00:29   16:29             None
# 17   13445201           0    00:28   19:15             None
# 18   13440831           0    00:58   02:25             None
# 19   13440832           0    00:46   06:07             None
# 20   13441216           0    00:47   08:30             None
# 21   13441217           0    00:56   11:54             None
# 22   13441595           0    01:01   15:03             None
# 23   13441596           0    00:56   17:48             None
# 24   13441597           0    00:46   19:16             None
# 25   13442168           0    00:30   01:37             None
# 26   13442169           0    00:15   04:07             None
# 27   13442170           0    00:51   05:32             None
# 28   13442644           0    00:09   07:54             None
# 29   13442645           0    00:54   09:01             None
# 30   13442646           0    00:53   11:17             None
# 31   13443129           0    00:55   14:39             None
# 32   13443130           0    00:20   17:03             None
# 33   13443560           0    00:57   19:26             None
# 34   13443798           0    00:21   00:21             None
# 826        CGY      20      Calgary Flames       517
# 827        CGY      20      Calgary Flames       517
# 828        CGY      20      Calgary Flames       517
# 829        CGY      20      Calgary Flames       517
# 830        CGY      20      Calgary Flames       517
# 831        CGY      20      Calgary Flames       517
# 832        CGY      20      Calgary Flames       517
# 833        CGY      20      Calgary Flames       517
# 834        CGY      20      Calgary Flames       517
# 835        CGY      20      Calgary Flames       517
# 836        CGY      20      Calgary Flames       517

# %%
details['typeCode'].value_counts()
# Out:
# 517    826
# 505     11
# Name: typeCode, dtype: int64

# %%
details.query('typeCode == 505')
# Out:
#            id  detailCode duration endTime eventDescription  \
# 57   13445578         801     None   04:07              PPG
# 181  13445579         803     None   03:32              EVG
# 198  13445580         807     None   17:03              EVG
# 338  13445581         801     None   03:12              EVG
# 350  13445582         803     None   16:52              EVG
# 419  13445583         802     None   00:00         Shootout
# 597  13445584         803     None   08:07              EVG
# 697  13445585         802     None   00:00         Shootout
# 751  13445586         803     None   12:16              EVG
# 785  13445587         805     None   13:43              EVG
# 791  13445588         806     None   00:00         Shootout
#
#                           eventDetails  eventNumber  firstName      gameId  \
# 57              Bo Horvat, Noah Dobson          209       Kyle  2023020260
# 181      Pierre Engvall, Sebastian Aho          815      Brock  2023020260
# 198  Nick DeSimone, Jonathan Huberdeau          734      Blake  2023020260
# 338           Connor Zary, Nazem Kadri          809  MacKenzie  2023020260
# 350      Cal Clutterbuck, Brock Nelson          504     Hudson  2023020260
# 419                                             912         Bo  2023020260
# 597                                             643     Mathew  2023020260
# 697                                             918     Oliver  2023020260
# 751           Nazem Kadri, Connor Zary          345     Martin  2023020260
# 785       Noah Hanifin, Elias Lindholm         1040      Yegor  2023020260
# 791                                             911      Yegor  2023020260
#
#     hexValue      lastName  period  playerId  shiftNumber startTime  \
# 57   #003087      Palmieri       2   8475151            0     04:07
# 181  #003087        Nelson       3   8475754            0     03:32
# 198  #C8102E       Coleman       2   8476399            0     17:03
# 338  #C8102E        Weegar       3   8477346            0     03:12
# 350  #003087      Fasching       1   8477392            0     16:52
# 419  #003087        Horvat       5   8477500            0     00:00
# 597  #003087        Barzal       2   8478445            0     08:07
# 697  #003087     Wahlstrom       5   8480789            0     00:00
# 751  #C8102E      Pospisil       1   8481028            0     12:16
# 785  #C8102E  Sharangovich       3   8481068            0     13:43
# 791  #C8102E  Sharangovich       5   8481068            0     00:00
#
#     teamAbbrev  teamId            teamName  typeCode
# 57         NYI       2  New York Islanders       505
# 181        NYI       2  New York Islanders       505
# 198        CGY      20      Calgary Flames       505
# 338        CGY      20      Calgary Flames       505
# 350        NYI       2  New York Islanders       505
# 419        NYI       2  New York Islanders       505
# 597        NYI       2  New York Islanders       505
# 697        NYI       2  New York Islanders       505
# 751        CGY      20      Calgary Flames       505
# 785        CGY      20      Calgary Flames       505
# 791        CGY      20      Calgary Flames       505

# %%
# Check if the request was successful (status code 200)
if response.status_code == 200:
    # The response content can be accessed using response.text
    response_text = response.text
    #pprint(response_text)
else:
    print(f"Request failed with status code {response.status_code}")

json_data = json.loads(response_text)

json_data.keys()
# Out:
# dict_keys(['nextStartDate', 'previousStartDate', 'gameWeek', 'preSeasonStartDate', 'regularSeasonStartDate', 'regularSeasonEndDate', 'playoffEndDate', 'numberOfGames'])

# %%
#get the dates and game numbers for the season
game_dates = json_data['gameWeek']
game_dates
# Out:
# [{'date': '2024-04-17',
#   'dayAbbrev': 'WED',
#   'numberOfGames': 4,
#   'games': [{'id': 2023021303,
#     'season': 20232024,
#     'gameType': 2,
#     'venue': {'default': 'UBS Arena'},
#     'neutralSite': False,
#     'startTimeUTC': '2024-04-17T23:00:00Z',
#     'easternUTCOffset': '-04:00',
#     'venueUTCOffset': '-04:00',
#     'venueTimezone': 'America/New_York',
#     'gameState': 'OFF',
#     'gameScheduleState': 'OK',
#     'tvBroadcasts': [{'id': 281,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'TVAS',
#       'sequenceNumber': 31},
#      {'id': 528,
#       'market': 'A',
#       'countryCode': 'US',
#       'network': 'SN-PIT',
#       'sequenceNumber': 52},
#      {'id': 409,
#       'market': 'H',
#       'countryCode': 'US',
#       'network': 'MSGSN',
#       'sequenceNumber': 88}],
#     'awayTeam': {'id': 5,
#      'placeName': {'default': 'Pittsburgh'},
#      'abbrev': 'PIT',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/PIT_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/PIT_dark.svg',
#      'awaySplitSquad': False,
#      'score': 4},
#     'homeTeam': {'id': 2,
#      'placeName': {'default': 'New York'},
#      'abbrev': 'NYI',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/NYI_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/NYI_dark.svg',
#      'homeSplitSquad': False,
#      'score': 5},
#     'periodDescriptor': {'number': 3,
#      'periodType': 'REG',
#      'maxRegulationPeriods': 3},
#     'gameOutcome': {'lastPeriodType': 'REG'},
#     'winningGoalie': {'playerId': 8478009,
#      'firstInitial': {'default': 'I.'},
#      'lastName': {'default': 'Sorokin'}},
#     'winningGoalScorer': {'playerId': 8481601,
#      'firstInitial': {'default': 'S.'},
#      'lastName': {'default': 'Holmstrom',
#       'cs': 'Holmström',
#       'sk': 'Holmström'}},
#     'threeMinRecap': '/video/recap-penguins-at-islanders-4-17-24-6351135791112',
#     'threeMinRecapFr': '/fr/video/recap-penguins-at-islanders-4-17-24-6351137011112',
#     'gameCenterLink': '/gamecenter/pit-vs-nyi/2024/04/17/2023021303'},
#    {'id': 2023021304,
#     'season': 20232024,
#     'gameType': 2,
#     'venue': {'default': 'Amalie Arena'},
#     'neutralSite': False,
#     'startTimeUTC': '2024-04-17T23:00:00Z',
#     'easternUTCOffset': '-04:00',
#     'venueUTCOffset': '-04:00',
#     'venueTimezone': 'US/Eastern',
#     'gameState': 'OFF',
#     'gameScheduleState': 'OK',
#     'tvBroadcasts': [{'id': 385,
#       'market': 'N',
#       'countryCode': 'US',
#       'network': 'TNT',
#       'sequenceNumber': 4},
#      {'id': 501,
#       'market': 'N',
#       'countryCode': 'US',
#       'network': 'truTV',
#       'sequenceNumber': 6},
#      {'id': 519,
#       'market': 'N',
#       'countryCode': 'US',
#       'network': 'MAX',
#       'sequenceNumber': 9},
#      {'id': 282,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'SN',
#       'sequenceNumber': 21},
#      {'id': 284,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'SN1',
#       'sequenceNumber': 22},
#      {'id': 291,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'TVAS2',
#       'sequenceNumber': 33}],
#     'awayTeam': {'id': 10,
#      'placeName': {'default': 'Toronto'},
#      'abbrev': 'TOR',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/TOR_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/TOR_dark.svg',
#      'awaySplitSquad': False,
#      'score': 4},
#     'homeTeam': {'id': 14,
#      'placeName': {'default': 'Tampa Bay'},
#      'abbrev': 'TBL',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/TBL_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/TBL_dark.svg',
#      'homeSplitSquad': False,
#      'score': 6},
#     'periodDescriptor': {'number': 3,
#      'periodType': 'REG',
#      'maxRegulationPeriods': 3},
#     'gameOutcome': {'lastPeriodType': 'REG'},
#     'winningGoalie': {'playerId': 8477035,
#      'firstInitial': {'default': 'M.'},
#      'lastName': {'default': 'Tomkins'}},
#     'winningGoalScorer': {'playerId': 8479542,
#      'firstInitial': {'default': 'B.'},
#      'lastName': {'default': 'Hagel'}},
#     'threeMinRecap': '/video/recap-leafs-at-lightning-4-17-24-6351137051112',
#     'threeMinRecapFr': '/fr/video/recap-leafs-at-lightning-4-17-24-6351135776112',
#     'gameCenterLink': '/gamecenter/tor-vs-tbl/2024/04/17/2023021304'},
#    {'id': 2023021305,
#     'season': 20232024,
#     'gameType': 2,
#     'venue': {'default': 'American Airlines Center'},
#     'neutralSite': False,
#     'startTimeUTC': '2024-04-18T01:30:00Z',
#     'easternUTCOffset': '-04:00',
#     'venueUTCOffset': '-05:00',
#     'venueTimezone': 'US/Central',
#     'gameState': 'OFF',
#     'gameScheduleState': 'OK',
#     'tvBroadcasts': [{'id': 385,
#       'market': 'N',
#       'countryCode': 'US',
#       'network': 'TNT',
#       'sequenceNumber': 4},
#      {'id': 501,
#       'market': 'N',
#       'countryCode': 'US',
#       'network': 'truTV',
#       'sequenceNumber': 6},
#      {'id': 519,
#       'market': 'N',
#       'countryCode': 'US',
#       'network': 'MAX',
#       'sequenceNumber': 9}],
#     'awayTeam': {'id': 19,
#      'placeName': {'default': 'St. Louis'},
#      'abbrev': 'STL',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/STL_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/STL_dark.svg',
#      'awaySplitSquad': False,
#      'score': 1},
#     'homeTeam': {'id': 25,
#      'placeName': {'default': 'Dallas'},
#      'abbrev': 'DAL',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/DAL_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/DAL_dark.svg',
#      'homeSplitSquad': False,
#      'score': 2},
#     'periodDescriptor': {'number': 5,
#      'periodType': 'SO',
#      'maxRegulationPeriods': 3},
#     'gameOutcome': {'lastPeriodType': 'SO'},
#     'winningGoalie': {'playerId': 8479979,
#      'firstInitial': {'default': 'J.'},
#      'lastName': {'default': 'Oettinger'}},
#     'threeMinRecap': '/video/recap-blues-at-stars-4-17-24-6351143422112',
#     'gameCenterLink': '/gamecenter/stl-vs-dal/2024/04/17/2023021305'},
#    {'id': 2023021306,
#     'season': 20232024,
#     'gameType': 2,
#     'venue': {'default': 'Mullett Arena'},
#     'neutralSite': False,
#     'startTimeUTC': '2024-04-18T02:00:00Z',
#     'easternUTCOffset': '-04:00',
#     'venueUTCOffset': '-07:00',
#     'venueTimezone': 'America/Phoenix',
#     'gameState': 'OFF',
#     'gameScheduleState': 'OK',
#     'tvBroadcasts': [{'id': 282,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'SN',
#       'sequenceNumber': 21},
#      {'id': 284,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'SN1',
#       'sequenceNumber': 22},
#      {'id': 281,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'TVAS',
#       'sequenceNumber': 31},
#      {'id': 521,
#       'market': 'H',
#       'countryCode': 'US',
#       'network': 'SCRIPPS',
#       'sequenceNumber': 87}],
#     'awayTeam': {'id': 22,
#      'placeName': {'default': 'Edmonton'},
#      'abbrev': 'EDM',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/EDM_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/EDM_dark.svg',
#      'awaySplitSquad': False,
#      'score': 2},
#     'homeTeam': {'id': 53,
#      'placeName': {'default': 'Arizona'},
#      'abbrev': 'ARI',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/ARI_20202021-20232024_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/ARI_20202021-20232024_dark.svg',
#      'homeSplitSquad': False,
#      'score': 5},
#     'periodDescriptor': {'number': 3,
#      'periodType': 'REG',
#      'maxRegulationPeriods': 3},
#     'gameOutcome': {'lastPeriodType': 'REG'},
#     'winningGoalie': {'playerId': 8478971,
#      'firstInitial': {'default': 'C.'},
#      'lastName': {'default': 'Ingram'}},
#     'winningGoalScorer': {'playerId': 8478474,
#      'firstInitial': {'default': 'L.'},
#      'lastName': {'default': 'Crouse'}},
#     'threeMinRecap': '/video/recap-oilers-at-coyotes-4-17-24-6351144752112',
#     'threeMinRecapFr': '/fr/video/recap-oilers-at-coyotes-4-17-24-6351145253112',
#     'gameCenterLink': '/gamecenter/edm-vs-ari/2024/04/17/2023021306'}]},
#  {'date': '2024-04-18',
#   'dayAbbrev': 'THU',
#   'numberOfGames': 6,
#   'games': [{'id': 2023021307,
#     'season': 20232024,
#     'gameType': 2,
#     'venue': {'default': 'Xcel Energy Center'},
#     'neutralSite': False,
#     'startTimeUTC': '2024-04-18T23:00:00Z',
#     'easternUTCOffset': '-04:00',
#     'venueUTCOffset': '-05:00',
#     'venueTimezone': 'US/Central',
#     'gameState': 'OFF',
#     'gameScheduleState': 'OK',
#     'tvBroadcasts': [{'id': 309,
#       'market': 'N',
#       'countryCode': 'US',
#       'network': 'ESPN',
#       'sequenceNumber': 2}],
#     'awayTeam': {'id': 55,
#      'placeName': {'default': 'Seattle'},
#      'abbrev': 'SEA',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/SEA_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/SEA_dark.svg',
#      'awaySplitSquad': False,
#      'score': 4},
#     'homeTeam': {'id': 30,
#      'placeName': {'default': 'Minnesota'},
#      'abbrev': 'MIN',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/MIN_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/MIN_dark.svg',
#      'homeSplitSquad': False,
#      'score': 3},
#     'periodDescriptor': {'number': 3,
#      'periodType': 'REG',
#      'maxRegulationPeriods': 3},
#     'gameOutcome': {'lastPeriodType': 'REG'},
#     'winningGoalie': {'playerId': 8478916,
#      'firstInitial': {'default': 'J.'},
#      'lastName': {'default': 'Daccord'}},
#     'winningGoalScorer': {'playerId': 8476826,
#      'firstInitial': {'default': 'Y.'},
#      'lastName': {'default': 'Gourde'}},
#     'threeMinRecap': '/video/recap-kraken-at-wild-4-18-24-6351203673112',
#     'gameCenterLink': '/gamecenter/sea-vs-min/2024/04/18/2023021307'},
#    {'id': 2023021308,
#     'season': 20232024,
#     'gameType': 2,
#     'venue': {'default': 'Canada Life Centre'},
#     'neutralSite': False,
#     'startTimeUTC': '2024-04-19T00:00:00Z',
#     'easternUTCOffset': '-04:00',
#     'venueUTCOffset': '-05:00',
#     'venueTimezone': 'America/Winnipeg',
#     'gameState': 'OFF',
#     'gameScheduleState': 'OK',
#     'tvBroadcasts': [{'id': 290,
#       'market': 'A',
#       'countryCode': 'CA',
#       'network': 'SNP',
#       'sequenceNumber': 29},
#      {'id': 281,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'TVAS',
#       'sequenceNumber': 31},
#      {'id': 292,
#       'market': 'H',
#       'countryCode': 'CA',
#       'network': 'TSN3',
#       'sequenceNumber': 75}],
#     'awayTeam': {'id': 23,
#      'placeName': {'default': 'Vancouver'},
#      'abbrev': 'VAN',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/VAN_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/VAN_dark.svg',
#      'awaySplitSquad': False,
#      'score': 2},
#     'homeTeam': {'id': 52,
#      'placeName': {'default': 'Winnipeg'},
#      'abbrev': 'WPG',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/WPG_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/WPG_dark.svg',
#      'homeSplitSquad': False,
#      'score': 4},
#     'periodDescriptor': {'number': 3,
#      'periodType': 'REG',
#      'maxRegulationPeriods': 3},
#     'gameOutcome': {'lastPeriodType': 'REG'},
#     'winningGoalie': {'playerId': 8476316,
#      'firstInitial': {'default': 'L.'},
#      'lastName': {'default': 'Brossoit'}},
#     'winningGoalScorer': {'playerId': 8482787,
#      'firstInitial': {'default': 'N.'},
#      'lastName': {'default': 'Chibrikov'}},
#     'threeMinRecap': '/video/recap-canucks-at-jets-4-18-24-6351205716112',
#     'threeMinRecapFr': '/fr/video/recap-canucks-at-jets-4-18-24-6351206972112',
#     'gameCenterLink': '/gamecenter/van-vs-wpg/2024/04/18/2023021308'},
#    {'id': 2023021309,
#     'season': 20232024,
#     'gameType': 2,
#     'venue': {'default': 'Scotiabank Saddledome'},
#     'neutralSite': False,
#     'startTimeUTC': '2024-04-19T01:00:00Z',
#     'easternUTCOffset': '-04:00',
#     'venueUTCOffset': '-06:00',
#     'venueTimezone': 'US/Mountain',
#     'gameState': 'OFF',
#     'gameScheduleState': 'OK',
#     'tvBroadcasts': [{'id': 289,
#       'market': 'H',
#       'countryCode': 'CA',
#       'network': 'SNW',
#       'sequenceNumber': 30},
#      {'id': 314,
#       'market': 'A',
#       'countryCode': 'US',
#       'network': 'NBCSCA',
#       'sequenceNumber': 63}],
#     'awayTeam': {'id': 28,
#      'placeName': {'default': 'San Jose'},
#      'abbrev': 'SJS',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/SJS_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/SJS_dark.svg',
#      'awaySplitSquad': False,
#      'score': 1},
#     'homeTeam': {'id': 20,
#      'placeName': {'default': 'Calgary'},
#      'abbrev': 'CGY',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/CGY_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/CGY_dark.svg',
#      'homeSplitSquad': False,
#      'score': 5},
#     'periodDescriptor': {'number': 3,
#      'periodType': 'REG',
#      'maxRegulationPeriods': 3},
#     'gameOutcome': {'lastPeriodType': 'REG'},
#     'winningGoalie': {'playerId': 8481692,
#      'firstInitial': {'default': 'D.'},
#      'lastName': {'default': 'Wolf'}},
#     'winningGoalScorer': {'playerId': 8476399,
#      'firstInitial': {'default': 'B.'},
#      'lastName': {'default': 'Coleman'}},
#     'threeMinRecap': '/video/recap-sharks-at-flames-4-18-24-6351208117112',
#     'gameCenterLink': '/gamecenter/sjs-vs-cgy/2024/04/18/2023021309'},
#    {'id': 2023021310,
#     'season': 20232024,
#     'gameType': 2,
#     'venue': {'default': 'Ball Arena'},
#     'neutralSite': False,
#     'startTimeUTC': '2024-04-19T01:30:00Z',
#     'easternUTCOffset': '-04:00',
#     'venueUTCOffset': '-06:00',
#     'venueTimezone': 'America/Denver',
#     'gameState': 'OFF',
#     'gameScheduleState': 'OK',
#     'tvBroadcasts': [{'id': 309,
#       'market': 'N',
#       'countryCode': 'US',
#       'network': 'ESPN',
#       'sequenceNumber': 2},
#      {'id': 282,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'SN',
#       'sequenceNumber': 21},
#      {'id': 284,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'SN1',
#       'sequenceNumber': 22}],
#     'awayTeam': {'id': 22,
#      'placeName': {'default': 'Edmonton'},
#      'abbrev': 'EDM',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/EDM_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/EDM_dark.svg',
#      'awaySplitSquad': False,
#      'score': 1},
#     'homeTeam': {'id': 21,
#      'placeName': {'default': 'Colorado'},
#      'abbrev': 'COL',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/COL_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/COL_dark.svg',
#      'homeSplitSquad': False,
#      'score': 5},
#     'periodDescriptor': {'number': 3,
#      'periodType': 'REG',
#      'maxRegulationPeriods': 3},
#     'gameOutcome': {'lastPeriodType': 'REG'},
#     'winningGoalie': {'playerId': 8481020,
#      'firstInitial': {'default': 'J.'},
#      'lastName': {'default': 'Annunen'}},
#     'winningGoalScorer': {'playerId': 8478420,
#      'firstInitial': {'default': 'M.'},
#      'lastName': {'default': 'Rantanen'}},
#     'threeMinRecap': '/video/recap-oilers-at-avalanche-4-18-24-6351208330112',
#     'gameCenterLink': '/gamecenter/edm-vs-col/2024/04/18/2023021310'},
#    {'id': 2023021311,
#     'season': 20232024,
#     'gameType': 2,
#     'venue': {'default': 'T-Mobile Arena'},
#     'neutralSite': False,
#     'startTimeUTC': '2024-04-19T02:00:00Z',
#     'easternUTCOffset': '-04:00',
#     'venueUTCOffset': '-07:00',
#     'venueTimezone': 'US/Pacific',
#     'gameState': 'OFF',
#     'gameScheduleState': 'OK',
#     'tvBroadcasts': [{'id': 365,
#       'market': 'A',
#       'countryCode': 'US',
#       'network': 'BSSD',
#       'sequenceNumber': 81},
#      {'id': 341,
#       'market': 'A',
#       'countryCode': 'US',
#       'network': 'BSSC',
#       'sequenceNumber': 84},
#      {'id': 521,
#       'market': 'H',
#       'countryCode': 'US',
#       'network': 'SCRIPPS',
#       'sequenceNumber': 87}],
#     'awayTeam': {'id': 24,
#      'placeName': {'default': 'Anaheim'},
#      'abbrev': 'ANA',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/ANA_20132014-20232024_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/ANA_20132014-20232024_dark.svg',
#      'awaySplitSquad': False,
#      'score': 4},
#     'homeTeam': {'id': 54,
#      'placeName': {'default': 'Vegas'},
#      'abbrev': 'VGK',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/VGK_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/VGK_dark.svg',
#      'homeSplitSquad': False,
#      'score': 1},
#     'periodDescriptor': {'number': 3,
#      'periodType': 'REG',
#      'maxRegulationPeriods': 3},
#     'gameOutcome': {'lastPeriodType': 'REG'},
#     'winningGoalie': {'playerId': 8480843,
#      'firstInitial': {'default': 'L.'},
#      'lastName': {'default': 'Dostal', 'cs': 'Dostál', 'sk': 'Dostál'}},
#     'winningGoalScorer': {'playerId': 8481605,
#      'firstInitial': {'default': 'J.'},
#      'lastName': {'default': 'LaCombe'}},
#     'threeMinRecap': '/video/recap-ducks-at-golden-knights-4-18-24-6351210154112',
#     'gameCenterLink': '/gamecenter/ana-vs-vgk/2024/04/18/2023021311'},
#    {'id': 2023021312,
#     'season': 20232024,
#     'gameType': 2,
#     'venue': {'default': 'Crypto.com Arena'},
#     'neutralSite': False,
#     'startTimeUTC': '2024-04-19T02:30:00Z',
#     'easternUTCOffset': '-04:00',
#     'venueUTCOffset': '-07:00',
#     'venueTimezone': 'America/Los_Angeles',
#     'gameState': 'OFF',
#     'gameScheduleState': 'OK',
#     'tvBroadcasts': [{'id': 283,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'SN360',
#       'sequenceNumber': 23},
#      {'id': 318,
#       'market': 'A',
#       'countryCode': 'US',
#       'network': 'NBCSCH',
#       'sequenceNumber': 54},
#      {'id': 355,
#       'market': 'H',
#       'countryCode': 'US',
#       'network': 'BSW',
#       'sequenceNumber': 57}],
#     'awayTeam': {'id': 16,
#      'placeName': {'default': 'Chicago'},
#      'abbrev': 'CHI',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/CHI_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/CHI_dark.svg',
#      'awaySplitSquad': False,
#      'score': 4},
#     'homeTeam': {'id': 26,
#      'placeName': {'default': 'Los Angeles'},
#      'abbrev': 'LAK',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/LAK_20192020-20232024_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/LAK_20192020-20232024_dark.svg',
#      'homeSplitSquad': False,
#      'score': 5},
#     'periodDescriptor': {'number': 4,
#      'periodType': 'OT',
#      'maxRegulationPeriods': 3},
#     'gameOutcome': {'lastPeriodType': 'OT'},
#     'winningGoalie': {'playerId': 8475660,
#      'firstInitial': {'default': 'C.'},
#      'lastName': {'default': 'Talbot'}},
#     'winningGoalScorer': {'playerId': 8477960,
#      'firstInitial': {'default': 'A.'},
#      'lastName': {'default': 'Kempe'}},
#     'threeMinRecap': '/video/recap-blackhawks-at-kings-4-18-24-6351217203112',
#     'gameCenterLink': '/gamecenter/chi-vs-lak/2024/04/18/2023021312'}]},
#  {'date': '2024-04-19', 'dayAbbrev': 'FRI', 'numberOfGames': 0, 'games': []},
#  {'date': '2024-04-20',
#   'dayAbbrev': 'SAT',
#   'numberOfGames': 2,
#   'games': [{'id': 2023030141,
#     'season': 20232024,
#     'gameType': 3,
#     'venue': {'default': 'PNC Arena'},
#     'neutralSite': False,
#     'startTimeUTC': '2024-04-20T21:00:00Z',
#     'easternUTCOffset': '-04:00',
#     'venueUTCOffset': '-04:00',
#     'venueTimezone': 'US/Eastern',
#     'gameState': 'OFF',
#     'gameScheduleState': 'OK',
#     'tvBroadcasts': [{'id': 403,
#       'market': 'N',
#       'countryCode': 'US',
#       'network': 'TBS',
#       'sequenceNumber': 5},
#      {'id': 501,
#       'market': 'N',
#       'countryCode': 'US',
#       'network': 'truTV',
#       'sequenceNumber': 6},
#      {'id': 519,
#       'market': 'N',
#       'countryCode': 'US',
#       'network': 'MAX',
#       'sequenceNumber': 9},
#      {'id': 282,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'SN',
#       'sequenceNumber': 21},
#      {'id': 283,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'SN360',
#       'sequenceNumber': 23},
#      {'id': 281,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'TVAS',
#       'sequenceNumber': 31},
#      {'id': 375,
#       'market': 'H',
#       'countryCode': 'US',
#       'network': 'BSSO',
#       'sequenceNumber': 70},
#      {'id': 409,
#       'market': 'A',
#       'countryCode': 'US',
#       'network': 'MSGSN',
#       'sequenceNumber': 88}],
#     'awayTeam': {'id': 2,
#      'placeName': {'default': 'New York'},
#      'abbrev': 'NYI',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/NYI_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/NYI_dark.svg',
#      'awaySplitSquad': False,
#      'score': 1},
#     'homeTeam': {'id': 12,
#      'placeName': {'default': 'Carolina', 'fr': 'Caroline'},
#      'abbrev': 'CAR',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/CAR_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/CAR_dark.svg',
#      'homeSplitSquad': False,
#      'score': 3},
#     'periodDescriptor': {'number': 3,
#      'periodType': 'REG',
#      'maxRegulationPeriods': 3},
#     'gameOutcome': {'lastPeriodType': 'REG'},
#     'winningGoalie': {'playerId': 8475883,
#      'firstInitial': {'default': 'F.'},
#      'lastName': {'default': 'Andersen'}},
#     'winningGoalScorer': {'playerId': 8476474,
#      'firstInitial': {'default': 'S.'},
#      'lastName': {'default': 'Noesen'}},
#     'seriesStatus': {'round': 1,
#      'seriesAbbrev': 'R1',
#      'seriesTitle': '1st Round',
#      'seriesLetter': 'D',
#      'neededToWin': 4,
#      'topSeedTeamAbbrev': 'CAR',
#      'topSeedWins': 1,
#      'bottomSeedTeamAbbrev': 'NYI',
#      'bottomSeedWins': 0,
#      'gameNumberOfSeries': 1},
#     'seriesUrl': '/schedule/playoff-series/2024/series-d/hurricanes-vs-islanders',
#     'threeMinRecap': '/video/recap-islanders-at-hurricanes-4-20-24-6351339086112',
#     'gameCenterLink': '/gamecenter/nyi-vs-car/2024/04/20/2023030141'},
#    {'id': 2023030121,
#     'season': 20232024,
#     'gameType': 3,
#     'venue': {'default': 'TD Garden'},
#     'neutralSite': False,
#     'startTimeUTC': '2024-04-21T00:00:00Z',
#     'easternUTCOffset': '-04:00',
#     'venueUTCOffset': '-04:00',
#     'venueTimezone': 'US/Eastern',
#     'gameState': 'OFF',
#     'gameScheduleState': 'OK',
#     'tvBroadcasts': [{'id': 403,
#       'market': 'N',
#       'countryCode': 'US',
#       'network': 'TBS',
#       'sequenceNumber': 5},
#      {'id': 501,
#       'market': 'N',
#       'countryCode': 'US',
#       'network': 'truTV',
#       'sequenceNumber': 6},
#      {'id': 519,
#       'market': 'N',
#       'countryCode': 'US',
#       'network': 'MAX',
#       'sequenceNumber': 9},
#      {'id': 282,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'SN',
#       'sequenceNumber': 21},
#      {'id': 4,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'CBC',
#       'sequenceNumber': 24},
#      {'id': 281,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'TVAS',
#       'sequenceNumber': 31},
#      {'id': 31,
#       'market': 'H',
#       'countryCode': 'US',
#       'network': 'NESN',
#       'sequenceNumber': 78}],
#     'awayTeam': {'id': 10,
#      'placeName': {'default': 'Toronto'},
#      'abbrev': 'TOR',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/TOR_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/TOR_dark.svg',
#      'awaySplitSquad': False,
#      'score': 1},
#     'homeTeam': {'id': 6,
#      'placeName': {'default': 'Boston'},
#      'abbrev': 'BOS',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/BOS_20232024_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/BOS_20232024_dark.svg',
#      'homeSplitSquad': False,
#      'score': 5},
#     'periodDescriptor': {'number': 3,
#      'periodType': 'REG',
#      'maxRegulationPeriods': 3},
#     'gameOutcome': {'lastPeriodType': 'REG'},
#     'winningGoalie': {'playerId': 8480280,
#      'firstInitial': {'default': 'J.'},
#      'lastName': {'default': 'Swayman'}},
#     'winningGoalScorer': {'playerId': 8478443,
#      'firstInitial': {'default': 'B.'},
#      'lastName': {'default': 'Carlo'}},
#     'seriesStatus': {'round': 1,
#      'seriesAbbrev': 'R1',
#      'seriesTitle': '1st Round',
#      'seriesLetter': 'B',
#      'neededToWin': 4,
#      'topSeedTeamAbbrev': 'BOS',
#      'topSeedWins': 1,
#      'bottomSeedTeamAbbrev': 'TOR',
#      'bottomSeedWins': 0,
#      'gameNumberOfSeries': 1},
#     'seriesUrl': '/schedule/playoff-series/2024/series-b/bruins-vs-mapleleafs',
#     'threeMinRecap': '/video/recap-leafs-at-bruins-4-20-24-6351339941112',
#     'gameCenterLink': '/gamecenter/tor-vs-bos/2024/04/20/2023030121'}]},
#  {'date': '2024-04-21',
#   'dayAbbrev': 'SUN',
#   'numberOfGames': 4,
#   'games': [{'id': 2023030111,
#     'season': 20232024,
#     'gameType': 3,
#     'venue': {'default': 'Amerant Bank Arena'},
#     'neutralSite': False,
#     'startTimeUTC': '2024-04-21T16:30:00Z',
#     'easternUTCOffset': '-04:00',
#     'venueUTCOffset': '-04:00',
#     'venueTimezone': 'US/Eastern',
#     'gameState': 'OFF',
#     'gameScheduleState': 'OK',
#     'tvBroadcasts': [{'id': 309,
#       'market': 'N',
#       'countryCode': 'US',
#       'network': 'ESPN',
#       'sequenceNumber': 2},
#      {'id': 282,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'SN',
#       'sequenceNumber': 21},
#      {'id': 281,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'TVAS',
#       'sequenceNumber': 31},
#      {'id': 359,
#       'market': 'A',
#       'countryCode': 'US',
#       'network': 'BSSUN',
#       'sequenceNumber': 86},
#      {'id': 353,
#       'market': 'H',
#       'countryCode': 'US',
#       'network': 'BSFL',
#       'sequenceNumber': 92}],
#     'awayTeam': {'id': 14,
#      'placeName': {'default': 'Tampa Bay'},
#      'abbrev': 'TBL',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/TBL_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/TBL_dark.svg',
#      'awaySplitSquad': False,
#      'score': 2},
#     'homeTeam': {'id': 13,
#      'placeName': {'default': 'Florida', 'fr': 'Floride'},
#      'abbrev': 'FLA',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/FLA_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/FLA_dark.svg',
#      'homeSplitSquad': False,
#      'score': 3},
#     'periodDescriptor': {'number': 3,
#      'periodType': 'REG',
#      'maxRegulationPeriods': 3},
#     'gameOutcome': {'lastPeriodType': 'REG'},
#     'winningGoalie': {'playerId': 8475683,
#      'firstInitial': {'default': 'S.'},
#      'lastName': {'default': 'Bobrovsky',
#       'cs': 'Bobrovskij',
#       'sk': 'Bobrovskij'}},
#     'winningGoalScorer': {'playerId': 8479314,
#      'firstInitial': {'default': 'M.'},
#      'lastName': {'default': 'Tkachuk'}},
#     'seriesStatus': {'round': 1,
#      'seriesAbbrev': 'R1',
#      'seriesTitle': '1st Round',
#      'seriesLetter': 'A',
#      'neededToWin': 4,
#      'topSeedTeamAbbrev': 'FLA',
#      'topSeedWins': 1,
#      'bottomSeedTeamAbbrev': 'TBL',
#      'bottomSeedWins': 0,
#      'gameNumberOfSeries': 1},
#     'seriesUrl': '/schedule/playoff-series/2024/series-a/panthers-vs-lightning',
#     'threeMinRecap': '/video/recap-lightning-at-panthers-4-21-24-6351373109112',
#     'threeMinRecapFr': '/fr/video/recap-lightning-at-panthers-4-21-24-6351373010112',
#     'gameCenterLink': '/gamecenter/tbl-vs-fla/2024/04/21/2023030111'},
#    {'id': 2023030131,
#     'season': 20232024,
#     'gameType': 3,
#     'venue': {'default': 'Madison Square Garden'},
#     'neutralSite': False,
#     'startTimeUTC': '2024-04-21T19:00:00Z',
#     'easternUTCOffset': '-04:00',
#     'venueUTCOffset': '-04:00',
#     'venueTimezone': 'America/New_York',
#     'gameState': 'OFF',
#     'gameScheduleState': 'OK',
#     'tvBroadcasts': [{'id': 309,
#       'market': 'N',
#       'countryCode': 'US',
#       'network': 'ESPN',
#       'sequenceNumber': 2},
#      {'id': 282,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'SN',
#       'sequenceNumber': 21},
#      {'id': 281,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'TVAS',
#       'sequenceNumber': 31},
#      {'id': 517,
#       'market': 'A',
#       'countryCode': 'US',
#       'network': 'MNMT',
#       'sequenceNumber': 67},
#      {'id': 27,
#       'market': 'H',
#       'countryCode': 'US',
#       'network': 'MSG',
#       'sequenceNumber': 97}],
#     'awayTeam': {'id': 15,
#      'placeName': {'default': 'Washington'},
#      'abbrev': 'WSH',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/WSH_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/WSH_dark.svg',
#      'awaySplitSquad': False,
#      'score': 1},
#     'homeTeam': {'id': 3,
#      'placeName': {'default': 'New York'},
#      'abbrev': 'NYR',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/NYR_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/NYR_dark.svg',
#      'homeSplitSquad': False,
#      'score': 4},
#     'periodDescriptor': {'number': 3,
#      'periodType': 'REG',
#      'maxRegulationPeriods': 3},
#     'gameOutcome': {'lastPeriodType': 'REG'},
#     'winningGoalie': {'playerId': 8478048,
#      'firstInitial': {'default': 'I.'},
#      'lastName': {'default': 'Shesterkin',
#       'cs': 'Šesťorkin',
#       'sk': 'Šesťorkin'}},
#     'winningGoalScorer': {'playerId': 8478550,
#      'firstInitial': {'default': 'A.'},
#      'lastName': {'default': 'Panarin'}},
#     'seriesStatus': {'round': 1,
#      'seriesAbbrev': 'R1',
#      'seriesTitle': '1st Round',
#      'seriesLetter': 'C',
#      'neededToWin': 4,
#      'topSeedTeamAbbrev': 'NYR',
#      'topSeedWins': 1,
#      'bottomSeedTeamAbbrev': 'WSH',
#      'bottomSeedWins': 0,
#      'gameNumberOfSeries': 1},
#     'seriesUrl': '/schedule/playoff-series/2024/series-c/rangers-vs-capitals',
#     'threeMinRecap': '/video/recap-capitals-at-rangers-4-21-24-6351377957112',
#     'threeMinRecapFr': '/fr/video/recap-capitals-at-rangers-4-21-24-6351378448112',
#     'gameCenterLink': '/gamecenter/wsh-vs-nyr/2024/04/21/2023030131'},
#    {'id': 2023030161,
#     'season': 20232024,
#     'gameType': 3,
#     'venue': {'default': 'Canada Life Centre'},
#     'neutralSite': False,
#     'startTimeUTC': '2024-04-21T23:00:00Z',
#     'easternUTCOffset': '-04:00',
#     'venueUTCOffset': '-05:00',
#     'venueTimezone': 'America/Winnipeg',
#     'gameState': 'OFF',
#     'gameScheduleState': 'OK',
#     'tvBroadcasts': [{'id': 307,
#       'market': 'N',
#       'countryCode': 'US',
#       'network': 'ESPN2',
#       'sequenceNumber': 3},
#      {'id': 282,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'SN',
#       'sequenceNumber': 21},
#      {'id': 4,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'CBC',
#       'sequenceNumber': 24},
#      {'id': 281,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'TVAS',
#       'sequenceNumber': 31},
#      {'id': 2,
#       'market': 'A',
#       'countryCode': 'US',
#       'network': 'ALT',
#       'sequenceNumber': 53}],
#     'awayTeam': {'id': 21,
#      'placeName': {'default': 'Colorado'},
#      'abbrev': 'COL',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/COL_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/COL_dark.svg',
#      'awaySplitSquad': False,
#      'score': 6},
#     'homeTeam': {'id': 52,
#      'placeName': {'default': 'Winnipeg'},
#      'abbrev': 'WPG',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/WPG_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/WPG_dark.svg',
#      'homeSplitSquad': False,
#      'score': 7},
#     'periodDescriptor': {'number': 3,
#      'periodType': 'REG',
#      'maxRegulationPeriods': 3},
#     'gameOutcome': {'lastPeriodType': 'REG'},
#     'winningGoalie': {'playerId': 8476945,
#      'firstInitial': {'default': 'C.'},
#      'lastName': {'default': 'Hellebuyck'}},
#     'winningGoalScorer': {'playerId': 8478398,
#      'firstInitial': {'default': 'K.'},
#      'lastName': {'default': 'Connor'}},
#     'seriesStatus': {'round': 1,
#      'seriesAbbrev': 'R1',
#      'seriesTitle': '1st Round',
#      'seriesLetter': 'F',
#      'neededToWin': 4,
#      'topSeedTeamAbbrev': 'WPG',
#      'topSeedWins': 1,
#      'bottomSeedTeamAbbrev': 'COL',
#      'bottomSeedWins': 0,
#      'gameNumberOfSeries': 1},
#     'seriesUrl': '/schedule/playoff-series/2024/series-f/jets-vs-avalanche',
#     'threeMinRecap': '/video/recap-avalanche-at-jets-4-21-24-6351383998112',
#     'threeMinRecapFr': '/fr/video/recap-avalanche-at-jets-4-21-24-6351381750112',
#     'gameCenterLink': '/gamecenter/col-vs-wpg/2024/04/21/2023030161'},
#    {'id': 2023030171,
#     'season': 20232024,
#     'gameType': 3,
#     'venue': {'default': 'Rogers Arena'},
#     'neutralSite': False,
#     'startTimeUTC': '2024-04-22T02:00:00Z',
#     'easternUTCOffset': '-04:00',
#     'venueUTCOffset': '-07:00',
#     'venueTimezone': 'America/Vancouver',
#     'gameState': 'OFF',
#     'gameScheduleState': 'OK',
#     'tvBroadcasts': [{'id': 309,
#       'market': 'N',
#       'countryCode': 'US',
#       'network': 'ESPN',
#       'sequenceNumber': 2},
#      {'id': 282,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'SN',
#       'sequenceNumber': 21},
#      {'id': 283,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'SN360',
#       'sequenceNumber': 23},
#      {'id': 4,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'CBC',
#       'sequenceNumber': 24},
#      {'id': 281,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'TVAS',
#       'sequenceNumber': 31},
#      {'id': 375,
#       'market': 'A',
#       'countryCode': 'US',
#       'network': 'BSSO',
#       'sequenceNumber': 70}],
#     'awayTeam': {'id': 18,
#      'placeName': {'default': 'Nashville'},
#      'abbrev': 'NSH',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/NSH_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/NSH_dark.svg',
#      'awaySplitSquad': False,
#      'score': 2},
#     'homeTeam': {'id': 23,
#      'placeName': {'default': 'Vancouver'},
#      'abbrev': 'VAN',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/VAN_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/VAN_dark.svg',
#      'homeSplitSquad': False,
#      'score': 4},
#     'periodDescriptor': {'number': 3,
#      'periodType': 'REG',
#      'maxRegulationPeriods': 3},
#     'gameOutcome': {'lastPeriodType': 'REG'},
#     'winningGoalie': {'playerId': 8477967,
#      'firstInitial': {'default': 'T.'},
#      'lastName': {'default': 'Demko'}},
#     'winningGoalScorer': {'playerId': 8478057,
#      'firstInitial': {'default': 'D.'},
#      'lastName': {'default': 'Joshua'}},
#     'seriesStatus': {'round': 1,
#      'seriesAbbrev': 'R1',
#      'seriesTitle': '1st Round',
#      'seriesLetter': 'G',
#      'neededToWin': 4,
#      'topSeedTeamAbbrev': 'VAN',
#      'topSeedWins': 1,
#      'bottomSeedTeamAbbrev': 'NSH',
#      'bottomSeedWins': 0,
#      'gameNumberOfSeries': 1},
#     'seriesUrl': '/schedule/playoff-series/2024/series-g/canucks-vs-predators',
#     'threeMinRecap': '/video/recap-predators-at-canucks-4-21-24-6351389319112',
#     'threeMinRecapFr': '/fr/video/recap-predators-at-canucks-4-21-24-6351391404112',
#     'gameCenterLink': '/gamecenter/nsh-vs-van/2024/04/21/2023030171'}]},
#  {'date': '2024-04-22',
#   'dayAbbrev': 'MON',
#   'numberOfGames': 4,
#   'games': [{'id': 2023030122,
#     'season': 20232024,
#     'gameType': 3,
#     'venue': {'default': 'TD Garden'},
#     'neutralSite': False,
#     'startTimeUTC': '2024-04-22T23:00:00Z',
#     'easternUTCOffset': '-04:00',
#     'venueUTCOffset': '-04:00',
#     'venueTimezone': 'US/Eastern',
#     'gameState': 'OFF',
#     'gameScheduleState': 'OK',
#     'tvBroadcasts': [{'id': 309,
#       'market': 'N',
#       'countryCode': 'US',
#       'network': 'ESPN',
#       'sequenceNumber': 2},
#      {'id': 282,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'SN',
#       'sequenceNumber': 21},
#      {'id': 4,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'CBC',
#       'sequenceNumber': 24},
#      {'id': 281,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'TVAS',
#       'sequenceNumber': 31},
#      {'id': 31,
#       'market': 'H',
#       'countryCode': 'US',
#       'network': 'NESN',
#       'sequenceNumber': 78}],
#     'awayTeam': {'id': 10,
#      'placeName': {'default': 'Toronto'},
#      'abbrev': 'TOR',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/TOR_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/TOR_dark.svg',
#      'awaySplitSquad': False,
#      'score': 3},
#     'homeTeam': {'id': 6,
#      'placeName': {'default': 'Boston'},
#      'abbrev': 'BOS',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/BOS_20232024_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/BOS_20232024_dark.svg',
#      'homeSplitSquad': False,
#      'score': 2},
#     'periodDescriptor': {'number': 3,
#      'periodType': 'REG',
#      'maxRegulationPeriods': 3},
#     'gameOutcome': {'lastPeriodType': 'REG'},
#     'winningGoalie': {'playerId': 8478492,
#      'firstInitial': {'default': 'I.'},
#      'lastName': {'default': 'Samsonov'}},
#     'winningGoalScorer': {'playerId': 8479318,
#      'firstInitial': {'default': 'A.'},
#      'lastName': {'default': 'Matthews'}},
#     'seriesStatus': {'round': 1,
#      'seriesAbbrev': 'R1',
#      'seriesTitle': '1st Round',
#      'seriesLetter': 'B',
#      'neededToWin': 4,
#      'topSeedTeamAbbrev': 'BOS',
#      'topSeedWins': 1,
#      'bottomSeedTeamAbbrev': 'TOR',
#      'bottomSeedWins': 1,
#      'gameNumberOfSeries': 2},
#     'seriesUrl': '/schedule/playoff-series/2024/series-b/bruins-vs-mapleleafs',
#     'threeMinRecap': '/video/recap-leafs-at-bruins-4-22-24-6351438219112',
#     'threeMinRecapFr': '/fr/video/recap-leafs-at-bruins-4-22-24-6351440955112',
#     'gameCenterLink': '/gamecenter/tor-vs-bos/2024/04/22/2023030122'},
#    {'id': 2023030142,
#     'season': 20232024,
#     'gameType': 3,
#     'venue': {'default': 'PNC Arena'},
#     'neutralSite': False,
#     'startTimeUTC': '2024-04-22T23:30:00Z',
#     'easternUTCOffset': '-04:00',
#     'venueUTCOffset': '-04:00',
#     'venueTimezone': 'US/Eastern',
#     'gameState': 'OFF',
#     'gameScheduleState': 'OK',
#     'tvBroadcasts': [{'id': 307,
#       'market': 'N',
#       'countryCode': 'US',
#       'network': 'ESPN2',
#       'sequenceNumber': 3},
#      {'id': 283,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'SN360',
#       'sequenceNumber': 23},
#      {'id': 291,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'TVAS2',
#       'sequenceNumber': 33},
#      {'id': 375,
#       'market': 'H',
#       'countryCode': 'US',
#       'network': 'BSSO',
#       'sequenceNumber': 70},
#      {'id': 409,
#       'market': 'A',
#       'countryCode': 'US',
#       'network': 'MSGSN',
#       'sequenceNumber': 88}],
#     'awayTeam': {'id': 2,
#      'placeName': {'default': 'New York'},
#      'abbrev': 'NYI',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/NYI_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/NYI_dark.svg',
#      'awaySplitSquad': False,
#      'score': 3},
#     'homeTeam': {'id': 12,
#      'placeName': {'default': 'Carolina', 'fr': 'Caroline'},
#      'abbrev': 'CAR',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/CAR_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/CAR_dark.svg',
#      'homeSplitSquad': False,
#      'score': 5},
#     'periodDescriptor': {'number': 3,
#      'periodType': 'REG',
#      'maxRegulationPeriods': 3},
#     'gameOutcome': {'lastPeriodType': 'REG'},
#     'winningGoalie': {'playerId': 8475883,
#      'firstInitial': {'default': 'F.'},
#      'lastName': {'default': 'Andersen'}},
#     'winningGoalScorer': {'playerId': 8476921,
#      'firstInitial': {'default': 'J.'},
#      'lastName': {'default': 'Martinook'}},
#     'seriesStatus': {'round': 1,
#      'seriesAbbrev': 'R1',
#      'seriesTitle': '1st Round',
#      'seriesLetter': 'D',
#      'neededToWin': 4,
#      'topSeedTeamAbbrev': 'CAR',
#      'topSeedWins': 2,
#      'bottomSeedTeamAbbrev': 'NYI',
#      'bottomSeedWins': 0,
#      'gameNumberOfSeries': 2},
#     'seriesUrl': '/schedule/playoff-series/2024/series-d/hurricanes-vs-islanders',
#     'threeMinRecap': '/video/recap-islanders-at-hurricanes-4-22-24-6351440411112',
#     'threeMinRecapFr': '/fr/video/recap-islanders-at-hurricanes-4-22-24-6351441686112',
#     'gameCenterLink': '/gamecenter/nyi-vs-car/2024/04/22/2023030142'},
#    {'id': 2023030151,
#     'season': 20232024,
#     'gameType': 3,
#     'venue': {'default': 'American Airlines Center'},
#     'neutralSite': False,
#     'startTimeUTC': '2024-04-23T01:30:00Z',
#     'easternUTCOffset': '-04:00',
#     'venueUTCOffset': '-05:00',
#     'venueTimezone': 'US/Central',
#     'gameState': 'OFF',
#     'gameScheduleState': 'OK',
#     'tvBroadcasts': [{'id': 309,
#       'market': 'N',
#       'countryCode': 'US',
#       'network': 'ESPN',
#       'sequenceNumber': 2},
#      {'id': 283,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'SN360',
#       'sequenceNumber': 23},
#      {'id': 281,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'TVAS',
#       'sequenceNumber': 31},
#      {'id': 285,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'FX-CA',
#       'sequenceNumber': 32},
#      {'id': 349,
#       'market': 'H',
#       'countryCode': 'US',
#       'network': 'BSSW',
#       'sequenceNumber': 61},
#      {'id': 521,
#       'market': 'A',
#       'countryCode': 'US',
#       'network': 'SCRIPPS',
#       'sequenceNumber': 87}],
#     'awayTeam': {'id': 54,
#      'placeName': {'default': 'Vegas'},
#      'abbrev': 'VGK',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/VGK_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/VGK_dark.svg',
#      'awaySplitSquad': False,
#      'score': 4},
#     'homeTeam': {'id': 25,
#      'placeName': {'default': 'Dallas'},
#      'abbrev': 'DAL',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/DAL_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/DAL_dark.svg',
#      'homeSplitSquad': False,
#      'score': 3},
#     'periodDescriptor': {'number': 3,
#      'periodType': 'REG',
#      'maxRegulationPeriods': 3},
#     'gameOutcome': {'lastPeriodType': 'REG'},
#     'winningGoalie': {'playerId': 8480313,
#      'firstInitial': {'default': 'L.'},
#      'lastName': {'default': 'Thompson'}},
#     'winningGoalScorer': {'playerId': 8475188,
#      'firstInitial': {'default': 'B.'},
#      'lastName': {'default': 'McNabb'}},
#     'seriesStatus': {'round': 1,
#      'seriesAbbrev': 'R1',
#      'seriesTitle': '1st Round',
#      'seriesLetter': 'E',
#      'neededToWin': 4,
#      'topSeedTeamAbbrev': 'DAL',
#      'topSeedWins': 0,
#      'bottomSeedTeamAbbrev': 'VGK',
#      'bottomSeedWins': 1,
#      'gameNumberOfSeries': 1},
#     'seriesUrl': '/schedule/playoff-series/2024/series-e/stars-vs-goldenknights',
#     'threeMinRecap': '/video/recap-golden-knights-at-stars-4-22-24-6351442562112',
#     'threeMinRecapFr': '/fr/video/recap-golden-knights-at-stars-4-22-24-6351445014112',
#     'gameCenterLink': '/gamecenter/vgk-vs-dal/2024/04/22/2023030151'},
#    {'id': 2023030181,
#     'season': 20232024,
#     'gameType': 3,
#     'venue': {'default': 'Rogers Place'},
#     'neutralSite': False,
#     'startTimeUTC': '2024-04-23T02:00:00Z',
#     'easternUTCOffset': '-04:00',
#     'venueUTCOffset': '-06:00',
#     'venueTimezone': 'America/Edmonton',
#     'gameState': 'OFF',
#     'gameScheduleState': 'OK',
#     'tvBroadcasts': [{'id': 307,
#       'market': 'N',
#       'countryCode': 'US',
#       'network': 'ESPN2',
#       'sequenceNumber': 3},
#      {'id': 282,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'SN',
#       'sequenceNumber': 21},
#      {'id': 4,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'CBC',
#       'sequenceNumber': 24},
#      {'id': 291,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'TVAS2',
#       'sequenceNumber': 33},
#      {'id': 341,
#       'market': 'A',
#       'countryCode': 'US',
#       'network': 'BSSC',
#       'sequenceNumber': 84}],
#     'awayTeam': {'id': 26,
#      'placeName': {'default': 'Los Angeles'},
#      'abbrev': 'LAK',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/LAK_20192020-20232024_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/LAK_20192020-20232024_dark.svg',
#      'awaySplitSquad': False,
#      'score': 4},
#     'homeTeam': {'id': 22,
#      'placeName': {'default': 'Edmonton'},
#      'abbrev': 'EDM',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/EDM_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/EDM_dark.svg',
#      'homeSplitSquad': False,
#      'score': 7},
#     'periodDescriptor': {'number': 3,
#      'periodType': 'REG',
#      'maxRegulationPeriods': 3},
#     'gameOutcome': {'lastPeriodType': 'REG'},
#     'winningGoalie': {'playerId': 8479973,
#      'firstInitial': {'default': 'S.'},
#      'lastName': {'default': 'Skinner'}},
#     'winningGoalScorer': {'playerId': 8477934,
#      'firstInitial': {'default': 'L.'},
#      'lastName': {'default': 'Draisaitl'}},
#     'seriesStatus': {'round': 1,
#      'seriesAbbrev': 'R1',
#      'seriesTitle': '1st Round',
#      'seriesLetter': 'H',
#      'neededToWin': 4,
#      'topSeedTeamAbbrev': 'EDM',
#      'topSeedWins': 1,
#      'bottomSeedTeamAbbrev': 'LAK',
#      'bottomSeedWins': 0,
#      'gameNumberOfSeries': 1},
#     'seriesUrl': '/schedule/playoff-series/2024/series-h/oilers-vs-kings',
#     'threeMinRecap': '/video/recap-kings-at-oilers-4-22-24-6351448830112',
#     'threeMinRecapFr': '/fr/video/recap-kings-at-oilers-4-22-24-6351450212112',
#     'gameCenterLink': '/gamecenter/lak-vs-edm/2024/04/22/2023030181'}]},
#  {'date': '2024-04-23',
#   'dayAbbrev': 'TUE',
#   'numberOfGames': 4,
#   'games': [{'id': 2023030132,
#     'season': 20232024,
#     'gameType': 3,
#     'venue': {'default': 'Madison Square Garden'},
#     'neutralSite': False,
#     'startTimeUTC': '2024-04-23T23:00:00Z',
#     'easternUTCOffset': '-04:00',
#     'venueUTCOffset': '-04:00',
#     'venueTimezone': 'America/New_York',
#     'gameState': 'OFF',
#     'gameScheduleState': 'OK',
#     'tvBroadcasts': [{'id': 309,
#       'market': 'N',
#       'countryCode': 'US',
#       'network': 'ESPN',
#       'sequenceNumber': 2},
#      {'id': 282,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'SN',
#       'sequenceNumber': 21},
#      {'id': 281,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'TVAS',
#       'sequenceNumber': 31},
#      {'id': 517,
#       'market': 'A',
#       'countryCode': 'US',
#       'network': 'MNMT',
#       'sequenceNumber': 67},
#      {'id': 409,
#       'market': 'H',
#       'countryCode': 'US',
#       'network': 'MSGSN',
#       'sequenceNumber': 88},
#      {'id': 27,
#       'market': 'H',
#       'countryCode': 'US',
#       'network': 'MSG',
#       'sequenceNumber': 97}],
#     'awayTeam': {'id': 15,
#      'placeName': {'default': 'Washington'},
#      'abbrev': 'WSH',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/WSH_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/WSH_dark.svg',
#      'awaySplitSquad': False,
#      'score': 3},
#     'homeTeam': {'id': 3,
#      'placeName': {'default': 'New York'},
#      'abbrev': 'NYR',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/NYR_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/NYR_dark.svg',
#      'homeSplitSquad': False,
#      'score': 4},
#     'periodDescriptor': {'number': 3,
#      'periodType': 'REG',
#      'maxRegulationPeriods': 3},
#     'gameOutcome': {'lastPeriodType': 'REG'},
#     'winningGoalie': {'playerId': 8478048,
#      'firstInitial': {'default': 'I.'},
#      'lastName': {'default': 'Shesterkin',
#       'cs': 'Šesťorkin',
#       'sk': 'Šesťorkin'}},
#     'winningGoalScorer': {'playerId': 8480817,
#      'firstInitial': {'default': 'K.'},
#      'lastName': {'default': 'Miller'}},
#     'seriesStatus': {'round': 1,
#      'seriesAbbrev': 'R1',
#      'seriesTitle': '1st Round',
#      'seriesLetter': 'C',
#      'neededToWin': 4,
#      'topSeedTeamAbbrev': 'NYR',
#      'topSeedWins': 2,
#      'bottomSeedTeamAbbrev': 'WSH',
#      'bottomSeedWins': 0,
#      'gameNumberOfSeries': 2},
#     'seriesUrl': '/schedule/playoff-series/2024/series-c/rangers-vs-capitals',
#     'threeMinRecap': '/video/recap-capitals-at-rangers-4-23-24-6351509543112',
#     'threeMinRecapFr': '/fr/video/recap-capitals-at-rangers-4-23-24-6351509070112',
#     'gameCenterLink': '/gamecenter/wsh-vs-nyr/2024/04/23/2023030132'},
#    {'id': 2023030112,
#     'season': 20232024,
#     'gameType': 3,
#     'venue': {'default': 'Amerant Bank Arena'},
#     'neutralSite': False,
#     'startTimeUTC': '2024-04-23T23:30:00Z',
#     'easternUTCOffset': '-04:00',
#     'venueUTCOffset': '-04:00',
#     'venueTimezone': 'US/Eastern',
#     'gameState': 'OFF',
#     'gameScheduleState': 'OK',
#     'tvBroadcasts': [{'id': 307,
#       'market': 'N',
#       'countryCode': 'US',
#       'network': 'ESPN2',
#       'sequenceNumber': 3},
#      {'id': 283,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'SN360',
#       'sequenceNumber': 23},
#      {'id': 291,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'TVAS2',
#       'sequenceNumber': 33},
#      {'id': 359,
#       'market': 'A',
#       'countryCode': 'US',
#       'network': 'BSSUN',
#       'sequenceNumber': 86},
#      {'id': 353,
#       'market': 'H',
#       'countryCode': 'US',
#       'network': 'BSFL',
#       'sequenceNumber': 92}],
#     'awayTeam': {'id': 14,
#      'placeName': {'default': 'Tampa Bay'},
#      'abbrev': 'TBL',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/TBL_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/TBL_dark.svg',
#      'awaySplitSquad': False,
#      'score': 2},
#     'homeTeam': {'id': 13,
#      'placeName': {'default': 'Florida', 'fr': 'Floride'},
#      'abbrev': 'FLA',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/FLA_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/FLA_dark.svg',
#      'homeSplitSquad': False,
#      'score': 3},
#     'periodDescriptor': {'number': 4,
#      'periodType': 'OT',
#      'maxRegulationPeriods': 3},
#     'gameOutcome': {'lastPeriodType': 'OT'},
#     'winningGoalie': {'playerId': 8475683,
#      'firstInitial': {'default': 'S.'},
#      'lastName': {'default': 'Bobrovsky',
#       'cs': 'Bobrovskij',
#       'sk': 'Bobrovskij'}},
#     'winningGoalScorer': {'playerId': 8477409,
#      'firstInitial': {'default': 'C.'},
#      'lastName': {'default': 'Verhaeghe'}},
#     'seriesStatus': {'round': 1,
#      'seriesAbbrev': 'R1',
#      'seriesTitle': '1st Round',
#      'seriesLetter': 'A',
#      'neededToWin': 4,
#      'topSeedTeamAbbrev': 'FLA',
#      'topSeedWins': 2,
#      'bottomSeedTeamAbbrev': 'TBL',
#      'bottomSeedWins': 0,
#      'gameNumberOfSeries': 2},
#     'seriesUrl': '/schedule/playoff-series/2024/series-a/panthers-vs-lightning',
#     'threeMinRecap': '/video/recap-lightning-at-panthers-4-23-24-6351522100112',
#     'gameCenterLink': '/gamecenter/tbl-vs-fla/2024/04/23/2023030112'},
#    {'id': 2023030162,
#     'season': 20232024,
#     'gameType': 3,
#     'venue': {'default': 'Canada Life Centre'},
#     'neutralSite': False,
#     'startTimeUTC': '2024-04-24T01:30:00Z',
#     'easternUTCOffset': '-04:00',
#     'venueUTCOffset': '-05:00',
#     'venueTimezone': 'America/Winnipeg',
#     'gameState': 'OFF',
#     'gameScheduleState': 'OK',
#     'tvBroadcasts': [{'id': 309,
#       'market': 'N',
#       'countryCode': 'US',
#       'network': 'ESPN',
#       'sequenceNumber': 2},
#      {'id': 4,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'CBC',
#       'sequenceNumber': 24},
#      {'id': 281,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'TVAS',
#       'sequenceNumber': 31},
#      {'id': 2,
#       'market': 'A',
#       'countryCode': 'US',
#       'network': 'ALT',
#       'sequenceNumber': 53}],
#     'awayTeam': {'id': 21,
#      'placeName': {'default': 'Colorado'},
#      'abbrev': 'COL',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/COL_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/COL_dark.svg',
#      'awaySplitSquad': False,
#      'score': 5},
#     'homeTeam': {'id': 52,
#      'placeName': {'default': 'Winnipeg'},
#      'abbrev': 'WPG',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/WPG_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/WPG_dark.svg',
#      'homeSplitSquad': False,
#      'score': 2},
#     'periodDescriptor': {'number': 3,
#      'periodType': 'REG',
#      'maxRegulationPeriods': 3},
#     'gameOutcome': {'lastPeriodType': 'REG'},
#     'winningGoalie': {'playerId': 8480382,
#      'firstInitial': {'default': 'A.'},
#      'lastName': {'default': 'Georgiev',
#       'cs': 'Georgijev',
#       'fi': 'Georgijev',
#       'sk': 'Georgijev'}},
#     'winningGoalScorer': {'playerId': 8470610,
#      'firstInitial': {'default': 'Z.'},
#      'lastName': {'default': 'Parise'}},
#     'seriesStatus': {'round': 1,
#      'seriesAbbrev': 'R1',
#      'seriesTitle': '1st Round',
#      'seriesLetter': 'F',
#      'neededToWin': 4,
#      'topSeedTeamAbbrev': 'WPG',
#      'topSeedWins': 1,
#      'bottomSeedTeamAbbrev': 'COL',
#      'bottomSeedWins': 1,
#      'gameNumberOfSeries': 2},
#     'seriesUrl': '/schedule/playoff-series/2024/series-f/jets-vs-avalanche',
#     'threeMinRecap': '/video/recap-avalanche-at-jets-4-23-24-6351528368112',
#     'gameCenterLink': '/gamecenter/col-vs-wpg/2024/04/23/2023030162'},
#    {'id': 2023030172,
#     'season': 20232024,
#     'gameType': 3,
#     'venue': {'default': 'Rogers Arena'},
#     'neutralSite': False,
#     'startTimeUTC': '2024-04-24T02:00:00Z',
#     'easternUTCOffset': '-04:00',
#     'venueUTCOffset': '-07:00',
#     'venueTimezone': 'America/Vancouver',
#     'gameState': 'OFF',
#     'gameScheduleState': 'OK',
#     'tvBroadcasts': [{'id': 307,
#       'market': 'N',
#       'countryCode': 'US',
#       'network': 'ESPN2',
#       'sequenceNumber': 3},
#      {'id': 282,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'SN',
#       'sequenceNumber': 21},
#      {'id': 291,
#       'market': 'N',
#       'countryCode': 'CA',
#       'network': 'TVAS2',
#       'sequenceNumber': 33},
#      {'id': 375,
#       'market': 'A',
#       'countryCode': 'US',
#       'network': 'BSSO',
#       'sequenceNumber': 70}],
#     'awayTeam': {'id': 18,
#      'placeName': {'default': 'Nashville'},
#      'abbrev': 'NSH',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/NSH_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/NSH_dark.svg',
#      'awaySplitSquad': False,
#      'score': 4},
#     'homeTeam': {'id': 23,
#      'placeName': {'default': 'Vancouver'},
#      'abbrev': 'VAN',
#      'logo': 'https://assets.nhle.com/logos/nhl/svg/VAN_light.svg',
#      'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/VAN_dark.svg',
#      'homeSplitSquad': False,
#      'score': 1},
#     'periodDescriptor': {'number': 3,
#      'periodType': 'REG',
#      'maxRegulationPeriods': 3},
#     'gameOutcome': {'lastPeriodType': 'REG'},
#     'winningGoalie': {'playerId': 8477424,
#      'firstInitial': {'default': 'J.'},
#      'lastName': {'default': 'Saros'}},
#     'winningGoalScorer': {'playerId': 8476887,
#      'firstInitial': {'default': 'F.'},
#      'lastName': {'default': 'Forsberg'}},
#     'seriesStatus': {'round': 1,
#      'seriesAbbrev': 'R1',
#      'seriesTitle': '1st Round',
#      'seriesLetter': 'G',
#      'neededToWin': 4,
#      'topSeedTeamAbbrev': 'VAN',
#      'topSeedWins': 1,
#      'bottomSeedTeamAbbrev': 'NSH',
#      'bottomSeedWins': 1,
#      'gameNumberOfSeries': 2},
#     'seriesUrl': '/schedule/playoff-series/2024/series-g/canucks-vs-predators',
#     'threeMinRecap': '/video/recap-predators-at-canucks-4-23-24-6351531801112',
#     'gameCenterLink': '/gamecenter/nsh-vs-van/2024/04/23/2023030172'}]}]

# %%
#convert the game info dictionary into a dataframe that shows the date, day of week abbrev, the number of games that night and a nested table of games
df_game_info= pd.DataFrame(game_dates)
df_game_info = df_game_info[df_game_info['numberOfGames'] != 0]
#df_game_info = df_game_info.convert_dtypes()
df_game_info
# Out:
#          date dayAbbrev  numberOfGames  \
# 0  2024-04-17       WED              4
# 1  2024-04-18       THU              6
# 3  2024-04-20       SAT              2
# 4  2024-04-21       SUN              4
# 5  2024-04-22       MON              4
# 6  2024-04-23       TUE              4
#
#                                                games
# 0  [{'id': 2023021303, 'season': 20232024, 'gameT...
# 1  [{'id': 2023021307, 'season': 20232024, 'gameT...
# 3  [{'id': 2023030141, 'season': 20232024, 'gameT...
# 4  [{'id': 2023030111, 'season': 20232024, 'gameT...
# 5  [{'id': 2023030122, 'season': 20232024, 'gameT...
# 6  [{'id': 2023030132, 'season': 20232024, 'gameT...

# %%
#Normalize (separates the data in the curly brackets out into separate columns) the data in the games column to see the games
#creates a table where every row is each date from the week and each cell contains game info
game_data =pd.json_normalize(df_game_info['games'])
game_data= pd.DataFrame(game_data)
game_data.head()
# #end_value = len(game_data.columns)
# Out:
#                                                    0  \
# 0  {'id': 2023021303, 'season': 20232024, 'gameTy...
# 1  {'id': 2023021307, 'season': 20232024, 'gameTy...
# 2  {'id': 2023030141, 'season': 20232024, 'gameTy...
# 3  {'id': 2023030111, 'season': 20232024, 'gameTy...
# 4  {'id': 2023030122, 'season': 20232024, 'gameTy...
#
#                                                    1  \
# 0  {'id': 2023021304, 'season': 20232024, 'gameTy...
# 1  {'id': 2023021308, 'season': 20232024, 'gameTy...
# 2  {'id': 2023030121, 'season': 20232024, 'gameTy...
# 3  {'id': 2023030131, 'season': 20232024, 'gameTy...
# 4  {'id': 2023030142, 'season': 20232024, 'gameTy...
#
#                                                    2  \
# 0  {'id': 2023021305, 'season': 20232024, 'gameTy...
# 1  {'id': 2023021309, 'season': 20232024, 'gameTy...
# 2                                               None
# 3  {'id': 2023030161, 'season': 20232024, 'gameTy...
# 4  {'id': 2023030151, 'season': 20232024, 'gameTy...
#
#                                                    3  \
# 0  {'id': 2023021306, 'season': 20232024, 'gameTy...
# 1  {'id': 2023021310, 'season': 20232024, 'gameTy...
# 2                                               None
# 3  {'id': 2023030171, 'season': 20232024, 'gameTy...
# 4  {'id': 2023030181, 'season': 20232024, 'gameTy...
#
#                                                    4  \
# 0                                               None
# 1  {'id': 2023021311, 'season': 20232024, 'gameTy...
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                                    5
# 0                                               None
# 1  {'id': 2023021312, 'season': 20232024, 'gameTy...
# 2                                               None
# 3                                               None
# 4                                               None

# %%
#in order to extract the data properly, it needs to be stored in a dictionary. This extracts each of the games from the cells

dfs = {}

# Loop through the iterations (30 times)
for i in range(0, len(game_data.columns)): 
    api_response = game_dates
    
    if api_response is not None:
        # Extract relevant data from the API response and normalize it
        game_info = pd.json_normalize(game_data[i])
        
        # Create a DataFrame for this iteration
        df_name = f'game_test{i}'  # Generate a unique variable name
        dfs[df_name] = pd.DataFrame(game_info)
    else:
        # Handle the case where the API request failed
        print(f"API request failed for index {i}")

# %%
#Then I combine all of the dfs in the list by concatenation to create a single df. now all of the game data is spread out across each row. 
combined_df = pd.concat(dfs.values(), ignore_index=True)
combined_df.head()
# Out:
#              id      season  gameType neutralSite          startTimeUTC  \
# 0  2.022021e+09  20222023.0       2.0       False  2023-04-14T23:30:00Z
# 1  2.022030e+09  20222023.0       3.0       False  2023-04-17T23:00:00Z
# 2  2.022030e+09  20222023.0       3.0       False  2023-04-18T23:00:00Z
# 3  2.022030e+09  20222023.0       3.0       False  2023-04-19T23:00:00Z
# 4  2.022030e+09  20222023.0       3.0       False  2023-04-20T23:00:00Z
#
#   easternUTCOffset venueUTCOffset    venueTimezone gameState  \
# 0           -04:00         -04:00       US/Eastern       OFF
# 1           -04:00         -04:00       US/Eastern       OFF
# 2           -04:00         -04:00       US/Eastern       OFF
# 3           -04:00         -04:00       US/Eastern       OFF
# 4           -04:00         -04:00  America/Toronto       OFF
#
#   gameScheduleState                                       tvBroadcasts  \
# 0                OK  [{'id': 28, 'market': 'A', 'countryCode': 'US'...
# 1                OK                                                 []
# 2                OK                                                 []
# 3                OK                                                 []
# 4                OK                                                 []
#
#                              threeMinRecap  \
# 0       /video/recap-buf-5-cbj-2-343561710
# 1       /video/recap-car-2-nyi-1-343628614
# 2       /video/recap-nyr-5-njd-1-343668214
# 3  /video/recap-car-4-nyi-3-f-ot-343701784
# 4       /video/recap-tor-7-tbl-2-343738742
#
#                                  gameCenterLink      venue.default  \
# 0  /gamecenter/buf-vs-cbj/2023/04/14/2022020547   Nationwide Arena
# 1  /gamecenter/nyi-vs-car/2023/04/17/2022030131          PNC Arena
# 2  /gamecenter/nyr-vs-njd/2023/04/18/2022030141  Prudential Center
# 3  /gamecenter/nyi-vs-car/2023/04/19/2022030132          PNC Arena
# 4  /gamecenter/tbl-vs-tor/2023/04/20/2022030122   Scotiabank Arena
#
#    awayTeam.id awayTeam.placeName.default awayTeam.abbrev  \
# 0          7.0                    Buffalo             BUF
# 1          2.0                   New York             NYI
# 2          3.0                   New York             NYR
# 3          2.0                   New York             NYI
# 4         14.0                  Tampa Bay             TBL
#
#                                        awayTeam.logo  \
# 0  https://assets.nhle.com/logos/nhl/svg/BUF_ligh...
# 1  https://assets.nhle.com/logos/nhl/svg/NYI_ligh...
# 2  https://assets.nhle.com/logos/nhl/svg/NYR_ligh...
# 3  https://assets.nhle.com/logos/nhl/svg/NYI_ligh...
# 4  https://assets.nhle.com/logos/nhl/svg/TBL_ligh...
#
#                                    awayTeam.darkLogo awayTeam.awaySplitSquad  \
# 0  https://assets.nhle.com/logos/nhl/svg/BUF_dark...                   False
# 1  https://assets.nhle.com/logos/nhl/svg/NYI_dark...                   False
# 2  https://assets.nhle.com/logos/nhl/svg/NYR_dark...                   False
# 3  https://assets.nhle.com/logos/nhl/svg/NYI_dark...                   False
# 4  https://assets.nhle.com/logos/nhl/svg/TBL_dark...                   False
#
#    awayTeam.score  homeTeam.id homeTeam.placeName.default homeTeam.abbrev  \
# 0             5.0         29.0                   Columbus             CBJ
# 1             1.0         12.0                   Carolina             CAR
# 2             5.0          1.0                 New Jersey             NJD
# 3             3.0         12.0                   Carolina             CAR
# 4             2.0         10.0                    Toronto             TOR
#
#                                        homeTeam.logo  \
# 0  https://assets.nhle.com/logos/nhl/svg/CBJ_ligh...
# 1  https://assets.nhle.com/logos/nhl/svg/CAR_ligh...
# 2  https://assets.nhle.com/logos/nhl/svg/NJD_ligh...
# 3  https://assets.nhle.com/logos/nhl/svg/CAR_ligh...
# 4  https://assets.nhle.com/logos/nhl/svg/TOR_ligh...
#
#                                    homeTeam.darkLogo homeTeam.homeSplitSquad  \
# 0  https://assets.nhle.com/logos/nhl/svg/CBJ_dark...                   False
# 1  https://assets.nhle.com/logos/nhl/svg/CAR_dark...                   False
# 2  https://assets.nhle.com/logos/nhl/svg/NJD_dark...                   False
# 3  https://assets.nhle.com/logos/nhl/svg/CAR_dark...                   False
# 4  https://assets.nhle.com/logos/nhl/svg/TOR_dark...                   False
#
#    homeTeam.score  periodDescriptor.number periodDescriptor.periodType  \
# 0             2.0                      3.0                         REG
# 1             2.0                      3.0                         REG
# 2             1.0                      3.0                         REG
# 3             4.0                      4.0                          OT
# 4             7.0                      3.0                         REG
#
#    periodDescriptor.maxRegulationPeriods gameOutcome.lastPeriodType  \
# 0                                    3.0                        REG
# 1                                    3.0                        REG
# 2                                    3.0                        REG
# 3                                    3.0                         OT
# 4                                    3.0                        REG
#
#    winningGoalie.playerId winningGoalie.firstInitial.default  \
# 0               8482221.0                                 D.
# 1               8477293.0                                 A.
# 2               8478048.0                                 I.
# 3               8477293.0                                 A.
# 4               8478492.0                                 I.
#
#   winningGoalie.lastName.default  winningGoalScorer.playerId  \
# 0                           Levi                   8477949.0
# 1                         Raanta                   8476474.0
# 2                     Shesterkin                   8475184.0
# 3                         Raanta                   8475855.0
# 4                       Samsonov                   8477939.0
#
#   winningGoalScorer.firstInitial.default winningGoalScorer.lastName.default  \
# 0                                     A.                               Tuch
# 1                                     S.                             Noesen
# 2                                     C.                            Kreider
# 3                                     J.                               Fast
# 4                                     W.                           Nylander
#
#                                            seriesUrl homeTeam.placeName.fr  \
# 0                                                NaN                   NaN
# 1  /schedule/playoff-series/2023/series-c/hurrica...              Caroline
# 2  /schedule/playoff-series/2023/series-d/devils-...                   NaN
# 3  /schedule/playoff-series/2023/series-c/hurrica...              Caroline
# 4  /schedule/playoff-series/2023/series-b/maplele...                   NaN
#
#    seriesStatus.round seriesStatus.seriesAbbrev seriesStatus.seriesTitle  \
# 0                 NaN                       NaN                      NaN
# 1                 1.0                        R1                1st Round
# 2                 1.0                        R1                1st Round
# 3                 1.0                        R1                1st Round
# 4                 1.0                        R1                1st Round
#
#   seriesStatus.seriesLetter  seriesStatus.neededToWin  \
# 0                       NaN                       NaN
# 1                         C                       4.0
# 2                         D                       4.0
# 3                         C                       4.0
# 4                         B                       4.0
#
#   seriesStatus.topSeedTeamAbbrev  seriesStatus.topSeedWins  \
# 0                            NaN                       NaN
# 1                            CAR                       1.0
# 2                            NJD                       0.0
# 3                            CAR                       2.0
# 4                            TOR                       1.0
#
#   seriesStatus.bottomSeedTeamAbbrev  seriesStatus.bottomSeedWins  \
# 0                               NaN                          NaN
# 1                               NYI                          0.0
# 2                               NYR                          1.0
# 3                               NYI                          0.0
# 4                               TBL                          1.0
#
#    seriesStatus.gameNumberOfSeries winningGoalie.lastName.cs  \
# 0                              NaN                       NaN
# 1                              1.0                       NaN
# 2                              1.0                 Šesťorkin
# 3                              2.0                       NaN
# 4                              2.0                       NaN
#
#   winningGoalie.lastName.sk winningGoalScorer.lastName.cs  \
# 0                       NaN                           NaN
# 1                       NaN                           NaN
# 2                 Šesťorkin                           NaN
# 3                       NaN                         Fasth
# 4                       NaN                           NaN
#
#   winningGoalScorer.lastName.de winningGoalScorer.lastName.fi  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                         Fasth                         Fasth
# 4                           NaN                           NaN
#
#   winningGoalScorer.lastName.sk winningGoalScorer.lastName.sv  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                         Fasth                         Fasth
# 4                           NaN                           NaN
#
#   winningGoalie.lastName.fi awayTeam.placeName.fr  periodDescriptor.otPeriods
# 0                       NaN                   NaN                         NaN
# 1                       NaN                   NaN                         NaN
# 2                       NaN                   NaN                         NaN
# 3                       NaN                   NaN                         NaN
# 4                       NaN                   NaN                         NaN

# %%
combined_df.dropna(how='all', inplace=True)

# %%
combined_df['id']
# Out:
# 0     2.022021e+09
# 1     2.022030e+09
# 2     2.022030e+09
# 3     2.022030e+09
# 4     2.022030e+09
# 5     2.022020e+09
# 6     2.022030e+09
# 7     2.022030e+09
# 8     2.022030e+09
# 9     2.022030e+09
# 11    2.022030e+09
# 12    2.022030e+09
# 13    2.022030e+09
# 14    2.022030e+09
# 16    2.022030e+09
# 17    2.022030e+09
# 18    2.022030e+09
# 19    2.022030e+09
# Name: id, dtype: float64

# %%
combined_df = combined_df[['id', 'season', 'startTimeUTC', 'gameType', 'awayTeam.id', 'awayTeam.abbrev', 'awayTeam.logo', 
                        'homeTeam.id', 'homeTeam.abbrev','homeTeam.logo', 'homeTeam.placeName.default', 'awayTeam.placeName.default',
                        'awayTeam.score', 'homeTeam.score', 'winningGoalScorer.playerId', 
                        'winningGoalie.playerId', 'gameState']]
combined_df=combined_df.convert_dtypes()
combined_df['id'] = combined_df['id'].astype(str)
combined_df['link_prefix'] = 'https://api-web.nhle.com/v1/gamecenter/'
combined_df['link_suffix'] = '/play-by-play'
combined_df['link']=combined_df['link_prefix'] + combined_df['id'] + combined_df['link_suffix']

# Assuming '<NA>' is a string, replace it with np.nan
combined_df['id'].replace('<NA>', np.nan, inplace=True)
# Drop rows with NaN values in the 'link' column
combined_df = combined_df.dropna(subset=['id'])
combined_df = combined_df.query('gameState == "OFF"')
combined_df['startTimeUTC'] = pd.to_datetime(combined_df['startTimeUTC'])
combined_df = combined_df.rename(columns = {'id':'game_id'})
combined_df.head()
# Out:
#       game_id    season              startTimeUTC  gameType  awayTeam.id  \
# 0  2022020547  20222023 2023-04-14 23:30:00+00:00         2            7
# 1  2022030131  20222023 2023-04-17 23:00:00+00:00         3            2
# 2  2022030141  20222023 2023-04-18 23:00:00+00:00         3            3
# 3  2022030132  20222023 2023-04-19 23:00:00+00:00         3            2
# 4  2022030122  20222023 2023-04-20 23:00:00+00:00         3           14
#
#   awayTeam.abbrev                                      awayTeam.logo  \
# 0             BUF  https://assets.nhle.com/logos/nhl/svg/BUF_ligh...
# 1             NYI  https://assets.nhle.com/logos/nhl/svg/NYI_ligh...
# 2             NYR  https://assets.nhle.com/logos/nhl/svg/NYR_ligh...
# 3             NYI  https://assets.nhle.com/logos/nhl/svg/NYI_ligh...
# 4             TBL  https://assets.nhle.com/logos/nhl/svg/TBL_ligh...
#
#    homeTeam.id homeTeam.abbrev  \
# 0           29             CBJ
# 1           12             CAR
# 2            1             NJD
# 3           12             CAR
# 4           10             TOR
#
#                                        homeTeam.logo  \
# 0  https://assets.nhle.com/logos/nhl/svg/CBJ_ligh...
# 1  https://assets.nhle.com/logos/nhl/svg/CAR_ligh...
# 2  https://assets.nhle.com/logos/nhl/svg/NJD_ligh...
# 3  https://assets.nhle.com/logos/nhl/svg/CAR_ligh...
# 4  https://assets.nhle.com/logos/nhl/svg/TOR_ligh...
#
#   homeTeam.placeName.default awayTeam.placeName.default  awayTeam.score  \
# 0                   Columbus                    Buffalo               5
# 1                   Carolina                   New York               1
# 2                 New Jersey                   New York               5
# 3                   Carolina                   New York               3
# 4                    Toronto                  Tampa Bay               2
#
#    homeTeam.score  winningGoalScorer.playerId  winningGoalie.playerId  \
# 0               2                     8477949                 8482221
# 1               2                     8476474                 8477293
# 2               1                     8475184                 8478048
# 3               4                     8475855                 8477293
# 4               7                     8477939                 8478492
#
#   gameState                              link_prefix    link_suffix  \
# 0       OFF  https://api-web.nhle.com/v1/gamecenter/  /play-by-play
# 1       OFF  https://api-web.nhle.com/v1/gamecenter/  /play-by-play
# 2       OFF  https://api-web.nhle.com/v1/gamecenter/  /play-by-play
# 3       OFF  https://api-web.nhle.com/v1/gamecenter/  /play-by-play
# 4       OFF  https://api-web.nhle.com/v1/gamecenter/  /play-by-play
#
#                                                 link
# 0  https://api-web.nhle.com/v1/gamecenter/2022020...
# 1  https://api-web.nhle.com/v1/gamecenter/2022030...
# 2  https://api-web.nhle.com/v1/gamecenter/2022030...
# 3  https://api-web.nhle.com/v1/gamecenter/2022030...
# 4  https://api-web.nhle.com/v1/gamecenter/2022030...

# %%
combined_df

# %%
# Specify the UTC time zone
utc_timezone = pytz.utc

# Specify the target time zone (Eastern Time)
eastern_timezone = pytz.timezone('America/New_York')

# Convert 'startTimeUTC' to Eastern Time
combined_df['game_date'] = combined_df['startTimeUTC'].dt.tz_convert(eastern_timezone)
combined_df['game_date'] = pd.to_datetime(combined_df['game_date'])
combined_df['game_date'] = combined_df['game_date'].dt.strftime('%Y-%m-%d')
combined_df.drop('startTimeUTC', axis=1, inplace=True)
# combined_df = combined_df[combined_df['game_date'] == formatted_date]

# print("combined_df done")
combined_df.head()
# Out:
#       game_id    season  gameType  awayTeam.id awayTeam.abbrev  \
# 0  2022020547  20222023         2            7             BUF
# 1  2022030131  20222023         3            2             NYI
# 2  2022030141  20222023         3            3             NYR
# 3  2022030132  20222023         3            2             NYI
# 4  2022030122  20222023         3           14             TBL
#
#                                        awayTeam.logo  homeTeam.id  \
# 0  https://assets.nhle.com/logos/nhl/svg/BUF_ligh...           29
# 1  https://assets.nhle.com/logos/nhl/svg/NYI_ligh...           12
# 2  https://assets.nhle.com/logos/nhl/svg/NYR_ligh...            1
# 3  https://assets.nhle.com/logos/nhl/svg/NYI_ligh...           12
# 4  https://assets.nhle.com/logos/nhl/svg/TBL_ligh...           10
#
#   homeTeam.abbrev                                      homeTeam.logo  \
# 0             CBJ  https://assets.nhle.com/logos/nhl/svg/CBJ_ligh...
# 1             CAR  https://assets.nhle.com/logos/nhl/svg/CAR_ligh...
# 2             NJD  https://assets.nhle.com/logos/nhl/svg/NJD_ligh...
# 3             CAR  https://assets.nhle.com/logos/nhl/svg/CAR_ligh...
# 4             TOR  https://assets.nhle.com/logos/nhl/svg/TOR_ligh...
#
#   homeTeam.placeName.default awayTeam.placeName.default  awayTeam.score  \
# 0                   Columbus                    Buffalo               5
# 1                   Carolina                   New York               1
# 2                 New Jersey                   New York               5
# 3                   Carolina                   New York               3
# 4                    Toronto                  Tampa Bay               2
#
#    homeTeam.score  winningGoalScorer.playerId  winningGoalie.playerId  \
# 0               2                     8477949                 8482221
# 1               2                     8476474                 8477293
# 2               1                     8475184                 8478048
# 3               4                     8475855                 8477293
# 4               7                     8477939                 8478492
#
#   gameState                              link_prefix    link_suffix  \
# 0       OFF  https://api-web.nhle.com/v1/gamecenter/  /play-by-play
# 1       OFF  https://api-web.nhle.com/v1/gamecenter/  /play-by-play
# 2       OFF  https://api-web.nhle.com/v1/gamecenter/  /play-by-play
# 3       OFF  https://api-web.nhle.com/v1/gamecenter/  /play-by-play
# 4       OFF  https://api-web.nhle.com/v1/gamecenter/  /play-by-play
#
#                                                 link   game_date
# 0  https://api-web.nhle.com/v1/gamecenter/2022020...  2023-04-14
# 1  https://api-web.nhle.com/v1/gamecenter/2022030...  2023-04-17
# 2  https://api-web.nhle.com/v1/gamecenter/2022030...  2023-04-18
# 3  https://api-web.nhle.com/v1/gamecenter/2022030...  2023-04-19
# 4  https://api-web.nhle.com/v1/gamecenter/2022030...  2023-04-20

# %%
combined_df.sort_values(by='game_id')
# Out:
#        game_id    season  gameType  awayTeam.id awayTeam.abbrev  \
# 5   2022020320  20222023         2           21             COL
# 0   2022020547  20222023         2            7             BUF
# 6   2022030111  20222023         3           13             FLA
# 8   2022030112  20222023         3           13             FLA
# 7   2022030121  20222023         3           14             TBL
# 4   2022030122  20222023         3           14             TBL
# 1   2022030131  20222023         3            2             NYI
# 3   2022030132  20222023         3            2             NYI
# 2   2022030141  20222023         3            3             NYR
# 9   2022030142  20222023         3            3             NYR
# 17  2022030151  20222023         3           55             SEA
# 14  2022030152  20222023         3           55             SEA
# 11  2022030161  20222023         3           30             MIN
# 13  2022030162  20222023         3           30             MIN
# 12  2022030171  20222023         3           52             WPG
# 19  2022030172  20222023         3           52             WPG
# 16  2022030181  20222023         3           26             LAK
# 18  2022030182  20222023         3           26             LAK
#
#                                         awayTeam.logo  homeTeam.id  \
# 5   https://assets.nhle.com/logos/nhl/svg/COL_ligh...           18
# 0   https://assets.nhle.com/logos/nhl/svg/BUF_ligh...           29
# 6   https://assets.nhle.com/logos/nhl/svg/FLA_ligh...            6
# 8   https://assets.nhle.com/logos/nhl/svg/FLA_ligh...            6
# 7   https://assets.nhle.com/logos/nhl/svg/TBL_ligh...           10
# 4   https://assets.nhle.com/logos/nhl/svg/TBL_ligh...           10
# 1   https://assets.nhle.com/logos/nhl/svg/NYI_ligh...           12
# 3   https://assets.nhle.com/logos/nhl/svg/NYI_ligh...           12
# 2   https://assets.nhle.com/logos/nhl/svg/NYR_ligh...            1
# 9   https://assets.nhle.com/logos/nhl/svg/NYR_ligh...            1
# 17  https://assets.nhle.com/logos/nhl/svg/SEA_ligh...           21
# 14  https://assets.nhle.com/logos/nhl/svg/SEA_ligh...           21
# 11  https://assets.nhle.com/logos/nhl/svg/MIN_ligh...           25
# 13  https://assets.nhle.com/logos/nhl/svg/MIN_ligh...           25
# 12  https://assets.nhle.com/logos/nhl/svg/WPG_ligh...           54
# 19  https://assets.nhle.com/logos/nhl/svg/WPG_ligh...           54
# 16  https://assets.nhle.com/logos/nhl/svg/LAK_2019...           22
# 18  https://assets.nhle.com/logos/nhl/svg/LAK_2019...           22
#
#    homeTeam.abbrev                                      homeTeam.logo  \
# 5              NSH  https://assets.nhle.com/logos/nhl/svg/NSH_ligh...
# 0              CBJ  https://assets.nhle.com/logos/nhl/svg/CBJ_ligh...
# 6              BOS  https://assets.nhle.com/logos/nhl/svg/BOS_2008...
# 8              BOS  https://assets.nhle.com/logos/nhl/svg/BOS_2008...
# 7              TOR  https://assets.nhle.com/logos/nhl/svg/TOR_ligh...
# 4              TOR  https://assets.nhle.com/logos/nhl/svg/TOR_ligh...
# 1              CAR  https://assets.nhle.com/logos/nhl/svg/CAR_ligh...
# 3              CAR  https://assets.nhle.com/logos/nhl/svg/CAR_ligh...
# 2              NJD  https://assets.nhle.com/logos/nhl/svg/NJD_ligh...
# 9              NJD  https://assets.nhle.com/logos/nhl/svg/NJD_ligh...
# 17             COL  https://assets.nhle.com/logos/nhl/svg/COL_ligh...
# 14             COL  https://assets.nhle.com/logos/nhl/svg/COL_ligh...
# 11             DAL  https://assets.nhle.com/logos/nhl/svg/DAL_ligh...
# 13             DAL  https://assets.nhle.com/logos/nhl/svg/DAL_ligh...
# 12             VGK  https://assets.nhle.com/logos/nhl/svg/VGK_ligh...
# 19             VGK  https://assets.nhle.com/logos/nhl/svg/VGK_ligh...
# 16             EDM  https://assets.nhle.com/logos/nhl/svg/EDM_ligh...
# 18             EDM  https://assets.nhle.com/logos/nhl/svg/EDM_ligh...
#
#    homeTeam.placeName.default awayTeam.placeName.default  awayTeam.score  \
# 5                   Nashville                   Colorado               4
# 0                    Columbus                    Buffalo               5
# 6                      Boston                    Florida               1
# 8                      Boston                    Florida               6
# 7                     Toronto                  Tampa Bay               7
# 4                     Toronto                  Tampa Bay               2
# 1                    Carolina                   New York               1
# 3                    Carolina                   New York               3
# 2                  New Jersey                   New York               5
# 9                  New Jersey                   New York               5
# 17                   Colorado                    Seattle               3
# 14                   Colorado                    Seattle               2
# 11                     Dallas                  Minnesota               3
# 13                     Dallas                  Minnesota               3
# 12                      Vegas                   Winnipeg               5
# 19                      Vegas                   Winnipeg               2
# 16                   Edmonton                Los Angeles               4
# 18                   Edmonton                Los Angeles               2
#
#     homeTeam.score  winningGoalScorer.playerId  winningGoalie.playerId  \
# 5                3                     8477492                 8480382
# 0                2                     8477949                 8482221
# 6                3                     8473419                 8476999
# 8                3                     8477409                 8479312
# 7                3                     8478010                 8476883
# 4                7                     8477939                 8478492
# 1                2                     8476474                 8477293
# 3                4                     8475855                 8477293
# 2                1                     8475184                 8478048
# 9                1                     8475184                 8478048
# 17               1                     8477505                 8475831
# 14               3                     8478038                 8480382
# 11               2                     8477451                 8479406
# 13               7                     8474149                 8479979
# 12               1                     8479400                 8476945
# 19               5                     8476905                 8476316
# 16               3                     8480113                 8476914
# 18               4                     8480011                 8479973
#
#    gameState                              link_prefix    link_suffix  \
# 5        OFF  https://api-web.nhle.com/v1/gamecenter/  /play-by-play
# 0        OFF  https://api-web.nhle.com/v1/gamecenter/  /play-by-play
# 6        OFF  https://api-web.nhle.com/v1/gamecenter/  /play-by-play
# 8        OFF  https://api-web.nhle.com/v1/gamecenter/  /play-by-play
# 7        OFF  https://api-web.nhle.com/v1/gamecenter/  /play-by-play
# 4        OFF  https://api-web.nhle.com/v1/gamecenter/  /play-by-play
# 1        OFF  https://api-web.nhle.com/v1/gamecenter/  /play-by-play
# 3        OFF  https://api-web.nhle.com/v1/gamecenter/  /play-by-play
# 2        OFF  https://api-web.nhle.com/v1/gamecenter/  /play-by-play
# 9        OFF  https://api-web.nhle.com/v1/gamecenter/  /play-by-play
# 17       OFF  https://api-web.nhle.com/v1/gamecenter/  /play-by-play
# 14       OFF  https://api-web.nhle.com/v1/gamecenter/  /play-by-play
# 11       OFF  https://api-web.nhle.com/v1/gamecenter/  /play-by-play
# 13       OFF  https://api-web.nhle.com/v1/gamecenter/  /play-by-play
# 12       OFF  https://api-web.nhle.com/v1/gamecenter/  /play-by-play
# 19       OFF  https://api-web.nhle.com/v1/gamecenter/  /play-by-play
# 16       OFF  https://api-web.nhle.com/v1/gamecenter/  /play-by-play
# 18       OFF  https://api-web.nhle.com/v1/gamecenter/  /play-by-play
#
#                                                  link   game_date
# 5   https://api-web.nhle.com/v1/gamecenter/2022020...  2023-04-14
# 0   https://api-web.nhle.com/v1/gamecenter/2022020...  2023-04-14
# 6   https://api-web.nhle.com/v1/gamecenter/2022030...  2023-04-17
# 8   https://api-web.nhle.com/v1/gamecenter/2022030...  2023-04-19
# 7   https://api-web.nhle.com/v1/gamecenter/2022030...  2023-04-18
# 4   https://api-web.nhle.com/v1/gamecenter/2022030...  2023-04-20
# 1   https://api-web.nhle.com/v1/gamecenter/2022030...  2023-04-17
# 3   https://api-web.nhle.com/v1/gamecenter/2022030...  2023-04-19
# 2   https://api-web.nhle.com/v1/gamecenter/2022030...  2023-04-18
# 9   https://api-web.nhle.com/v1/gamecenter/2022030...  2023-04-20
# 17  https://api-web.nhle.com/v1/gamecenter/2022030...  2023-04-18
# 14  https://api-web.nhle.com/v1/gamecenter/2022030...  2023-04-20
# 11  https://api-web.nhle.com/v1/gamecenter/2022030...  2023-04-17
# 13  https://api-web.nhle.com/v1/gamecenter/2022030...  2023-04-19
# 12  https://api-web.nhle.com/v1/gamecenter/2022030...  2023-04-18
# 19  https://api-web.nhle.com/v1/gamecenter/2022030...  2023-04-20
# 16  https://api-web.nhle.com/v1/gamecenter/2022030...  2023-04-17
# 18  https://api-web.nhle.com/v1/gamecenter/2022030...  2023-04-19

# %%
home_df = pd.DataFrame({
    'game_id': combined_df['game_id'],
    'team_id': combined_df['homeTeam.id'],
    'tri_code': combined_df['homeTeam.abbrev'],
    'team_name': combined_df['homeTeam.placeName.default'],
    'value': "home",
    'team_logo': combined_df['homeTeam.logo']
})

away_df =  pd.DataFrame({
    'game_id': combined_df['game_id'],
    'team_id': combined_df['awayTeam.id'],
    'tri_code': combined_df['awayTeam.abbrev'],
    'team_name': combined_df['awayTeam.placeName.default'],
    'value':"away",
    'team_logo':combined_df['awayTeam.logo']
})

# %%
#Roster Data
team_url = "https://api.nhle.com/stats/rest/en/team"

response = requests.get(team_url )
content = json.loads(response.content)

# Send an HTTP GET request to the specified URL
response = requests.get(team_url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # The response content can be accessed using response.text
    response_text = response.text
    #pprint(response_text)
else:
    print(f"Request failed with status code {response.status_code}")

json_data = json.loads(response_text)
# json_data.keys()

roster = json_data['data']

# %%
roster
# Out:
# [{'id': 11,
#   'franchiseId': 35,
#   'fullName': 'Atlanta Thrashers',
#   'leagueId': 133,
#   'rawTricode': 'ATL',
#   'triCode': 'ATL'},
#  {'id': 34,
#   'franchiseId': 26,
#   'fullName': 'Hartford Whalers',
#   'leagueId': 133,
#   'rawTricode': 'HFD',
#   'triCode': 'HFD'},
#  {'id': 31,
#   'franchiseId': 15,
#   'fullName': 'Minnesota North Stars',
#   'leagueId': 133,
#   'rawTricode': 'MNS',
#   'triCode': 'MNS'},
#  {'id': 32,
#   'franchiseId': 27,
#   'fullName': 'Quebec Nordiques',
#   'leagueId': 133,
#   'rawTricode': 'QUE',
#   'triCode': 'QUE'},
#  {'id': 33,
#   'franchiseId': 28,
#   'fullName': 'Winnipeg Jets (1979)',
#   'leagueId': 133,
#   'rawTricode': 'WIN',
#   'triCode': 'WIN'},
#  {'id': 35,
#   'franchiseId': 23,
#   'fullName': 'Colorado Rockies',
#   'leagueId': 133,
#   'rawTricode': 'CLR',
#   'triCode': 'CLR'},
#  {'id': 36,
#   'franchiseId': 3,
#   'fullName': 'Ottawa Senators (1917)',
#   'leagueId': 133,
#   'rawTricode': 'SEN',
#   'triCode': 'SEN'},
#  {'id': 37,
#   'franchiseId': 4,
#   'fullName': 'Hamilton Tigers',
#   'leagueId': 133,
#   'rawTricode': 'HAM',
#   'triCode': 'HAM'},
#  {'id': 38,
#   'franchiseId': 9,
#   'fullName': 'Pittsburgh Pirates',
#   'leagueId': 133,
#   'rawTricode': 'PIR',
#   'triCode': 'PIR'},
#  {'id': 39,
#   'franchiseId': 9,
#   'fullName': 'Philadelphia Quakers',
#   'leagueId': 133,
#   'rawTricode': 'QUA',
#   'triCode': 'QUA'},
#  {'id': 40,
#   'franchiseId': 12,
#   'fullName': 'Detroit Cougars',
#   'leagueId': 133,
#   'rawTricode': 'DCG',
#   'triCode': 'DCG'},
#  {'id': 41,
#   'franchiseId': 2,
#   'fullName': 'Montreal Wanderers',
#   'leagueId': 133,
#   'rawTricode': 'MWN',
#   'triCode': 'MWN'},
#  {'id': 42,
#   'franchiseId': 4,
#   'fullName': 'Quebec Bulldogs',
#   'leagueId': 133,
#   'rawTricode': 'QBD',
#   'triCode': 'QBD'},
#  {'id': 43,
#   'franchiseId': 7,
#   'fullName': 'Montreal Maroons',
#   'leagueId': 133,
#   'rawTricode': 'MMR',
#   'triCode': 'MMR'},
#  {'id': 44,
#   'franchiseId': 8,
#   'fullName': 'New York Americans',
#   'leagueId': 133,
#   'rawTricode': 'NYA',
#   'triCode': 'NYA'},
#  {'id': 45,
#   'franchiseId': 3,
#   'fullName': 'St. Louis Eagles',
#   'leagueId': 133,
#   'rawTricode': 'SLE',
#   'triCode': 'SLE'},
#  {'id': 46,
#   'franchiseId': 13,
#   'fullName': 'Oakland Seals',
#   'leagueId': 133,
#   'rawTricode': 'OAK',
#   'triCode': 'OAK'},
#  {'id': 47,
#   'franchiseId': 21,
#   'fullName': 'Atlanta Flames',
#   'leagueId': 133,
#   'rawTricode': 'AFM',
#   'triCode': 'AFM'},
#  {'id': 48,
#   'franchiseId': 23,
#   'fullName': 'Kansas City Scouts',
#   'leagueId': 133,
#   'rawTricode': 'KCS',
#   'triCode': 'KCS'},
#  {'id': 49,
#   'franchiseId': 13,
#   'fullName': 'Cleveland Barons',
#   'leagueId': 133,
#   'rawTricode': 'CLE',
#   'triCode': 'CLE'},
#  {'id': 50,
#   'franchiseId': 12,
#   'fullName': 'Detroit Falcons',
#   'leagueId': 133,
#   'rawTricode': 'DFL',
#   'triCode': 'DFL'},
#  {'id': 51,
#   'franchiseId': 8,
#   'fullName': 'Brooklyn Americans',
#   'leagueId': 133,
#   'rawTricode': 'BRK',
#   'triCode': 'BRK'},
#  {'id': 56,
#   'franchiseId': 13,
#   'fullName': 'California Golden Seals',
#   'leagueId': 133,
#   'rawTricode': 'CGS',
#   'triCode': 'CGS'},
#  {'id': 57,
#   'franchiseId': 5,
#   'fullName': 'Toronto Arenas',
#   'leagueId': 133,
#   'rawTricode': 'TAN',
#   'triCode': 'TAN'},
#  {'id': 58,
#   'franchiseId': 5,
#   'fullName': 'Toronto St. Patricks',
#   'leagueId': 133,
#   'rawTricode': 'TSP',
#   'triCode': 'TSP'},
#  {'id': 99,
#   'franchiseId': None,
#   'fullName': 'NHL',
#   'leagueId': 133,
#   'rawTricode': 'NHL',
#   'triCode': 'NHL'},
#  {'id': 17,
#   'franchiseId': 12,
#   'fullName': 'Detroit Red Wings',
#   'leagueId': 133,
#   'rawTricode': 'DET',
#   'triCode': 'DET'},
#  {'id': 6,
#   'franchiseId': 6,
#   'fullName': 'Boston Bruins',
#   'leagueId': 133,
#   'rawTricode': 'BOS',
#   'triCode': 'BOS'},
#  {'id': 5,
#   'franchiseId': 17,
#   'fullName': 'Pittsburgh Penguins',
#   'leagueId': 133,
#   'rawTricode': 'PIT',
#   'triCode': 'PIT'},
#  {'id': 14,
#   'franchiseId': 31,
#   'fullName': 'Tampa Bay Lightning',
#   'leagueId': 133,
#   'rawTricode': 'TBL',
#   'triCode': 'TBL'},
#  {'id': 4,
#   'franchiseId': 16,
#   'fullName': 'Philadelphia Flyers',
#   'leagueId': 133,
#   'rawTricode': 'PHI',
#   'triCode': 'PHI'},
#  {'id': 12,
#   'franchiseId': 26,
#   'fullName': 'Carolina Hurricanes',
#   'leagueId': 133,
#   'rawTricode': 'CAR',
#   'triCode': 'CAR'},
#  {'id': 20,
#   'franchiseId': 21,
#   'fullName': 'Calgary Flames',
#   'leagueId': 133,
#   'rawTricode': 'CGY',
#   'triCode': 'CGY'},
#  {'id': 8,
#   'franchiseId': 1,
#   'fullName': 'Montréal Canadiens',
#   'leagueId': 133,
#   'rawTricode': 'MTL',
#   'triCode': 'MTL'},
#  {'id': 15,
#   'franchiseId': 24,
#   'fullName': 'Washington Capitals',
#   'leagueId': 133,
#   'rawTricode': 'WSH',
#   'triCode': 'WSH'},
#  {'id': 23,
#   'franchiseId': 20,
#   'fullName': 'Vancouver Canucks',
#   'leagueId': 133,
#   'rawTricode': 'VAN',
#   'triCode': 'VAN'},
#  {'id': 21,
#   'franchiseId': 27,
#   'fullName': 'Colorado Avalanche',
#   'leagueId': 133,
#   'rawTricode': 'COL',
#   'triCode': 'COL'},
#  {'id': 18,
#   'franchiseId': 34,
#   'fullName': 'Nashville Predators',
#   'leagueId': 133,
#   'rawTricode': 'NSH',
#   'triCode': 'NSH'},
#  {'id': 24,
#   'franchiseId': 32,
#   'fullName': 'Anaheim Ducks',
#   'leagueId': 133,
#   'rawTricode': 'ANA',
#   'triCode': 'ANA'},
#  {'id': 54,
#   'franchiseId': 38,
#   'fullName': 'Vegas Golden Knights',
#   'leagueId': 133,
#   'rawTricode': 'VGK',
#   'triCode': 'VGK'},
#  {'id': 25,
#   'franchiseId': 15,
#   'fullName': 'Dallas Stars',
#   'leagueId': 133,
#   'rawTricode': 'DAL',
#   'triCode': 'DAL'},
#  {'id': 27,
#   'franchiseId': 28,
#   'fullName': 'Phoenix Coyotes',
#   'leagueId': 133,
#   'rawTricode': 'PHX',
#   'triCode': 'PHX'},
#  {'id': 16,
#   'franchiseId': 11,
#   'fullName': 'Chicago Blackhawks',
#   'leagueId': 133,
#   'rawTricode': 'CHI',
#   'triCode': 'CHI'},
#  {'id': 3,
#   'franchiseId': 10,
#   'fullName': 'New York Rangers',
#   'leagueId': 133,
#   'rawTricode': 'NYR',
#   'triCode': 'NYR'},
#  {'id': 13,
#   'franchiseId': 33,
#   'fullName': 'Florida Panthers',
#   'leagueId': 133,
#   'rawTricode': 'FLA',
#   'triCode': 'FLA'},
#  {'id': 22,
#   'franchiseId': 25,
#   'fullName': 'Edmonton Oilers',
#   'leagueId': 133,
#   'rawTricode': 'EDM',
#   'triCode': 'EDM'},
#  {'id': 30,
#   'franchiseId': 37,
#   'fullName': 'Minnesota Wild',
#   'leagueId': 133,
#   'rawTricode': 'MIN',
#   'triCode': 'MIN'},
#  {'id': 19,
#   'franchiseId': 18,
#   'fullName': 'St. Louis Blues',
#   'leagueId': 133,
#   'rawTricode': 'STL',
#   'triCode': 'STL'},
#  {'id': 2,
#   'franchiseId': 22,
#   'fullName': 'New York Islanders',
#   'leagueId': 133,
#   'rawTricode': 'NYI',
#   'triCode': 'NYI'},
#  {'id': 26,
#   'franchiseId': 14,
#   'fullName': 'Los Angeles Kings',
#   'leagueId': 133,
#   'rawTricode': 'LAK',
#   'triCode': 'LAK'},
#  {'id': 70,
#   'franchiseId': None,
#   'fullName': 'To be determined',
#   'leagueId': 133,
#   'rawTricode': 'TBD',
#   'triCode': 'TBD'},
#  {'id': 7,
#   'franchiseId': 19,
#   'fullName': 'Buffalo Sabres',
#   'leagueId': 133,
#   'rawTricode': 'BUF',
#   'triCode': 'BUF'},
#  {'id': 9,
#   'franchiseId': 30,
#   'fullName': 'Ottawa Senators',
#   'leagueId': 133,
#   'rawTricode': 'OTT',
#   'triCode': 'OTT'},
#  {'id': 10,
#   'franchiseId': 5,
#   'fullName': 'Toronto Maple Leafs',
#   'leagueId': 133,
#   'rawTricode': 'TOR',
#   'triCode': 'TOR'},
#  {'id': 1,
#   'franchiseId': 23,
#   'fullName': 'New Jersey Devils',
#   'leagueId': 133,
#   'rawTricode': 'NJD',
#   'triCode': 'NJD'},
#  {'id': 52,
#   'franchiseId': 35,
#   'fullName': 'Winnipeg Jets',
#   'leagueId': 133,
#   'rawTricode': 'WPG',
#   'triCode': 'WPG'},
#  {'id': 55,
#   'franchiseId': 39,
#   'fullName': 'Seattle Kraken',
#   'leagueId': 133,
#   'rawTricode': 'SEA',
#   'triCode': 'SEA'},
#  {'id': 28,
#   'franchiseId': 29,
#   'fullName': 'San Jose Sharks',
#   'leagueId': 133,
#   'rawTricode': 'SJS',
#   'triCode': 'SJS'},
#  {'id': 53,
#   'franchiseId': 28,
#   'fullName': 'Arizona Coyotes',
#   'leagueId': 133,
#   'rawTricode': 'ARI',
#   'triCode': 'ARI'},
#  {'id': 29,
#   'franchiseId': 36,
#   'fullName': 'Columbus Blue Jackets',
#   'leagueId': 133,
#   'rawTricode': 'CBJ',
#   'triCode': 'CBJ'},
#  {'id': 59,
#   'franchiseId': 40,
#   'fullName': 'Utah Hockey Club',
#   'leagueId': 133,
#   'rawTricode': 'UTA',
#   'triCode': 'UTA'}]

# %%
df_roster= pd.DataFrame(roster)
df_roster = df_roster.convert_dtypes()
df_roster = df_roster[['id', 'fullName', 'triCode']]
df_roster['prefix'] = "https://api-web.nhle.com/v1/roster/"
df_roster['suffix'] = "/20232024"
df_roster['roster_url'] = df_roster['prefix'] + df_roster['triCode'] + df_roster['suffix']
df_roster = df_roster[['id','fullName', 'triCode', 'roster_url']]
df_roster = df_roster.rename(columns = {'id':'team_id', 'fullName':'team_name', 'triCode':'tri_code'})
df_roster=df_roster.sort_values(by='team_id')


valid_team_codes = set(range(1, 11)).union(set(range(12, 27))).union(set(range(28, 31))).union(set(range(52, 53))).union(set(range(54, 56))).union(set(range(59, 60)))
filtered_rosters = df_roster[df_roster['team_id'].isin(valid_team_codes)]
filtered_rosters
# Out:
#     team_id              team_name tri_code  \
# 54        1      New Jersey Devils      NJD
# 48        2     New York Islanders      NYI
# 43        3       New York Rangers      NYR
# 30        4    Philadelphia Flyers      PHI
# 28        5    Pittsburgh Penguins      PIT
# 27        6          Boston Bruins      BOS
# 51        7         Buffalo Sabres      BUF
# 33        8     Montréal Canadiens      MTL
# 52        9        Ottawa Senators      OTT
# 53       10    Toronto Maple Leafs      TOR
# 31       12    Carolina Hurricanes      CAR
# 44       13       Florida Panthers      FLA
# 29       14    Tampa Bay Lightning      TBL
# 34       15    Washington Capitals      WSH
# 42       16     Chicago Blackhawks      CHI
# 26       17      Detroit Red Wings      DET
# 37       18    Nashville Predators      NSH
# 47       19        St. Louis Blues      STL
# 32       20         Calgary Flames      CGY
# 36       21     Colorado Avalanche      COL
# 45       22        Edmonton Oilers      EDM
# 35       23      Vancouver Canucks      VAN
# 38       24          Anaheim Ducks      ANA
# 40       25           Dallas Stars      DAL
# 49       26      Los Angeles Kings      LAK
# 57       28        San Jose Sharks      SJS
# 59       29  Columbus Blue Jackets      CBJ
# 46       30         Minnesota Wild      MIN
# 55       52          Winnipeg Jets      WPG
# 39       54   Vegas Golden Knights      VGK
# 56       55         Seattle Kraken      SEA
# 60       59       Utah Hockey Club      UTA
#
#                                          roster_url
# 54  https://api-web.nhle.com/v1/roster/NJD/20232024
# 48  https://api-web.nhle.com/v1/roster/NYI/20232024
# 43  https://api-web.nhle.com/v1/roster/NYR/20232024
# 30  https://api-web.nhle.com/v1/roster/PHI/20232024
# 28  https://api-web.nhle.com/v1/roster/PIT/20232024
# 27  https://api-web.nhle.com/v1/roster/BOS/20232024
# 51  https://api-web.nhle.com/v1/roster/BUF/20232024
# 33  https://api-web.nhle.com/v1/roster/MTL/20232024
# 52  https://api-web.nhle.com/v1/roster/OTT/20232024
# 53  https://api-web.nhle.com/v1/roster/TOR/20232024
# 31  https://api-web.nhle.com/v1/roster/CAR/20232024
# 44  https://api-web.nhle.com/v1/roster/FLA/20232024
# 29  https://api-web.nhle.com/v1/roster/TBL/20232024
# 34  https://api-web.nhle.com/v1/roster/WSH/20232024
# 42  https://api-web.nhle.com/v1/roster/CHI/20232024
# 26  https://api-web.nhle.com/v1/roster/DET/20232024
# 37  https://api-web.nhle.com/v1/roster/NSH/20232024
# 47  https://api-web.nhle.com/v1/roster/STL/20232024
# 32  https://api-web.nhle.com/v1/roster/CGY/20232024
# 36  https://api-web.nhle.com/v1/roster/COL/20232024
# 45  https://api-web.nhle.com/v1/roster/EDM/20232024
# 35  https://api-web.nhle.com/v1/roster/VAN/20232024
# 38  https://api-web.nhle.com/v1/roster/ANA/20232024
# 40  https://api-web.nhle.com/v1/roster/DAL/20232024
# 49  https://api-web.nhle.com/v1/roster/LAK/20232024
# 57  https://api-web.nhle.com/v1/roster/SJS/20232024
# 59  https://api-web.nhle.com/v1/roster/CBJ/20232024
# 46  https://api-web.nhle.com/v1/roster/MIN/20232024
# 55  https://api-web.nhle.com/v1/roster/WPG/20232024
# 39  https://api-web.nhle.com/v1/roster/VGK/20232024
# 56  https://api-web.nhle.com/v1/roster/SEA/20232024
# 60  https://api-web.nhle.com/v1/roster/UTA/20232024

# %%
filtered_rosters
# Out:
#     team_id              team_name tri_code  \
# 54        1      New Jersey Devils      NJD
# 48        2     New York Islanders      NYI
# 43        3       New York Rangers      NYR
# 30        4    Philadelphia Flyers      PHI
# 28        5    Pittsburgh Penguins      PIT
# 27        6          Boston Bruins      BOS
# 51        7         Buffalo Sabres      BUF
# 33        8     Montréal Canadiens      MTL
# 52        9        Ottawa Senators      OTT
# 53       10    Toronto Maple Leafs      TOR
# 31       12    Carolina Hurricanes      CAR
# 44       13       Florida Panthers      FLA
# 29       14    Tampa Bay Lightning      TBL
# 34       15    Washington Capitals      WSH
# 42       16     Chicago Blackhawks      CHI
# 26       17      Detroit Red Wings      DET
# 37       18    Nashville Predators      NSH
# 47       19        St. Louis Blues      STL
# 32       20         Calgary Flames      CGY
# 36       21     Colorado Avalanche      COL
# 45       22        Edmonton Oilers      EDM
# 35       23      Vancouver Canucks      VAN
# 38       24          Anaheim Ducks      ANA
# 40       25           Dallas Stars      DAL
# 49       26      Los Angeles Kings      LAK
# 57       28        San Jose Sharks      SJS
# 59       29  Columbus Blue Jackets      CBJ
# 46       30         Minnesota Wild      MIN
# 55       52          Winnipeg Jets      WPG
# 39       54   Vegas Golden Knights      VGK
# 56       55         Seattle Kraken      SEA
# 60       59       Utah Hockey Club      UTA
#
#                                          roster_url
# 54  https://api-web.nhle.com/v1/roster/NJD/20232024
# 48  https://api-web.nhle.com/v1/roster/NYI/20232024
# 43  https://api-web.nhle.com/v1/roster/NYR/20232024
# 30  https://api-web.nhle.com/v1/roster/PHI/20232024
# 28  https://api-web.nhle.com/v1/roster/PIT/20232024
# 27  https://api-web.nhle.com/v1/roster/BOS/20232024
# 51  https://api-web.nhle.com/v1/roster/BUF/20232024
# 33  https://api-web.nhle.com/v1/roster/MTL/20232024
# 52  https://api-web.nhle.com/v1/roster/OTT/20232024
# 53  https://api-web.nhle.com/v1/roster/TOR/20232024
# 31  https://api-web.nhle.com/v1/roster/CAR/20232024
# 44  https://api-web.nhle.com/v1/roster/FLA/20232024
# 29  https://api-web.nhle.com/v1/roster/TBL/20232024
# 34  https://api-web.nhle.com/v1/roster/WSH/20232024
# 42  https://api-web.nhle.com/v1/roster/CHI/20232024
# 26  https://api-web.nhle.com/v1/roster/DET/20232024
# 37  https://api-web.nhle.com/v1/roster/NSH/20232024
# 47  https://api-web.nhle.com/v1/roster/STL/20232024
# 32  https://api-web.nhle.com/v1/roster/CGY/20232024
# 36  https://api-web.nhle.com/v1/roster/COL/20232024
# 45  https://api-web.nhle.com/v1/roster/EDM/20232024
# 35  https://api-web.nhle.com/v1/roster/VAN/20232024
# 38  https://api-web.nhle.com/v1/roster/ANA/20232024
# 40  https://api-web.nhle.com/v1/roster/DAL/20232024
# 49  https://api-web.nhle.com/v1/roster/LAK/20232024
# 57  https://api-web.nhle.com/v1/roster/SJS/20232024
# 59  https://api-web.nhle.com/v1/roster/CBJ/20232024
# 46  https://api-web.nhle.com/v1/roster/MIN/20232024
# 55  https://api-web.nhle.com/v1/roster/WPG/20232024
# 39  https://api-web.nhle.com/v1/roster/VGK/20232024
# 56  https://api-web.nhle.com/v1/roster/SEA/20232024
# 60  https://api-web.nhle.com/v1/roster/UTA/20232024

# %%
# Create an empty dictionary to store the results
roster_dict = {}
roster_link = filtered_rosters['roster_url'] 

    # Define your extraction script as a function
def extract_roster_data(roster_link):
    try:
        # Send an HTTP GET request to the game URL
        response = requests.get(roster_link)
        
        # Check if the request was successful (status code 200)
        if response.status_code == 200:
            response_text = response.text
            json_data = json.loads(response_text)

            forwards = json_data['forwards']
            forwards_df = pd.DataFrame(forwards)
            forwards_df = forwards_df.convert_dtypes()
            forwards_df = forwards_df[['id', 'headshot', 'firstName', 'lastName', 'sweaterNumber', 'positionCode']]
            forwards_df = forwards_df.dropna(subset=['sweaterNumber'])

            # Normalize (separates the data in the curly brackets out into separate columns)
            forwards_last = pd.json_normalize(forwards_df['lastName'])
            forwards_last = pd.DataFrame(forwards_last)
            forwards_last = forwards_last[['default']]
            forwards_last = forwards_last.rename(columns={'default': 'last_name'})

            forwards_first = pd.json_normalize(forwards_df['firstName'])
            forwards_first = pd.DataFrame(forwards_first)
            forwards_first = forwards_first[['default']]
            forwards_first = forwards_first.rename(columns={'default': 'first_name'})

            forwards_roster = forwards_df.merge(forwards_first, left_index=True, right_index=True).merge(forwards_last, left_index=True, right_index=True)
            forwards_roster['player_name'] = forwards_roster['first_name'] + " " + forwards_roster['last_name']
            forwards_roster = forwards_roster[['id', 'headshot', 'player_name', 'sweaterNumber', 'positionCode']]

            defense = json_data['defensemen']
            defense_df = pd.DataFrame(defense)
            defense_df = defense_df.convert_dtypes()
            defense_df = defense_df[['id', 'headshot', 'firstName', 'lastName', 'sweaterNumber', 'positionCode']]
            defense_df = defense_df.dropna(subset=['sweaterNumber'])

            # Normalize (separates the data in the curly brackets out into separate columns)
            defense_last = pd.json_normalize(defense_df['lastName'])
            defense_last = pd.DataFrame(defense_last)
            defense_last = defense_last[['default']]
            defense_last = defense_last.rename(columns={'default': 'last_name'})

            defense_first = pd.json_normalize(defense_df['firstName'])
            defense_first = pd.DataFrame(defense_first)
            defense_first = defense_first[['default']]
            defense_first = defense_first.rename(columns={'default': 'first_name'})

            defense_roster = defense_df.merge(defense_first, left_index=True, right_index=True).merge(defense_last, left_index=True, right_index=True)
            defense_roster['player_name'] = defense_roster['first_name'] + " " + defense_roster['last_name']
            defense_roster = defense_roster[['id', 'headshot', 'player_name', 'sweaterNumber', 'positionCode']]

            goalies = json_data['goalies']
            goalies_df = pd.DataFrame(goalies)
            goalies_df = goalies_df.convert_dtypes()
            goalies_df = goalies_df[['id', 'headshot', 'firstName', 'lastName', 'sweaterNumber', 'positionCode']]
            goalies_df = goalies_df.dropna(subset=['sweaterNumber'])

            # Normalize (separates the data in the curly brackets out into separate columns)
            goalies_last = pd.json_normalize(goalies_df['lastName'])
            goalies_last = pd.DataFrame(goalies_last)
            goalies_last = goalies_last[['default']]
            goalies_last = goalies_last.rename(columns={'default': 'last_name'})

            goalies_first = pd.json_normalize(goalies_df['firstName'])
            goalies_first = pd.DataFrame(goalies_first)
            goalies_first = goalies_first[['default']]
            goalies_first = goalies_first.rename(columns={'default': 'first_name'})

            goalie_roster = goalies_df.merge(goalies_first, left_index=True, right_index=True).merge(goalies_last, left_index=True, right_index=True)
            goalie_roster['player_name'] = goalie_roster['first_name'] + " " + goalie_roster['last_name']
            goalie_roster = goalie_roster[['id', 'headshot', 'player_name', 'sweaterNumber', 'positionCode']]

            # Append all data to form a single team roster
            team_roster_df = pd.concat([forwards_roster, defense_roster, goalie_roster], axis=0, ignore_index=True)

            team_roster_df['id'] = team_roster_df['id'] .astype(float, errors='ignore')

                                
            def extract_tricode(link):
                # Use a regular expression to find the tricode
                match = re.search(r'/([A-Z]{3})/', link)
                if match:
                    return match.group(1)
                else:
                    # Return None if no match is found
                    return None

            team_roster_df['tri_code'] = team_roster_df['headshot'].apply(extract_tricode)
            return team_roster_df  # Return the entire processed DataFrame
        else:
            print(f"Request failed for {roster_link} with status code {response.status_code}")
            return None  # Return None to indicate failure
    
    except Exception as e:
            print(f"An error occurred: {e}")
            return None  # Return None to indicate failure
    
# Loop through the rows of the filtered_rosters df
for index, row in filtered_rosters.iterrows():
    # Extract the API link from the current row
    roster_link = row['roster_url']

    # Run your game-specific data script and get the entire processed DataFrame
    team_roster = extract_roster_data(roster_link)
    
    # Check if team_roster is not None before proceeding
    if team_roster is not None:
        # Add a 'game_id' column to the game_specific_data DataFrame
        team_roster['tri_code'] = row['tri_code']

        # Store the result in the dictionary with the game ID as the key
        roster_dict[row['tri_code']] = team_roster
    else:
        print(f"Skipping row {index} due to failed request or exception.")

all_rosters = pd.concat(roster_dict.values(), ignore_index=True)

team_rosters = filtered_rosters[['team_id', 'team_name', 'tri_code']]
team_rosters = team_rosters.merge(all_rosters,  on = "tri_code", how = "left")
team_rosters = team_rosters.rename(columns= {'id':'player_id'})


print("rosters done")
# Out:
# rosters done

# %%
games = combined_df[['game_id', 'season', 'gameType', 'awayTeam.id', 'awayTeam.abbrev', 'awayTeam.logo', 
                        'homeTeam.id', 'homeTeam.abbrev','homeTeam.logo', 'awayTeam.score', 'homeTeam.score', 'winningGoalScorer.playerId', 
                        'winningGoalie.playerId', 'link']]
games = games.sort_values(by='game_id')
games = games.rename(columns = {'gameType':'game_type', 'awayTeam.id':'away_team_id', 'awayTeam.abbrev':'away_team_tricode', 
                    'awayTeam.logo': 'away_logo', 'homeTeam.id':'home_team_id', 'homeTeam.abbrev':'home_team_tricode', 'homeTeam.logo':'home_logo', 
                    'awayTeam.score': 'away_score', 'homeTeam.score':'home_score', 'winningGoalScorer.playerId':'winning_goal_player_id', 
                    'winningGoalie.playerId':'winning_goalie_id'})


games = pd.merge(games, df_roster, left_on='home_team_id', right_on='team_id', how='left')

# Rename columns and drop redundant columns
games.rename(columns={'roster_url': 'home_roster_link', 'team_name':'home_team_name'}, inplace=True)
games.drop(columns=['team_id', 'tri_code'], inplace=True)

# Merge DataFrames based on away_team_code
games = pd.merge(games, df_roster, left_on='away_team_id', right_on='team_id', how='left')

# Rename columns and drop redundant columns
games.rename(columns={'roster_url': 'away_roster_link', 'team_name':'away_team_name'}, inplace=True)
games.drop(columns=['team_id','tri_code'], inplace=True)

# Assuming '<NA>' is a string, replace it with np.nan
games['game_id'].replace('<NA>', np.nan, inplace=True)
# Drop rows with NaN values in the 'link' column
games = games.dropna(subset=['game_id'])

# Reset index after dropping rows
games.reset_index(drop=True, inplace=True)

# %%
games.head()
# Out:
#       game_id    season  game_type  away_team_id away_team_tricode  \
# 0  2022020320  20222023          2            21               COL
# 1  2022020547  20222023          2             7               BUF
# 2  2022030111  20222023          3            13               FLA
# 3  2022030112  20222023          3            13               FLA
# 4  2022030121  20222023          3            14               TBL
#
#                                            away_logo  home_team_id  \
# 0  https://assets.nhle.com/logos/nhl/svg/COL_ligh...            18
# 1  https://assets.nhle.com/logos/nhl/svg/BUF_ligh...            29
# 2  https://assets.nhle.com/logos/nhl/svg/FLA_ligh...             6
# 3  https://assets.nhle.com/logos/nhl/svg/FLA_ligh...             6
# 4  https://assets.nhle.com/logos/nhl/svg/TBL_ligh...            10
#
#   home_team_tricode                                          home_logo  \
# 0               NSH  https://assets.nhle.com/logos/nhl/svg/NSH_ligh...
# 1               CBJ  https://assets.nhle.com/logos/nhl/svg/CBJ_ligh...
# 2               BOS  https://assets.nhle.com/logos/nhl/svg/BOS_2008...
# 3               BOS  https://assets.nhle.com/logos/nhl/svg/BOS_2008...
# 4               TOR  https://assets.nhle.com/logos/nhl/svg/TOR_ligh...
#
#    away_score  home_score  winning_goal_player_id  winning_goalie_id  \
# 0           4           3                 8477492            8480382
# 1           5           2                 8477949            8482221
# 2           1           3                 8473419            8476999
# 3           6           3                 8477409            8479312
# 4           7           3                 8478010            8476883
#
#                                                 link         home_team_name  \
# 0  https://api-web.nhle.com/v1/gamecenter/2022020...    Nashville Predators
# 1  https://api-web.nhle.com/v1/gamecenter/2022020...  Columbus Blue Jackets
# 2  https://api-web.nhle.com/v1/gamecenter/2022030...          Boston Bruins
# 3  https://api-web.nhle.com/v1/gamecenter/2022030...          Boston Bruins
# 4  https://api-web.nhle.com/v1/gamecenter/2022030...    Toronto Maple Leafs
#
#                                   home_roster_link       away_team_name  \
# 0  https://api-web.nhle.com/v1/roster/NSH/20232024   Colorado Avalanche
# 1  https://api-web.nhle.com/v1/roster/CBJ/20232024       Buffalo Sabres
# 2  https://api-web.nhle.com/v1/roster/BOS/20232024     Florida Panthers
# 3  https://api-web.nhle.com/v1/roster/BOS/20232024     Florida Panthers
# 4  https://api-web.nhle.com/v1/roster/TOR/20232024  Tampa Bay Lightning
#
#                                   away_roster_link
# 0  https://api-web.nhle.com/v1/roster/COL/20232024
# 1  https://api-web.nhle.com/v1/roster/BUF/20232024
# 2  https://api-web.nhle.com/v1/roster/FLA/20232024
# 3  https://api-web.nhle.com/v1/roster/FLA/20232024
# 4  https://api-web.nhle.com/v1/roster/TBL/20232024

# %%
# Create an empty dictionary to store the results
for index, row in games.iterrows():
    # Check if 'link' is in the columns of the current row
    if 'link' not in row.index:
        print(f"Skipping row {index} as it does not contain 'link' column.")
        continue

game_link = row['link']
game_data_dict = {}
game_id = row['game_id']

    # Define your extraction script as a function
def extract_game_data(game_link):
    try:
        # Send an HTTP GET request to the game URL
        response = requests.get(game_link)

        # Check if the request was successful (status code 200)
        if response.status_code == 200:
            response_text = response.text
            json_game_data = json.loads(response_text)

            #event data
            event_data = json_game_data['plays']
            events_df = pd.DataFrame(event_data)
            events_df = events_df.convert_dtypes()

            #game events data
            game_events = events_df[['sortOrder','timeInPeriod', 'homeTeamDefendingSide', 'typeCode']]

            #coordinates data
            details = pd.json_normalize(events_df['details'])
            details = pd.DataFrame(details)
            details = details[['eventOwnerTeamId', 'xCoord', 'yCoord', 'shotType', 'scoringPlayerId']]

            #join the dfs
            all_game_data = game_events.merge(details, left_index=True, right_index=True)

            # Filter rows where 'typeCode' is 505
            shots = all_game_data[all_game_data['typeCode'].isin([505, 506, 507, 508])]

            # Convert the 'player_id' column to the appropriate data type (e.g., int)
            #all_game_data['scoringPlayerId'] = all_game_data['scoringPlayerId'].astype(float).astype(pd.Int64Dtype(), errors='ignore')

            # Create a 'game_id' column
            all_game_data['game_id'] = row['game_id']

            return shots  # Return the processed DataFrame and game_id

        else:
            print(f"Request failed for {game_link} with status code {response.status_code}")
            return pd.DataFrame(), None  # Return an empty DataFrame and None to indicate failure

    except Exception as e:
        print(f"An error occurred: {e}")
        return pd.DataFrame(), None  # Return an empty DataFrame and None to indicate failure
    
    # Run your game-specific data script and get the entire processed DataFrame and game_id
for index, row in games.iterrows():
    # Extract the API link from the current row
    game_link = row['link']
    
# Run your game-specific data script and get the entire processed DataFrame
    game_specific_data = extract_game_data(game_link)

        # Add a 'game_id' column to the game_specific_data DataFrame
    game_specific_data['game_id'] = row['game_id']
    
    # Store the result in the dictionary with the game ID as the key
    game_data_dict[row['game_id']] = game_specific_data

game_data = pd.concat(game_data_dict.values(), ignore_index=True)
game_goals_data = game_data[game_data['typeCode'] == 505]
game_goals_data = game_goals_data.rename(columns = {'scoringPlayerId':'player_id'})

team_rosters = team_rosters.rename(columns = {'sweaterNumber': 'jersey_number', 'positionCode':'position'})

print("goals done")
# Out:
# goals done

# %%
game_data
# Out:
#       sortOrder timeInPeriod homeTeamDefendingSide  typeCode  \
# 0            13        00:28                  left       505
# 1            26        01:33                  left       506
# 2            38        02:10                  left       508
# 3            48        03:20                  left       505
# 4            54        04:00                  left       506
# 5            55        04:06                  left       506
# 6            61        04:16                  left       506
# 7            62        04:30                  left       506
# 8            63        04:35                  left       507
# 9            73        04:59                  left       506
# 10           78        05:19                  left       507
# 11           80        05:42                  left       505
# 12           84        06:04                  left       506
# 13           85        06:11                  left       506
# 14           87        06:37                  left       506
# 15          109        08:43                  left       507
# 16          110        08:50                  left       508
# 17          111        09:01                  left       508
# 18          119        09:19                  left       506
# 19          129        10:26                  left       508
# 20          131        10:36                  left       507
# 21          142        11:42                  left       506
# 22          143        11:43                  left       506
# 23          159        13:14                  left       505
# 24          173        14:13                  left       506
# 25          184        15:31                  left       507
# 26          188        16:02                  left       506
# 27          192        16:17                  left       507
# 28          193        16:27                  left       508
# 29          194        16:28                  left       508
# 30          199        17:22                  left       506
# 31          211        18:19                  left       506
# 32          227        19:46                  left       506
# 33          228        19:47                  left       506
# 34          250        01:09                 right       508
# 35          254        01:26                 right       508
# 36          261        01:51                 right       506
# 37          266        02:03                 right       506
# 38          267        02:12                 right       508
# 39          268        02:21                 right       507
# 40          272        02:32                 right       505
# 41          322        07:08                 right       505
# 42          333        08:13                 right       506
# 43          334        08:16                 right       506
# 44          335        08:22                 right       506
# 45          341        08:35                 right       508
# 46          371        11:03                 right       508
# 47          378        11:52                 right       506
# 48          384        12:02                 right       508
# 49          389        12:08                 right       508
# 50          390        12:26                 right       507
# 2223  2022030182
# 2224  2022030182
# 2225  2022030182
# 2226  2022030182
# 2227  2022030182
# 2228  2022030182
# 2229  2022030182
# 2230  2022030182
# 2231  2022030182
# 2232  2022030182
# 2233  2022030182
# 2234  2022030182
# 2235  2022030182
# 2236  2022030182
# 2237  2022030182
# 2238  2022030182
# 2239  2022030182
# 2240  2022030182
# 2241  2022030182
# 2242  2022030182
# 2243  2022030182
# 2244  2022030182
# 2245  2022030182
# 2246  2022030182
# 2247  2022030182
# 2248  2022030182
# 2249  2022030182
# 2250  2022030182
# 2251  2022030182
# 2252  2022030182
# 2253  2022030182
# 2254  2022030182
# 2255  2022030182
# 2256  2022030182
# 2257  2022030182
# 2258  2022030182
# 2259  2022030182
# 2260  2022030182
# 2261  2022030182
# 2262  2022030182
# 2263  2022030182
# 2264  2022030182
# 2265  2022030182
# 2266  2022030182
# 2267  2022030182
# 2268  2022030182
# 2269  2022030182
# 2270  2022030182

# %%
game_specific_data.head()
# Out:
#     sortOrder timeInPeriod homeTeamDefendingSide  typeCode  eventOwnerTeamId  \
# 2          12        00:28                  left       508              22.0
# 12         29        01:37                  left       508              22.0
# 19         48        02:32                  left       508              22.0
# 20         49        02:34                  left       505              22.0
# 24         56        03:13                  left       507              26.0
#
#     xCoord  yCoord shotType  scoringPlayerId     game_id
# 2     46.0   -16.0      NaN              NaN  2022030182
# 12    72.0    12.0      NaN              NaN  2022030182
# 19    67.0     0.0      NaN              NaN  2022030182
# 20    79.0    -3.0    wrist        8478585.0  2022030182
# 24   -66.0   -34.0    wrist              NaN  2022030182

# %%
shots_df = game_specific_data[game_specific_data['typeCode'].isin([505, 506, 507, 508])]
shots_df = shots_df.sort_values(by=['timeInPeriod', 'sortOrder'])

shots_df=shots_df.rename(columns = {'eventOwnerTeamId':'team_id'})
shots_df = shots_df.dropna(subset=['team_id'])
shots_df['team_id'] =shots_df['team_id'].astype('Int64').astype(int)

# %%
shots_df.head()
# Out:
#      sortOrder timeInPeriod homeTeamDefendingSide  typeCode  team_id  xCoord  \
# 140        329        00:18                 right       508       26    45.0
# 273        617        00:18                  left       506       22    73.0
# 141        330        00:24                 right       506       22   -52.0
# 274        618        00:24                  left       507       22    84.0
# 275        619        00:25                  left       506       22    89.0
#
#      yCoord  shotType  scoringPlayerId     game_id
# 140   -23.0       NaN              NaN  2022030182
# 273    -8.0  backhand              NaN  2022030182
# 141    17.0      snap              NaN  2022030182
# 274     8.0       bat              NaN  2022030182
# 275    12.0  backhand              NaN  2022030182

# %%
#Merging game data and roster data to create goal counts
if 'player_id' in team_rosters.columns:
    # Merge the coordinates data from final_game_data to goal_counts based on player IDs
    goal_counts = team_rosters.merge(game_goals_data[['player_id', 'sortOrder']],on = 'player_id')
else:
    print("Column 'player_id 'does not exist in goal_counts DataFrame.")

goal_counts = goal_counts.groupby(['jersey_number','player_id', 'player_name', 'position', 'team_name'])['sortOrder'].count()
goal_counts=pd.DataFrame(goal_counts).reset_index()
goal_counts = goal_counts.rename(columns={'sortOrder': 'goals'})
goal_counts = goal_counts.sort_values(by='player_name')
goal_counts.head()
# Out:
#     jersey_number  player_id      player_name position            team_name  \
# 16             17  8476392.0       Adam Lowry        C        Winnipeg Jets
# 6               9  8480113.0     Alex Iafallo        L        Winnipeg Jets
# 9              11  8471685.0  Alex Laferriere        C    Los Angeles Kings
# 47             71  8478519.0  Anthony Cirelli        C  Tampa Bay Lightning
# 4               9  8477960.0     Anze Kopitar        R    Los Angeles Kings
#
#     goals
# 16      3
# 6       1
# 9       1
# 47      1
# 4       2

# %%
game_goals_data
# Out:
#       sortOrder timeInPeriod homeTeamDefendingSide  typeCode  \
# 0            13        00:28                  left       505
# 3            48        03:20                  left       505
# 11           80        05:42                  left       505
# 23          159        13:14                  left       505
# 40          272        02:32                 right       505
# 41          322        07:08                 right       505
# 106         708        18:18                  left       505
# 110          13        00:34                  left       505
# 167         348        08:36                 right       505
# 176         393        12:35                 right       505
# 178         409        14:01                 right       505
# 186         459        18:24                 right       505
# 195         535        04:03                  left       505
# 220         697        17:27                  left       505
# 239         102        05:58                  left       505
# 279         383        03:41                 right       505
# 284         426        06:34                 right       505
# 306         585        17:32                 right       505
# 395         326        01:42                 right       505
# 421         468        12:13                 right       505
# 427         494        14:18                 right       505
# 429         524        17:01                 right       505
# 439         581        00:22                  left       505
# 452         674        07:00                  left       505
# 461         755        12:30                  left       505
# 469         819        17:35                  left       505
# 471         837        18:50                  left       505
# 475          32        01:18                 right       505
# 491         134        07:18                 right       505
# 517         337        19:56                 right       505
# 532         456        08:06                  left       505
# 548         536        13:11                  left       505
# 553         561        14:29                  left       505
# 558         611        17:54                  left       505
# 565         630        19:58                  left       505
# 577         738        06:59                 right       505
# 579         759        08:06                 right       505
# 598          21        00:47                 right       505
# 619         210        12:45                 right       505
# 626         252        15:08                 right       505
# 654         446        08:58                  left       505
# 666         507        13:14                  left       505
# 674         551        15:52                  left       505
# 677         574        18:02                  left       505
# 697         802        12:38                 right       505
# 702         839        15:06                 right       505
# 719          82        03:47                 right       505
# 760         380        02:27                  left       505
# 761         387        02:51                  left       505
# 856         103        05:49                 right       505
# 902         392        07:19                  left       505
# 910         436        10:48                  left       505
# 924         547        19:39                  left       505
# 941         695        09:18                 right       505
# 949         738        12:19                 right       505
# 975         938        05:03                  left       505
# 985          72        04:58                  left       505
# 993         137        09:30                  left       505
# 1050        530        16:57                 right       505
# 1077        712        11:07                  left       505
# 1086        807        17:14                  left       505
# 1087        813        18:02                  left       505
# 1113        182        11:44                  left       505
# 1141        390        05:53                 right       505
# 1151        437        09:57                 right       505
# 1157        505        16:00                 right       505
# 1179        653        06:34                  left       505
# 1190        740        13:05                  left       505
# 1211         61        03:26                 right       505
# 1232        207        12:35                 right       505
# 1252        340        01:20                  left       505
# 1312        668        04:03                 right       505
# 1349         60        02:40                 right       505
# 1365        201        13:27                 right       505
# 1394        398        06:42                  left       505
# 1397        413        07:30                  left       505
# 1456        802        12:59                 right       505
# 1492        298        19:12                 right       505
# 1500        351        02:08                  left       505
# 1504        385        04:13                  left       505
goal_locations = goal_locations[['jersey_number', 'player_id','player_name', 'position', 'team_name', 'sortOrder', 'xCoord', 'yCoord', 'game_id']]
goal_locations = goal_locations.dropna(subset=['player_id'])
goal_locations = goal_locations.sort_values(['player_name', 'player_id', 'sortOrder'], ascending=[True, True, True])
goal_locations.head()
# Out:
#     jersey_number  player_id      player_name position          team_name  \
# 81             17  8476392.0       Adam Lowry        C      Winnipeg Jets
# 79             17  8476392.0       Adam Lowry        C      Winnipeg Jets
# 80             17  8476392.0       Adam Lowry        C      Winnipeg Jets
# 78              9  8480113.0     Alex Iafallo        L      Winnipeg Jets
# 70             11  8471685.0  Alex Laferriere        C  Los Angeles Kings
#
#     sortOrder  xCoord  yCoord     game_id
# 81        157    69.0     0.0  2022030172
# 79        884    84.0     0.0  2022030171
# 80        897    84.0     5.0  2022030171
# 78       1011    67.0     4.0  2022030181
# 70        871   -83.0     0.0  2022030181

# %%
#append the data to the master set
goal_location_df = pd.concat([goal_location_df, goal_locations], ignore_index=True)
goal_location_df =  goal_location_df.sort_values(['player_name', 'player_id', 'sortOrder'], ascending=[True, True, True])

# file_path1 = 'C:\\Users\\Karoline Sears\\Documents\\GitHub\\hockey-streamlit\\data\\goal_locations.csv'
# goal_location_df.to_csv(file_path1,  index=False, encoding='utf-8')

# Append last_nights_goals to season_goals
combined_goals = pd.concat([goal_counts_df, goal_counts], ignore_index=True)

# Sum up the goals for duplicated players
result = combined_goals.groupby(['jersey_number', 'player_id', 'player_name', 'position', 'team_name'], as_index=False)['goals'].sum()
result=result.sort_values(by='player_name')

file_path2 = 'C:\\Users\\Karoline Sears\\Documents\\GitHub\\hockey-streamlit\\data\\goal_counts.csv'
result.to_csv(file_path2,  index=False, encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[92], line 2
#       1 #append the data to the master set
# ----> 2 goal_location_df = pd.concat([goal_location_df, goal_locations], ignore_index=True)
#       3 goal_location_df =  goal_location_df.sort_values(['player_name', 'player_id', 'sortOrder'], ascending=[True, True, True])
#       4 goal_location_df
#
# NameError: name 'goal_location_df' is not defined

# %%
#running count of goal number for each player - make sure this is ordered by game id and time in period

goal_talley =goal_location_df.sort_values(['player_name', 'player_id', 'game_id', 'sortOrder', 'period'], 
                                          ascending=[True, True, True, True, True])
goal_talley['goal_no'] = goal_talley.groupby('player_id').cumcount()+1

def adjust_coordinates(row):
    x = row['xCoord']
    y = row['yCoord']
    if x < 0:
        adj_x = abs(x)
        adj_y = -y
    else:
        adj_x = x
        adj_y = y
    return pd.Series({'x_adjusted': adj_x, 'y_adjusted': adj_y})

# Apply the function to each row of the DataFrame
goal_talley[['x_adjusted', 'y_adjusted']] = goal_talley.apply(adjust_coordinates, axis=1)
ice_map_data = goal_talley
ice_map_data=ice_map_data[['game_id', 'goal_no', 'player_id','player_name', 'team_name', 'period', 'x_adjusted', 'y_adjusted' ]]

# file_path3 = 'C:\\Users\\Karoline Sears\\Documents\\GitHub\\hockey-streamlit\\data\\ice_map_data.csv'
# ice_map_data.to_csv(file_path3,  index=False, encoding='utf-8')
print("completed", formatted_date)
